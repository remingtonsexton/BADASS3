# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True
plt.style.use('dark_background')
# plt.rcParams["font.family"] = "Times New Roman"
# import seaborn as sns
# sns.set_style("whitegrid")

from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))

from scipy import stats
# from astropy.table import Table
# tbdata = Table.read('datafile', format='fits')
# df = tbdata.to_pandas()

# df['class'] = df['class'].str.decode('utf-8') 

# Plot
# fig = plt.figure(figsize=(5,5))
# ax1 = fig.add_subplot(1,1,1)
# fontsize=16

# ax1.set_xlabel(r"",fontsize=fontsize)
# ax1.set_ylabel(r"",fontsize=fontsize)
# ax1.set_title(r"",fontsize=fontsize)
# ax1.tick_params(axis='both', labelsize=fontsize)
# plt.tight_layout()
# Out:
# <style>.container { width:85% !important; }</style>

# %%
r1 = np.array([50.57085798853485, 48.682315926834214, 48.968036827373176, 49.59126051487603, 49.73667336759903, 46.69426543619266, 47.15077002055725, 46.8301015171589, 46.34886189231951, 46.48363486732011, 46.32432750342802, 46.60351966904068, 47.533306465397985, 62.749336472154404, 50.60478651323454, 47.263468757064665, 47.26357101648495, 46.39165504769526, 50.74241780228304, 47.196371673218124, 47.60426233298364, 47.212564599335586, 46.273954309819324, 47.262982201251816, 47.23360361873232, 128.25365681083727, 47.236406966372])
r2 = np.array([34.95898939537462, 31.470506756882465, 31.377968820604107, 31.781511203706092, 33.954926463037644, 32.33171859072121, 31.357515285827702, 31.08057048900858, 31.420489299274003, 46.522318874418154, 31.504970407610845, 32.01991029962444, 31.56569274916735, 31.898621009825813, 31.167743729660266, 47.28803908821661, 31.829776361768, 31.380597280404324, 31.346164159334904, 31.62804605873703, 31.8349334057265, 31.216243021737903, 31.634513820133442])
r3 = np.array([31.725354049619853, 31.735429643614758, 31.73267887619262, 16.29342636972912, 31.205877088656333, 31.990949962758453, 16.686769616762426, 17.037615577853156, 16.040247856280505, 31.667214986839692, 16.086182588774967, 15.294021161024963, 31.480944094891296, 32.03244123299596, 15.945314204451215, 16.951574163414193, 31.651182239007227])
r4 = np.array([16.013880456536434, 13.871174260337058, 15.319364630214144])
# r5 = np.array()

med1 = np.array([np.nanmedian(r1[:r]) for r in range(len(r1))])
mad1 = np.array([stats.median_abs_deviation(r1[:r]) for r in range(len(r1))])
std1 = np.array([np.nanstd(r1[:r]) for r in range(len(r1))])

med2 = np.array([np.nanmedian(r2[:r]) for r in range(len(r2))])
mad2 = np.array([stats.median_abs_deviation(r2[:r]) for r in range(len(r2))])
std2 = np.array([np.nanstd(r2[:r]) for r in range(len(r2))])


med3 = np.array([np.nanmedian(r3[:r]) for r in range(len(r3))])
mad3 = np.array([stats.median_abs_deviation(r3[:r]) for r in range(len(r3))])
std3 = np.array([np.nanstd(r3[:r]) for r in range(len(r3))])


med4 = np.array([np.nanmedian(r4[:r]) for r in range(len(r4))])
mad4 = np.array([stats.median_abs_deviation(r4[:r]) for r in range(len(r4))])
std4 = np.array([np.nanstd(r4[:r]) for r in range(len(r4))])


med5 = np.array([np.nanmedian(r5[:r]) for r in range(len(r5))])
mad5 = np.array([stats.median_abs_deviation(r5[:r]) for r in range(len(r5))])
std5 = np.array([np.nanstd(r5[:r]) for r in range(len(r5))])

# %%
# Plot
fig = plt.figure(figsize=(14,7))
ax1 = fig.add_subplot(1,1,1)
fontsize=16

ax1.scatter(range(len(r1)),r1,label=r"$\textrm{RMSE 1 comp}$")
ax1.plot(range(len(med1)),med1,label=r"$\textrm{Running Median 1 comp}$")
ax1.plot(range(len(mad1)),mad1,label=r"$\textrm{MAD 1 comp}$")
ax1.plot(range(len(std1)),std1,label=r"$\textrm{Std. Dev 1 comp}$")


# ax1.step(range(len(r2)),r2,label=r"$\textrm{RMSE 2 comp}$")
# ax1.step(range(len(mad2)),mad2,label=r"$\textrm{MAD 2 comp}$")
# ax1.step(range(len(std2)),std2,label=r"$\textrm{Std. Dev 2 comp}$")


# ax1.step(range(len(r3)),r3,label=r"$\textrm{RMSE 3 comp}$")
# ax1.step(range(len(mad3)),mad3,label=r"$\textrm{MAD 3 comp}$")
# ax1.step(range(len(std3)),std3,label=r"$\textrm{Std. Dev 3 comp}$")


# ax1.step(range(len(r4)),r4,label=r"$\textrm{RMSE 4 comp}$")
# ax1.step(range(len(mad4)),mad4,label=r"$\textrm{MAD 4 comp}$")
# ax1.step(range(len(std4)),std4,label=r"$\textrm{Std. Dev 4 comp}$")


# ax1.step(range(len(r5)),r5,label=r"$\textrm{RMSE 5 comp}$")
# ax1.step(range(len(mad5)),mad5,label=r"$\textrm{MAD 5 comp}$")
# ax1.step(range(len(std5)),std5,label=r"$\textrm{Std. Dev 5 comp}$")


ax1.set_xlabel(r"$\textrm{Iteration}$",fontsize=fontsize)
ax1.set_ylabel(r"$\textrm{RMSE}$",fontsize=fontsize)
ax1.set_title(r"$\textrm{RMSE Timeseries}$",fontsize=fontsize)
ax1.tick_params(axis='both', labelsize=fontsize)
ax1.legend(loc='best',fontsize=fontsize)
plt.tight_layout()

# %%
stats.median_abs_deviation([])
# Out:
# nan
