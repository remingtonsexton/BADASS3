# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True
plt.style.use('dark_background')
# plt.rcParams["font.family"] = "Times New Roman"
# import seaborn as sns
# sns.set_style("whitegrid")

from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))

from scipy import stats
# from astropy.table import Table
# tbdata = Table.read('datafile', format='fits')
# df = tbdata.to_pandas()

# df['class'] = df['class'].str.decode('utf-8') 

# Plot
# fig = plt.figure(figsize=(5,5))
# ax1 = fig.add_subplot(1,1,1)
# fontsize=16

# ax1.set_xlabel(r"",fontsize=fontsize)
# ax1.set_ylabel(r"",fontsize=fontsize)
# ax1.set_title(r"",fontsize=fontsize)
# ax1.tick_params(axis='both', labelsize=fontsize)
# plt.tight_layout()
# Out:
# <style>.container { width:85% !important; }</style>

# %%
# Only accepted=1 appended to rmse_arr
# r1 = [178.70242052846132, 51.66308157497612, 51.5432650779446, 48.48492965875337, 47.25424163328022, 46.09151697683946, 46.17518370680759, 46.451026524136076, 46.13099799217318, 46.27663488793769]
# r2 = [40.79929005800686, 40.125075977723284, 30.4899778281909, 30.841238567630505, 31.308526320204734]
# r3 = [50.61686885091948, 43.75012494935012, 31.651947759025358, 31.25891616145883, 31.399134130882373, 31.406543873365152, 31.356834520551267, 31.343928699575443, 31.36650031414168, 31.3738275765392, 15.614015716054748, 14.758019232159135, 15.718914151379854, 14.78743729177217, 15.615066260516945, 15.497713807600409, 15.625750551222719]
# r4 = [16.09441931419506, 14.72116886564385, 15.789810881518497, 15.70770858200272, 15.689592124120285]
# r5 = [15.730608595738259, 14.715621124871351]

# All calculated rmse
r1 =[202.9409965887688, 184.15650303869526, 201.2629196708184, 228.77707161574585, 267.3291078997665, 263.1444709794862, 223.90732565799303, 54.98671131402431, 59.18715289665894, 485.58592997773684, 54.84212537094504, 239.35297092775664, 218.80214575674165, 368.40991226253533, 304.2344141746119, 390.86511896976486, 115.22711439629083, 49.15680747608219, 49.56150562050594, 50.57865308371505, 48.923059496086054, 149.83529503115156, 55.35241267146096, 324.40724436846085, 48.583857377848865, 47.78250872723389, 229.24273499761097, 47.69569936329204, 47.20998379372586, 47.952272626392705, 402.5961906675946, 347.8408413057262, 199.55621197531377, 183.7303293007457, 279.26806312635983, 47.245929931435256, 451.47734939570927, 308.50666899422504, 324.879718020342, 48.323121040267, 53.00167427165536, 197.02310005977216, 326.0321428013168, 252.50536723834455, 411.8538540964525, 47.277017466194216, 51.195663211221834, 308.7495461580951, 47.21602476723912, 46.10253657473097, 517.4438015509259, 47.55238612526519, 399.03024361660476, 47.26421478795355, 47.219938447022216, 228.06810669859763, 154.43406829469023, 46.87018907618177, 47.47945161558523, 46.2998870103504, 47.287732894932326, 47.251669394480466, 349.39771140206983, 48.02167078323744, 47.26563460893124, 49.298353874390045, 190.85011117383894, 256.17741905956024, 218.90433175538953, 201.25116989172483, 47.654571528931676, 46.871428940730084, 328.53958300461625, 48.57923057444282, 48.61252317153779]
# r1 = np.array([48.45371956012031, 49.50291938669402, 50.106025678720236, 49.40082379283949, 47.3281746491777, 48.213199411111894, 47.3288979874864, 47.23657639984693, 47.261376813175936, 47.39113215222014, 45.72097389340604, 46.37402007121916, 46.362771253598765, 47.4816585321269, 46.37538026200445, 141.2163321901689, 51.65622288695457, 45.95435897197446, 50.78277111190779, 47.268061010002256, 47.508181078115264, 47.289699033596946, 46.40716494445545, 48.346787607427075, 46.02068283487504, 47.35275522257064, 46.15086473557555, 47.21637964283278, 48.4531074952215, 46.3867577604042, 47.690003115594045, 46.13150522940112, 46.21151903456417, 45.92375482091796, 46.62164192186706, 46.30445666727415, 50.563634082455266, 160.78514555226673])
# r2 = np.array([42.71759905161465, 38.3092207363773, 31.522287174951522, 31.367089166972242, 31.366023648085086, 31.636254052125096, 31.867124939912408, 31.09616484139089, 31.368834976658796, 31.442197495448784, 31.62201861388617, 31.254945756817328, 31.981469043576904, 31.549710421961457, 41.20405004552853, 40.34723702910952])
# r3 = np.array([16.484663802352173, 16.82979426615022, 15.426670488460536, 18.918368369427952, 15.033825788157895, 16.004236473803847, 14.4294215890631, 15.600740564146776, 16.972771573606387, 16.092869677372846, 17.724704463828747, 15.80885099214458, 17.239803184213127])
# r4 = np.array()
# r5 = np.array()

mad1 = np.array([stats.median_abs_deviation(r1[:r]) for r in range(len(r1))])
mad2 = np.array([stats.median_abs_deviation(r2[:r]) for r in range(len(r2))])
mad3 = np.array([stats.median_abs_deviation(r3[:r]) for r in range(len(r3))])
# mad4 = np.array([stats.median_abs_deviation(r4[:r]) for r in range(len(r4))])
# mad5 = np.array([stats.median_abs_deviation(r5[:r]) for r in range(len(r5))])

# %%
# Plot
fig = plt.figure(figsize=(14,7))
ax1 = fig.add_subplot(1,1,1)
fontsize=16

# ax1.step(range(len(r1)),r1,label=r"$\textrm{RMSE 1 comp}$")
# ax1.step(range(len(mad1)),mad1,label=r"$\textrm{MAD 1 comp}$")

# ax1.step(range(len(r2)),r2,label=r"$\textrm{RMSE 2 comp}$")
# ax1.step(range(len(mad2)),mad2,label=r"$\textrm{MAD 2 comp}$")

ax1.step(range(len(r3)),r3,label=r"$\textrm{RMSE 3 comp}$")
ax1.step(range(len(mad3)),mad3,label=r"$\textrm{MAD 3 comp}$")

# ax1.step(range(len(r4)),r4,label=r"$\textrm{RMSE 4 comp}$")
# ax1.step(range(len(mad4)),mad4,label=r"$\textrm{MAD 4 comp}$")

# ax1.step(range(len(r5)),r5,label=r"$\textrm{RMSE 5 comp}$")
# ax1.step(range(len(mad5)),mad5,label=r"$\textrm{MAD 5 comp}$")

ax1.set_xlabel(r"$\textrm{Iteration}$",fontsize=fontsize)
ax1.set_ylabel(r"$\textrm{RMSE}$",fontsize=fontsize)
ax1.set_title(r"$\textrm{RMSE Timeseries}$",fontsize=fontsize)
ax1.tick_params(axis='both', labelsize=fontsize)
ax1.legend(loc='best',fontsize=fontsize)
plt.tight_layout()

# %%
stats.median_abs_deviation([])
# Out:
# nan
