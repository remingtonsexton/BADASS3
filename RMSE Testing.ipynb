# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True
plt.style.use('dark_background')
# plt.rcParams["font.family"] = "Times New Roman"
# import seaborn as sns
# sns.set_style("whitegrid")

from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))

from scipy import stats
# from astropy.table import Table
# tbdata = Table.read('datafile', format='fits')
# df = tbdata.to_pandas()

# df['class'] = df['class'].str.decode('utf-8') 

# Plot
# fig = plt.figure(figsize=(5,5))
# ax1 = fig.add_subplot(1,1,1)
# fontsize=16

# ax1.set_xlabel(r"",fontsize=fontsize)
# ax1.set_ylabel(r"",fontsize=fontsize)
# ax1.set_title(r"",fontsize=fontsize)
# ax1.tick_params(axis='both', labelsize=fontsize)
# plt.tight_layout()
# Out:
# <style>.container { width:85% !important; }</style>

# %%
r1 = np.array([54.94390832886366, 50.31940965077956, 158.41115544991771, 50.25663587935236, 47.36729886317869, 47.24720861849877, 47.07693630949465, 50.12994958941356, 51.41445202364974, 46.10458043371785, 48.04329577769593, 47.23066688641723, 47.23217150318763, 49.855565384439366, 47.9923632789243, 46.627059675160446, 46.331504550245484, 47.26416362069344, 46.92465486081019, 47.26407609895194, 48.47006374022077, 49.90378763832603, 151.88878614804392, 46.011795784840835, 47.71403241905303, 46.159535372477876, 50.1155041723134, 163.6734019298093, 46.210555161530415, 47.19476262007293, 46.56302702891455, 47.08545735024539, 46.747638255820426, 47.068247173141046, 47.20166024726584, 97.97021358081184, 46.368191417221986])
med1 = np.array([np.nanmedian(r1[:r]) for r in range(len(r1))])
mad1 = np.array([stats.median_abs_deviation(r1[:r]) for r in range(len(r1))])
std1 = np.array([np.nanstd(r1[:r]) for r in range(len(r1))])

r2 = np.array([45.83892915764273, 42.93762560506542, 41.44253504774656, 45.72051084324095, 40.196420059438566, 41.49904888653419, 39.964458815176165, 32.60033344734542, 46.42354193427165, 31.35160972078647, 32.818956231800996, 33.00157514001672, 41.037075084823755, 31.417229493389463, 31.426381592997327, 31.368826378655083, 31.43613965007159, 31.352519524083405, 50.44621440274176, 32.859413948077204, 31.86908421621061, 31.34271160317163, 34.182556561521295, 31.999453169308627, 31.37750014556295, 30.319566556515273, 31.770368617716617, 31.381080387744888, 31.52908943272791, 33.81268699902735, 31.013549257298823, 31.302250190656533, 31.82952980225642])
med2 = np.array([np.nanmedian(r2[:r]) for r in range(len(r2))])
mad2 = np.array([stats.median_abs_deviation(r2[:r]) for r in range(len(r2))])
std2 = np.array([np.nanstd(r2[:r]) for r in range(len(r2))])

r3 = np.array([31.85983052387381, 32.29154403766166, 16.391591490823377, 17.290738894305107, 32.064923064497705, 16.308902492350107, 19.604153411284997, 16.689120489882967, 29.179776847918497, 34.54523924851788, 16.016995048719256, 29.08847678152211, 20.627229205217, 15.451190791094007, 17.485503345668413, 15.378927784665638, 15.400819766600199, 32.18058392012754, 15.477028396053086, 31.255123909940828, 32.08777286922006, 15.293698367443108, 31.41007825556141, 21.905582896345027, 16.236744715655085, 15.869331506529763, 28.203238040756986, 32.314847903169785, 15.378067256155926])
med3 = np.array([np.nanmedian(r3[:r]) for r in range(len(r3))])
mad3 = np.array([stats.median_abs_deviation(r3[:r]) for r in range(len(r3))])
std3 = np.array([np.nanstd(r3[:r]) for r in range(len(r3))])

r4 = np.array([15.810168324383218, 15.141503925785875, 14.367286173031829, 15.174494946061413, 13.508970877505424, 13.338187363030968, 14.6614194529465, 14.900861716124401, 13.894460834697929, 15.165297860428621, 15.394997302958108, 15.715591471733761, 15.230372661805642])
med4 = np.array([np.nanmedian(r4[:r]) for r in range(len(r4))])
mad4 = np.array([stats.median_abs_deviation(r4[:r]) for r in range(len(r4))])
std4 = np.array([np.nanstd(r4[:r]) for r in range(len(r4))])

# r5 = np.array()
# med5 = np.array([np.nanmedian(r5[:r]) for r in range(len(r5))])
# mad5 = np.array([stats.median_abs_deviation(r5[:r]) for r in range(len(r5))])
# std5 = np.array([np.nanstd(r5[:r]) for r in range(len(r5))])
# Out:
# /Users/remington.sexton/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/remington.sexton/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1670: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
# Plot
fig = plt.figure(figsize=(14,7))
ax1 = fig.add_subplot(1,1,1)
fontsize=16

# ax1.scatter(range(len(r1)),r1,label=r"$\textrm{RMSE 1 comp}$")
# ax1.plot(range(len(med1)),med1,label=r"$\textrm{Running Median 1 comp}$")
# ax1.plot(range(len(mad1)),med1+mad1,label=r"$\textrm{MAD 1 comp}$")
# ax1.plot(range(len(std1)),med1+std1,label=r"$\textrm{Std. Dev 1 comp}$")


# ax1.scatter(range(len(r2)),r2,label=r"$\textrm{RMSE 2 comp}$")
# ax1.plot(range(len(med2)),med2,label=r"$\textrm{Running Median 2 comp}$")
# ax1.plot(range(len(mad2)),med2+mad2,label=r"$\textrm{MAD 2 comp}$")
# ax1.plot(range(len(std2)),med2+std2,label=r"$\textrm{Std. Dev 2 comp}$")


# ax1.scatter(range(len(r3)),r3,label=r"$\textrm{RMSE 3 comp}$")
# ax1.plot(range(len(med3)),med3,label=r"$\textrm{Running Median 3 comp}$")
# ax1.plot(range(len(mad3)),med3+mad3,label=r"$\textrm{MAD 3 comp}$")
# ax1.plot(range(len(std3)),med3+std3,label=r"$\textrm{Std. Dev 3 comp}$")


ax1.scatter(range(len(r4)),r4,label=r"$\textrm{RMSE 4 comp}$")
ax1.plot(range(len(med4)),med4,label=r"$\textrm{Running Median 4 comp}$")
ax1.plot(range(len(mad4)),med4+mad4,label=r"$\textrm{MAD 4 comp}$")
ax1.plot(range(len(std4)),med4+std4,label=r"$\textrm{Std. Dev 4 comp}$")


# ax1.scatter(range(len(r5)),r5,label=r"$\textrm{RMSE 5 comp}$")
# ax1.plot(range(len(med5)),med5,label=r"$\textrm{Running Median 5 comp}$")
# ax1.plot(range(len(mad5)),med5+mad5,label=r"$\textrm{MAD 5 comp}$")
# ax1.plot(range(len(std5)),med5+std5,label=r"$\textrm{Std. Dev 5 comp}$")


ax1.set_xlabel(r"$\textrm{Iteration}$",fontsize=fontsize)
ax1.set_ylabel(r"$\textrm{RMSE}$",fontsize=fontsize)
ax1.set_title(r"$\textrm{RMSE Timeseries}$",fontsize=fontsize)
ax1.tick_params(axis='both', labelsize=fontsize)
ax1.legend(loc='best',fontsize=fontsize)
plt.tight_layout()

# %%
stats.median_abs_deviation([])
# Out:
# nan
