# %% [markdown]
# ## Bayesian AGN Decomposition Analysis for SDSS Spectra (BADASS)
# ### Basic Example: A Single Spectrum
#
# ####  Remington O. Sexton$^{1}$, Sara M. Doan$^{2}$, William Matzko$^{2}$ Michael A. Reefe$^{2}$,
# $^{1}$United States Naval Observatory, $^{2}$George Mason University

# %%
import glob
import time
import natsort
from IPython.display import clear_output
import os
import sys
import psutil
import pathlib
import natsort
# Import BADASS here
BADASS_DIR = pathlib.Path(os.getcwd()).resolve().parent
sys.path.insert(1,str(BADASS_DIR))
import badass as badass
import badass_check_input

from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ### BADASS Options
#
# Below are many of the options you can specify for BADASS.

# %%
################################## Fit Options #################################
# Fitting Parameters
fit_options={
"fit_reg"    : (4400,5500),# Fitting region; Note: Indo-US Library=(3460,9464)
"good_thresh": 0.0, # percentage of "good" pixels required in fig_reg for fit.
"mask_bad_pix": False, # mask pixels SDSS flagged as 'bad' (careful!)
"mask_emline" : False, # automatically mask lines for continuum fitting.
"mask_metal": False, # interpolate over metal absorption lines for high-z spectra
"fit_stat": "ML", # fit statistic; ML = Max. Like. , OLS = Ordinary Least Squares
"n_basinhop": 10, # Number of consecutive basinhopping thresholds before solution achieved
"test_lines": False, # Perform line/configuration testing for multiple components
"max_like_niter": 0, # number of maximum likelihood iterations
"output_pars": False, # only output free parameters of fit and stop code (diagnostic)
"cosmology": {"H0":70.0, "Om0": 0.30}, # Flat Lam-CDM Cosmology
}
################################################################################

########################### MCMC algorithm parameters ##########################
mcmc_options={
"mcmc_fit"    : False, # Perform robust fitting using emcee
"nwalkers"    : 100,  # Number of emcee walkers; min = 2 x N_parameters
"auto_stop"   : False, # Automatic stop using autocorrelation analysis
"conv_type"   : "all", # "median", "mean", "all", or (tuple) of parameters
"min_samp"    : 1000,  # min number of iterations for sampling post-convergence
"ncor_times"  : 10.0,  # number of autocorrelation times for convergence
"autocorr_tol": 10.0,  # percent tolerance between checking autocorr. times
"write_iter"  : 100,   # write/check autocorrelation times interval
"write_thresh": 100,   # iteration to start writing/checking parameters
"burn_in"     : 1500, # burn-in if max_iter is reached
"min_iter"    : 1000, # min number of iterations before stopping
"max_iter"    : 2500, # max number of MCMC iterations
}
################################################################################

############################ Fit component op dtions #############################
comp_options={
"fit_opt_feii"     : True, # optical FeII
"fit_uv_iron"      : False, # UV Iron 
"fit_balmer"       : False, # Balmer continuum (<4000 A)
"fit_losvd"        : False, # stellar LOSVD
"fit_host"         : True, # host template
"fit_power"        : True, # AGN power-law
"fit_poly"         : True, # Add polynomial continuum component
"fit_narrow"       : True, # narrow lines
"fit_broad"        : True, # broad lines
"fit_absorp"       : False, # absorption lines
"tie_line_disp"    : False, # tie line widths (dispersions)
"tie_line_voff"    : False, # tie line velocity offsets
}

# Line options for each narrow, broad, and absorption.
narrow_options = {
#     "amp_plim": (0,1), # line amplitude parameter limits; default (0,)
    "disp_plim": (0,500), # line dispersion parameter limits; default (0,)
    "voff_plim": (-500,500), # line velocity offset parameter limits; default (0,)
    "line_profile": "gaussian", # line profile shape*
    "n_moments": 4, # number of higher order Gauss-Hermite moments (if line profile is gauss-hermite, laplace, or uniform)
}

broad_options ={
#     "amp_plim": (0,40), # line amplitude parameter limits; default (0,)
    "disp_plim": (500,3000), # line dispersion parameter limits; default (0,)
    "voff_plim": (-1000,1000), # line velocity offset parameter limits; default (0,)
    "line_profile": "gaussian", # line profile shape*
    "n_moments": 4, # number of higher order Gauss-Hermite moments (if line profile is gauss-hermite, laplace, or uniform)
}

absorp_options = {
#     "amp_plim": (-1,0), # line amplitude parameter limits; default (0,)
#     "disp_plim": (0,10), # line dispersion parameter limits; default (0,)
#     "voff_plim": (-2500,2500), # line velocity offset parameter limits; default (0,)
    "line_profile": "gaussian", # line profile shape*
    "n_moments": 4, # number of higher order Gauss-Hermite moments (if line profile is gauss-hermite, laplace, or uniform)        
}

# Choices for line profile shape include 'gaussian', 'lorentzian', 'voigt',
# 'gauss-hermite', 'laplace', and 'uniform'
################################################################################

########################### Emission Lines & Options ###########################
# If not specified, defaults to SDSS-QSO Emission Lines (http://classic.sdss.org/dr6/algorithms/linestable.html)
################################################################################
# User lines overrides the default line list with a user-input line list!
user_lines = {
    "NA_H_BETA"      :{"center":4862.691,"amp":"free","disp":"NA_OIII_5007_DISP","voff":"free","line_type":"na","label":r"H$\beta$","ncomp":1,},
    "NA_H_BETA_2"    :{"center":4862.691,"amp":"NA_H_BETA_AMP*NA_OIII_5007_2_AMP/NA_OIII_5007_AMP","disp":"NA_OIII_5007_2_DISP","voff":"NA_OIII_5007_2_VOFF","line_type":"na","ncomp":2,"parent":"NA_H_BETA"},

    "NA_OIII_4960"   :{"center":4960.295,"amp":"(NA_OIII_5007_AMP/2.98)","disp":"NA_OIII_5007_DISP","voff":"NA_OIII_5007_VOFF","line_type":"na","label":r"[O III]","ncomp":1,},
    "NA_OIII_4960_2" :{"center":4960.295,"amp":"(NA_OIII_5007_2_AMP/2.98)","disp":"NA_OIII_5007_2_DISP","voff":"NA_OIII_5007_2_VOFF","line_type":"na","ncomp":2,"parent":"NA_OIII_4960"},

    "NA_OIII_5007"   :{"center":5008.240,"amp":"free","disp":"free","voff":"free","line_type":"na","label":r"[O III]","ncomp":1,},
    "NA_OIII_5007_2" :{"center":5008.240,"amp":"free","disp":"free","voff":"free","line_type":"na","ncomp":2,"parent":"NA_OIII_5007"},

    "BR_H_BETA"      :{"center":4862.691,"amp":"free","disp":"free","voff":"free","line_type":"br","ncomp":1,},
}
user_constraints = [
    ("NA_OIII_5007_AMP","NA_OIII_5007_2_AMP"),
    ("NA_OIII_5007_2_DISP","NA_OIII_5007_DISP"),
]
# User defined masked regions (list of tuples)
user_mask = [
#     (4840,5015),
]

# Combined lines; define a composite line and calculate
# its combined parameters.  These are automatically
# generated for lines with multiple components (parent+child lines)
combined_lines = {
    "H_BETA_COMP"   :["NA_H_BETA","BR_H_BETA"],
}
########################## LOSVD Fitting & Options #############################
# For direct fitting of the stellar kinematics (stellar LOSVD), one can 
# specify a stellar template library (Indo-US or Vazdekis 2010).
# One can also hold velocity or dispersion constant to avoid template
# convolution during the fitting process.
################################################################################

losvd_options = {
"library"   : "IndoUS", # Options: IndoUS, Vazdekis2010
"vel_const" :  {"bool":False, "val":0.0},
"disp_const":  {"bool":False, "val":250.0},
}

########################## SSP Host Galaxy Template & Options ##################
# The default is zero velocity, 100 km/s dispersion 10 Gyr template from 
# the eMILES stellar library. 
################################################################################

host_options = {
"age"       : [1.0,5.0,10.0], # Gyr; [0.09 Gyr - 14 Gyr] 
"vel_const" : {"bool":False, "val":0.0},
"disp_const": {"bool":False, "val":150.0}
}

########################### AGN power-law continuum & Options ##################
# The default is a simple power law.
################################################################################

power_options = {
"type" : "simple" # alternatively, "broken" for smoothly-broken power-law
}

########################### Polynomial Continuum Options #######################
# Options for an additive legendre polynomial or multiplicative polynomial to be 
# included in the fit.  NOTE: these polynomials do not include the zeroth-order
# (constant) term to avoid degeneracies with other continuum components.
################################################################################

poly_options = {
"apoly" : {"bool": True , "order": 3}, # Legendre additive polynomial 
"mpoly" : {"bool": False, "order": 3}, # Legendre multiplicative polynomial 
}

############################### Optical FeII options ###############################
# Below are options for fitting optical FeII.  For most objects, you don't need to 
# perform detailed fitting on FeII (only fit for amplitudes) use the 
# Veron-Cetty 2004 template ('VC04') (2-6 free parameters)
# However in NLS1 objects, FeII is much stronger, and sometimes more detailed 
# fitting is necessary, use the Kovacevic 2010 template 
# ('K10'; 7 free parameters).

# The options are:
# template   : VC04 (Veron-Cetty 2004) or K10 (Kovacevic 2010)
# amp_const  : constant amplitude (default False)
# disp_const : constant dispersion (default True)
# voff_const : constant velocity offset (default True)
# temp_const : constant temp ('K10' only)

opt_feii_options={
"opt_template"  :{"type":"VC04"}, 
"opt_amp_const" :{"bool":False, "br_opt_feii_val":1.0   , "na_opt_feii_val":1.0},
"opt_disp_const":{"bool":False, "br_opt_feii_val":3000.0, "na_opt_feii_val":500.0},
"opt_voff_const":{"bool":False, "br_opt_feii_val":0.0   , "na_opt_feii_val":0.0},
}
# or
# opt_feii_options={
# "opt_template"  :{"type":"K10"},
# "opt_amp_const" :{"bool":False,"f_feii_val":1.0,"s_feii_val":1.0,"g_feii_val":1.0,"z_feii_val":1.0},
# "opt_disp_const":{"bool":False,"opt_feii_val":1500.0},
# "opt_voff_const":{"bool":False,"opt_feii_val":0.0},
# "opt_temp_const":{"bool":True,"opt_feii_val":10000.0},
# }
################################################################################

############################### UV Iron options ################################
uv_iron_options={
"uv_amp_const"  :{"bool":False, "uv_iron_val":1.0},
"uv_disp_const" :{"bool":False, "uv_iron_val":3000.0},
"uv_voff_const" :{"bool":True,  "uv_iron_val":0.0},
}
################################################################################

########################### Balmer Continuum options ###########################
# For most purposes, only the ratio R, and the overall amplitude are free paramters
# but if you want to go crazy, you can fit everything.
balmer_options = {
"R_const"          :{"bool":True,  "R_val":1.0}, # ratio between balmer continuum and higher-order balmer lines
"balmer_amp_const" :{"bool":False, "balmer_amp_val":1.0}, # amplitude of overall balmer model (continuum + higher-order lines)
"balmer_disp_const":{"bool":True,  "balmer_disp_val":5000.0}, # broadening of higher-order Balmer lines
"balmer_voff_const":{"bool":True,  "balmer_voff_val":0.0}, # velocity offset of higher-order Balmer lines
"Teff_const"       :{"bool":True,  "Teff_val":15000.0}, # effective temperature
"tau_const"        :{"bool":True,  "tau_val":1.0}, # optical depth
}

################################################################################

############################### Plotting options ###############################
plot_options={
"plot_param_hist"    : False,# Plot MCMC histograms and chains for each parameter
"plot_HTML"          : True,# make interactive plotly HTML best-fit plot
}
################################################################################

################################ Output options ################################
output_options={
"res_correct"  : True,  # Correct final emission line widths for the intrinsic 
                        # resolution of the spectrum; 
                        # WARNING: make sure your resolution is well-determined!
"write_chain"  : False, # Write MCMC chains for all paramters, fluxes, and
                         # luminosities to a FITS table We set this to false 
                         # because MCMC_chains.FITS file can become very large, 
                         # especially  if you are running multiple objects.  
                         # You only need this if you want to reconstruct full chains 
                         # and histograms. 
"write_options": False,  # output restart file
"verbose"      : True,   # print out all steps of fitting process
}
################################################################################

# %% [markdown]
# ### Run BADASS on a single spectrum
#
# The following is shows how to fit single SDSS spectra.

# %% [markdown]
# #### Directory Structure

# %%
nobj = 2 # Object in the spec_dir list
########################## Directory Structure #################################
spec_dir = BADASS_DIR.joinpath("example_spectra") # folder with spectra in it
# print(spec_dir)
# Get full list of spectrum folders; these will be the working directories
spec_loc = natsort.natsorted( glob.glob(str(spec_dir.joinpath("*"))) )[nobj]

################################################################################
print(spec_loc)
# Out:
# /Users/remington.sexton/BADASS3/example_spectra/2-test

# %% [markdown]
# #### Choose Spectrum

# %%
file = glob.glob(str(pathlib.Path(spec_loc).joinpath('*.fits')))[0] # Get name of FITS spectra file
print(file)
# Out:
# /Users/remington.sexton/BADASS3/example_spectra/2-test/spec-2756-54508-0579.fits

# %% [markdown]
# #### Run IRSA Dust Query
# To correct for Galactic extinction.  This only needs to be done once so that the data is stored locally.

# %%
badass_check_input.fetch_IRSA_dust(spec_loc)
# Out:
#  Fetching IRSA Dust for spectra...
#
#  Done fetching IRSA dust!

# %% [markdown]
# #### Run

# %%
# Call the main function in BADASS
badass.run_BADASS(pathlib.Path(file),
#                   options_file = "BADASS_options",
#                   restart_file         = restart_file,
                  fit_options          = fit_options,
                  mcmc_options         = mcmc_options,
                  comp_options         = comp_options,
                  # New line options
                  narrow_options       = narrow_options,
                  broad_options        = broad_options,
                  absorp_options       = absorp_options,
                  #
                  user_lines           = user_lines,       # User-lines
                  user_constraints     = user_constraints, # User-constraints
                  user_mask            = user_mask,        # User-mask
                  combined_lines       = combined_lines,
                  losvd_options        = losvd_options,
                  host_options         = host_options,
                  power_options        = power_options,
                  poly_options         = poly_options,
                  opt_feii_options     = opt_feii_options,
                  uv_iron_options      = uv_iron_options,
                  balmer_options       = balmer_options,
                  plot_options         = plot_options,
                  output_options       = output_options,
                  sdss_spec            = True,
                 )
    #
# Out:
# Start process memory: 0.27192115
#  Folder has not been created.  Creating MCMC_output folder...
#
#  > Starting fit for 2-test
#
#  Input fitting region exceeds available wavelength range.  BADASS will adjust your fitting range automatically...
# 		- Input fitting range: (4400, 5500)
# 		- Available wavelength range: (2218, 5354)
# 		- New fitting region is (4400, 5355).
#
#
#
# -----------------------------------------------------------
#  file:                        spec-2756-54508-0579.fits
#  SDSS redshift:               0.71967
#  fitting region:              (4400,5355) [A]
#  velocity scale:              69.15 [km/s/pixel]
#  Galactic E(B-V):             0.032
#  Flux Normalization:          1.0e-17
# -----------------------------------------------------------
#
#  Initializing parameters...
# ----------------------------------------------------------------------------------------------------
# 	- Fitting a SSP host-galaxy template.
# 	- Fitting additive legendre polynomial component.
# 	- Fitting Simple AGN power-law continuum.
# 	- Fitting broad and narrow optical FeII using Veron-Cetty et al. (2004) optical FeII templates
# 	 		* varying optical FeII amplitudes
# 	 		* varying optical FeII dispersion.
# 	 		* varying optical FeII voff
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Line List:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
# BR_H_BETA
#                               amp                           free
#                               center                        4862.691
#                               center_pix                    435.21099039301293
#                               disp                          free
#                               disp_res_ang                  0.7266926172967304
#                               disp_res_kms                  44.80172932021387
#                               line_profile                  gaussian
#                               line_type                     br
#                               ncomp                         1
#                               voff                          free
# NA_H_BETA
#                               amp                           free
#                               center                        4862.691
#                               center_pix                    435.21099039301293
#                               disp                          NA_OIII_5007_DISP
#                               disp_res_ang                  0.7266926172967304
#                               disp_res_kms                  44.80172932021387
#                               label                         H$\beta$
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          free
# NA_H_BETA_2
#                               amp                           NA_H_BETA_AMP*NA_OIII_5007_2_AMP/NA_OIII_5007_AMP
#                               center                        4862.691
#                               center_pix                    435.21099039301293
#                               disp                          NA_OIII_5007_2_DISP
#                               disp_res_ang                  0.7266926172967304
#                               disp_res_kms                  44.80172932021387
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         2
#                               parent                        NA_H_BETA
#                               voff                          NA_OIII_5007_2_VOFF
# NA_OIII_4960
#                               amp                           (NA_OIII_5007_AMP/2.98)
#                               center                        4960.295
#                               center_pix                    521.5197602739727
#                               disp                          NA_OIII_5007_DISP
#                               disp_res_ang                  0.7349264587941482
#                               disp_res_kms                  44.41780368529158
#                               label                         [O III]
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          NA_OIII_5007_VOFF
# NA_OIII_4960_2
#                               amp                           (NA_OIII_5007_2_AMP/2.98)
#                               center                        4960.295
#                               center_pix                    521.5197602739727
#                               disp                          NA_OIII_5007_2_DISP
#                               disp_res_ang                  0.7349264587941482
#                               disp_res_kms                  44.41780368529158
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         2
#                               parent                        NA_OIII_4960
#                               voff                          NA_OIII_5007_2_VOFF
# NA_OIII_5007
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    563.2959830508472
#                               disp                          free
#                               disp_res_ang                  0.7407543175269816
#                               disp_res_kms                  44.341436837197556
#                               label                         [O III]
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          free
# NA_OIII_5007_2
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    563.2959830508472
#                               disp                          free
#                               disp_res_ang                  0.7407543175269816
#                               disp_res_kms                  44.341436837197556
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         2
#                               parent                        NA_OIII_5007
#                               voff                          free
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Number of Free Line Parameters: 11
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  All Free Parameters:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
# APOLY_COEFF_1
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_2
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_3
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# BR_H_BETA_AMP
#                               init                          126.06889615498525
#                               plim                          (0.0, 812.7198363113289)
# BR_H_BETA_DISP
#                               init                          500.0
#                               plim                          (500, 3000)
# BR_H_BETA_VOFF
#                               init                          54.39160208657732
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# BR_OPT_FEII_AMP
#                               init                          5.826352429250029
#                               plim                          (0, 609.5398772334967)
# BR_OPT_FEII_DISP
#                               init                          500.0
#                               plim                          (500.0, 5000.0)
# BR_OPT_FEII_VOFF
#                               init                          0.0
#                               plim                          (-500.0, 500.0)
# HOST_TEMP_DISP
#                               init                          100.0
#                               plim                          (0.001, 500.0)
# HOST_TEMP_VEL
#                               init                          0.0
#                               plim                          (-500.0, 500)
# NA_H_BETA_AMP
#                               init                          63.03444807749263
#                               plim                          (0.0, 812.7198363113289)
# NA_H_BETA_VOFF
#                               init                          54.39160208657732
#                               plim                          (-500, 500)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_2_AMP
#                               init                          197.62656733292908
#                               plim                          (0.0, 812.7198363113289)
# NA_OIII_5007_2_DISP
#                               init                          50.0
#                               plim                          (0, 500)
# NA_OIII_5007_2_VOFF
#                               init                          -89.51267826969064
#                               plim                          (-500, 500)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_AMP
#                               init                          197.62656733292908
#                               plim                          (0.0, 812.7198363113289)
# NA_OIII_5007_DISP
#                               init                          50.0
#                               plim                          (0, 500)
# NA_OIII_5007_VOFF
#                               init                          -89.51267826969064
#                               plim                          (-500, 500)
#                               prior                         {'type': 'gaussian'}
# NA_OPT_FEII_AMP
#                               init                          5.826352429250029
#                               plim                          (0, 609.5398772334967)
# NA_OPT_FEII_DISP
#                               init                          10.0
#                               plim                          (0.1, 500.0)
# NA_OPT_FEII_VOFF
#                               init                          0.0
#                               plim                          (-500.0, 500.0)
# POWER_AMP
#                               init                          29.131762146250143
#                               plim                          (0, 609.5398772334967)
# POWER_SLOPE
#                               init                          -1.0
#                               plim                          (-6.0, 6.0)
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Total number of free parameters: 24
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Soft Constraints:
#
#               NA_OIII_5007_AMP > NA_OIII_5007_2_AMP
#            NA_OIII_5007_2_DISP > NA_OIII_5007_DISP
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Required Maximum Likelihood RMSE threshold: 0.5353
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 10
# warning: basinhopping: local minimization failure
# basinhopping step 0: f 34877.4
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.4284
#  Current RMSE: 0.4284
#  Accepted count: 1
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 1: f 34877.4 trial_f inf accepted 0  lowest_f 34877.4
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.4284
#  Current RMSE: 0.4605
#  Accepted count: 1
#  Basinhop count: 1
#
#
# basinhopping step 2: f 5655.85 trial_f 5655.85 accepted 1  lowest_f 5655.85
# found new global minimum on step 2 with function value 5655.85
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0518
#  Current RMSE: 0.0518
#  Accepted count: 2
#  Basinhop count: 0
#
#
# basinhopping step 3: f 5652.21 trial_f 5652.21 accepted 1  lowest_f 5652.21
# found new global minimum on step 3 with function value 5652.21
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0517
#  Current RMSE: 0.0517
#  Accepted count: 3
#  Basinhop count: 0
#
#
# basinhopping step 4: f 5626.45 trial_f 5626.45 accepted 1  lowest_f 5626.45
# found new global minimum on step 4 with function value 5626.45
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0512
#  Current RMSE: 0.0512
#  Accepted count: 4
#  Basinhop count: 0
#
#
# basinhopping step 5: f 5628.55 trial_f 5628.55 accepted 1  lowest_f 5626.45
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0512
#  Current RMSE: 0.0512
#  Accepted count: 5
#  Basinhop count: 1
#
#
# basinhopping step 6: f 5604.85 trial_f 5604.85 accepted 1  lowest_f 5604.85
# found new global minimum on step 6 with function value 5604.85
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.0507
#  Accepted count: 6
#  Basinhop count: 0
#
#
# basinhopping step 7: f 5604.85 trial_f 5614.03 accepted 0  lowest_f 5604.85
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.0509
#  Accepted count: 6
#  Basinhop count: 1
#
#
# basinhopping step 8: f 5604.85 trial_f 5615.98 accepted 0  lowest_f 5604.85
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.0509
#  Accepted count: 6
#  Basinhop count: 2
#
#
# basinhopping step 9: f 5604.85 trial_f 5608.09 accepted 0  lowest_f 5604.85
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.0508
#  Accepted count: 6
#  Basinhop count: 3
#
#
# basinhopping step 10: f 5596.21 trial_f 5596.21 accepted 1  lowest_f 5596.21
# found new global minimum on step 10 with function value 5596.21
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0505
#  Current RMSE: 0.0505
#  Accepted count: 7
#  Basinhop count: 0
#
#
# basinhopping step 11: f 5596.21 trial_f 5606.15 accepted 0  lowest_f 5596.21
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0505
#  Current RMSE: 0.0507
#  Accepted count: 7
#  Basinhop count: 1
#
#
# basinhopping step 12: f 5594.62 trial_f 5594.62 accepted 1  lowest_f 5594.62
# found new global minimum on step 12 with function value 5594.62
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0505
#  Current RMSE: 0.0505
#  Accepted count: 8
#  Basinhop count: 0
#
#
# basinhopping step 13: f 5592.91 trial_f 5592.91 accepted 1  lowest_f 5592.91
# found new global minimum on step 13 with function value 5592.91
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0505
#  Current RMSE: 0.0505
#  Accepted count: 9
#  Basinhop count: 0
#
#
# basinhopping step 14: f 5592.91 trial_f 5610.6 accepted 0  lowest_f 5592.91
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0505
#  Current RMSE: 0.0509
#  Accepted count: 9
#  Basinhop count: 1
#
#
# basinhopping step 15: f 5589.16 trial_f 5589.16 accepted 1  lowest_f 5589.16
# found new global minimum on step 15 with function value 5589.16
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0504
#  Current RMSE: 0.0504
#  Accepted count: 10
#  Basinhop count: 0
#
#
# basinhopping step 16: f 5588.08 trial_f 5588.08 accepted 1  lowest_f 5588.08
# found new global minimum on step 16 with function value 5588.08
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0504
#  Current RMSE: 0.0504
#  Accepted count: 11
#  Basinhop count: 0
#
#
# basinhopping step 17: f 5588.08 trial_f 6546.35 accepted 0  lowest_f 5588.08
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0504
#  Current RMSE: 0.0599
#  Accepted count: 11
#  Basinhop count: 1
#
#
# basinhopping step 18: f 5588.08 trial_f 5591.45 accepted 0  lowest_f 5588.08
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0504
#  Current RMSE: 0.0504
#  Accepted count: 11
#  Basinhop count: 2
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 19: f 5590.89 trial_f 5590.89 accepted 1  lowest_f 5588.08
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0504
#  Current RMSE: 0.0504
#  Accepted count: 12
#  Basinhop count: 3
#
#
# basinhopping step 20: f 5590.57 trial_f 5590.57 accepted 1  lowest_f 5588.08
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0504
#  Current RMSE: 0.0504
#  Accepted count: 13
#  Basinhop count: 4
#
#
# basinhopping step 21: f 5590.54 trial_f 5590.54 accepted 1  lowest_f 5588.08
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0504
#  Current RMSE: 0.0504
#  Accepted count: 14
#  Basinhop count: 5
#
#
# basinhopping step 22: f 5590.54 trial_f 5600.26 accepted 0  lowest_f 5588.08
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0504
#  Current RMSE: 0.0506
#  Accepted count: 14
#  Basinhop count: 6
#
#
# basinhopping step 23: f 5586.63 trial_f 5586.63 accepted 1  lowest_f 5586.63
# found new global minimum on step 23 with function value 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0503
#  Current RMSE: 0.0503
#  Accepted count: 15
#  Basinhop count: 0
#
#
# basinhopping step 24: f 5586.63 trial_f 5592.25 accepted 0  lowest_f 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0503
#  Current RMSE: 0.0505
#  Accepted count: 15
#  Basinhop count: 1
#
#
# basinhopping step 25: f 5586.63 trial_f 5598.77 accepted 0  lowest_f 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0499
#  Current RMSE: 0.0499
#  Accepted count: 15
#  Basinhop count: 2
#
#
# basinhopping step 26: f 5586.63 trial_f 5598.51 accepted 0  lowest_f 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0499
#  Current RMSE: 0.0506
#  Accepted count: 15
#  Basinhop count: 3
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 27: f 5586.63 trial_f 7255.99 accepted 0  lowest_f 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0499
#  Current RMSE: 0.0683
#  Accepted count: 15
#  Basinhop count: 4
#
#
# basinhopping step 28: f 5586.63 trial_f 6759.25 accepted 0  lowest_f 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0499
#  Current RMSE: 0.0624
#  Accepted count: 15
#  Basinhop count: 5
#
#
# basinhopping step 29: f 5586.63 trial_f 5594.41 accepted 0  lowest_f 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0499
#  Current RMSE: 0.0505
#  Accepted count: 15
#  Basinhop count: 6
#
#
# basinhopping step 30: f 5592.44 trial_f 5592.44 accepted 1  lowest_f 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0499
#  Current RMSE: 0.0505
#  Accepted count: 16
#  Basinhop count: 7
#
#
# basinhopping step 31: f 5592.44 trial_f 5608.68 accepted 0  lowest_f 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0499
#  Current RMSE: 0.0508
#  Accepted count: 16
#  Basinhop count: 8
#
#
# basinhopping step 32: f 5590.27 trial_f 5590.27 accepted 1  lowest_f 5586.63
#  Fit Status: False
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0499
#  Current RMSE: 0.0504
#  Accepted count: 17
#  Basinhop count: 9
#
#
# basinhopping step 33: f 5589.83 trial_f 5589.83 accepted 1  lowest_f 5586.63
#  Fit Status: True
#  Force threshold: 0.5353
#  Lowest RMSE: 0.0499
#  Current RMSE: 0.0503
#  Accepted count: 18
#  Basinhop count: 10
#
#
#
#  Maximum Likelihood Best-fit Parameters:
# --------------------------------------------------------------------------------------
#
# Parameter                     Best-fit Value                +/- 1-sigma                   Flag
# --------------------------------------------------------------------------------------
# APOLY_COEFF_1                 -38.670000                    0.000000                      1.0
# APOLY_COEFF_2                 -8.112153                     0.000000                      1.0
# APOLY_COEFF_3                 -1.741486                     0.000000                      1.0
# BR_H_BETA_AMP                 39.446554                     0.000000                      1.0
# BR_H_BETA_DISP                2234.928888                   0.000000                      1.0
# BR_H_BETA_DISP_CORR           2234.479792                   0.000000                      1.0
# BR_H_BETA_DISP_RES            44.801729                     nan                           nan
# BR_H_BETA_EW                  64.931774                     0.000000                      0.0
# BR_H_BETA_FLUX                -13.445899                    0.000000                      0.0
# BR_H_BETA_FWHM                76.115258                     0.000000                      0.0
# BR_H_BETA_FWHM_CORR           0.000000                      0.000000                      0.0
# BR_H_BETA_LUM                 43.920320                     0.000000                      0.0
# BR_H_BETA_NPIX                163.000000                    0.000000                      0.0
# BR_H_BETA_SNR                 23.504983                     0.000000                      0.0
# BR_H_BETA_VOFF                273.455581                    0.000000                      1.0
# BR_H_BETA_W80                 5856.986720                   0.000000                      0.0
# BR_OPT_FEII_AMP               0.000000                      0.000000                      1.0
# BR_OPT_FEII_DISP              511.851529                    0.000000                      1.0
# BR_OPT_FEII_TEMPLATE_EW       0.000000                      0.000000                      1.0
# BR_OPT_FEII_TEMPLATE_FLUX     -30.718604                    0.000000                      1.0
# BR_OPT_FEII_TEMPLATE_LUM      26.647615                     0.000000                      1.0
# BR_OPT_FEII_VOFF              1.172226                      0.000000                      1.0
# HOST_TEMP_DISP                491.513155                    0.000000                      1.0
# HOST_TEMP_VEL                 -493.816560                   0.000000                      1.0
# H_BETA_COMP_DISP              2165.755011                   0.000000                      0.0
# H_BETA_COMP_DISP_CORR         2165.291568                   0.000000                      0.0
# H_BETA_COMP_DISP_RES          44.801729                     nan                           nan
# H_BETA_COMP_EW                69.235798                     0.000000                      1.0
# H_BETA_COMP_FLUX              -13.418079                    0.000000                      1.0
# H_BETA_COMP_FWHM              34.698712                     0.000000                      0.0
# H_BETA_COMP_FWHM_CORR         0.000000                      0.000000                      0.0
# H_BETA_COMP_LUM               43.948139                     0.000000                      1.0
# H_BETA_COMP_NPIX              163.000000                    0.000000                      0.0
# H_BETA_COMP_SNR               37.423441                     0.000000                      0.0
# H_BETA_COMP_VOFF              254.608429                    0.000000                      0.0
# H_BETA_COMP_W80               5694.793001                   0.000000                      0.0
# LOG_LIKE                      5586.633151                   0.000000                      0.0
# L_CONT_AGN_5100               45.758790                     0.000000                      1.0
# L_CONT_HOST_5100              0.000000                      0.000000                      1.0
# L_CONT_TOT_5100               45.778239                     0.000000                      1.0
# NA_H_BETA_2_AMP               5.126243                      0.000000                      3.0
# NA_H_BETA_2_DISP              497.484650                    0.000000                      1.0
# NA_H_BETA_2_DISP_CORR         495.463200                    0.000000                      1.0
# NA_H_BETA_2_DISP_RES          44.801729                     nan                           nan
# NA_H_BETA_2_EW                1.879500                      0.000000                      0.0
# NA_H_BETA_2_FLUX              -14.985026                    0.000000                      0.0
# NA_H_BETA_2_FWHM              16.954005                     0.000000                      0.0
# NA_H_BETA_2_FWHM_CORR         0.000000                      0.000000                      0.0
# NA_H_BETA_2_LUM               42.381192                     0.000000                      0.0
# NA_H_BETA_2_NPIX              16.000000                     0.000000                      0.0
# NA_H_BETA_2_SNR               3.054580                      0.000000                      0.0
# NA_H_BETA_2_VOFF              -16.814625                    0.000000                      1.0
# NA_H_BETA_2_W80               1302.912648                   0.000000                      0.0
# NA_H_BETA_AMP                 29.272255                     0.000000                      1.0
# NA_H_BETA_COMB_DISP           317.736165                    0.000000                      0.0
# NA_H_BETA_COMB_DISP_CORR      314.561720                    0.000000                      0.0
# NA_H_BETA_COMB_DISP_RES       44.801729                     nan                           nan
# NA_H_BETA_COMB_EW             6.183524                      0.000000                      1.0
# NA_H_BETA_COMB_FLUX           -14.467938                    0.000000                      1.0
# NA_H_BETA_COMB_FWHM           7.486281                      0.000000                      0.0
# NA_H_BETA_COMB_FWHM_CORR      0.000000                      0.000000                      0.0
# NA_H_BETA_COMB_LUM            42.898280                     0.000000                      1.0
# NA_H_BETA_COMB_NPIX           20.000000                     0.000000                      0.0
# NA_H_BETA_COMB_SNR            14.900516                     0.000000                      0.0
# NA_H_BETA_COMB_VOFF           -25.982386                    0.000000                      0.0
# NA_H_BETA_COMB_W80            727.797180                    0.000000                      0.0
# NA_H_BETA_DISP                199.450230                    0.000000                      1.0
# NA_H_BETA_DISP_CORR           194.353285                    0.000000                      1.0
# NA_H_BETA_DISP_RES            44.801729                     nan                           nan
# NA_H_BETA_EW                  4.304024                      0.000000                      0.0
# NA_H_BETA_FLUX                -14.625346                    0.000000                      0.0
# NA_H_BETA_FWHM                6.830068                      0.000000                      0.0
# NA_H_BETA_FWHM_CORR           0.000000                      0.000000                      0.0
# NA_H_BETA_LUM                 42.740873                     0.000000                      0.0
# NA_H_BETA_NPIX                13.000000                     0.000000                      0.0
# NA_H_BETA_SNR                 17.390759                     0.000000                      0.0
# NA_H_BETA_VOFF                -29.986900                    0.000000                      1.0
# NA_H_BETA_W80                 525.218537                    0.000000                      0.0
# NA_OIII_4960_2_AMP            17.030638                     0.000000                      1.0
# NA_OIII_4960_2_DISP           497.484650                    0.000000                      1.0
# NA_OIII_4960_2_DISP_CORR      495.497766                    0.000000                      1.0
# NA_OIII_4960_2_DISP_RES       44.417804                     nan                           nan
# NA_OIII_4960_2_EW             6.525292                      0.000000                      0.0
# NA_OIII_4960_2_FLUX           -14.454966                    0.000000                      0.0
# NA_OIII_4960_2_FWHM           16.959361                     0.000000                      0.0
# NA_OIII_4960_2_FWHM_CORR      0.000000                      0.000000                      0.0
# NA_OIII_4960_2_LUM            42.911253                     0.000000                      0.0
# NA_OIII_4960_2_NPIX           32.000000                     0.000000                      0.0
# NA_OIII_4960_2_SNR            10.140669                     0.000000                      0.0
# NA_OIII_4960_2_VOFF           -16.814625                    0.000000                      1.0
# NA_OIII_4960_2_W80            1304.222157                   0.000000                      0.0
# NA_OIII_4960_AMP              97.249608                     0.000000                      1.0
# NA_OIII_4960_COMB_DISP        317.773737                    0.000000                      0.0
# NA_OIII_4960_COMB_DISP_CORR   314.654106                    0.000000                      0.0
# NA_OIII_4960_COMB_DISP_RES    44.417804                     nan                           nan
# NA_OIII_4960_COMB_EW          21.459658                     0.000000                      1.0
# NA_OIII_4960_COMB_FLUX        -13.937872                    0.000000                      1.0
# NA_OIII_4960_COMB_FWHM        7.478465                      0.000000                      0.0
# NA_OIII_4960_COMB_FWHM_CORR   0.000000                      0.000000                      0.0
# NA_OIII_4960_COMB_LUM         43.428347                     0.000000                      1.0
# NA_OIII_4960_COMB_NPIX        32.000000                     0.000000                      0.0
# NA_OIII_4960_COMB_SNR         58.884182                     0.000000                      0.0
# NA_OIII_4960_COMB_VOFF        -24.572078                    0.000000                      0.0
# NA_OIII_4960_COMB_W80         726.812538                    0.000000                      0.0
# NA_OIII_4960_DISP             199.450230                    0.000000                      1.0
# NA_OIII_4960_DISP_CORR        194.441387                    0.000000                      1.0
# NA_OIII_4960_DISP_RES         44.417804                     nan                           nan
# NA_OIII_4960_EW               14.934366                     0.000000                      0.0
# NA_OIII_4960_FLUX             -14.095277                    0.000000                      0.0
# NA_OIII_4960_FWHM             6.824786                      0.000000                      0.0
# NA_OIII_4960_FWHM_CORR        0.000000                      0.000000                      0.0
# NA_OIII_4960_LUM              43.270942                     0.000000                      0.0
# NA_OIII_4960_NPIX             17.000000                     0.000000                      0.0
# NA_OIII_4960_SNR              57.902456                     0.000000                      0.0
# NA_OIII_4960_VOFF             -27.960575                    0.000000                      1.0
# NA_OIII_4960_W80              524.460649                    0.000000                      0.0
# NA_OIII_5007_2_AMP            50.751301                     0.000000                      1.0
# NA_OIII_5007_2_DISP           497.484650                    0.000000                      1.0
# NA_OIII_5007_2_DISP_CORR      495.504606                    0.000000                      1.0
# NA_OIII_5007_2_DISP_RES       44.341437                     nan                           nan
# NA_OIII_5007_2_EW             20.034248                     0.000000                      0.0
# NA_OIII_5007_2_FLUX           -13.976569                    0.000000                      0.0
# NA_OIII_5007_2_FWHM           16.954129                     0.000000                      0.0
# NA_OIII_5007_2_FWHM_CORR      0.000000                      0.000000                      0.0
# NA_OIII_5007_2_LUM            43.389650                     0.000000                      0.0
# NA_OIII_5007_2_NPIX           39.000000                     0.000000                      0.0
# NA_OIII_5007_2_SNR            30.240716                     0.000000                      0.0
# NA_OIII_5007_2_VOFF           -16.814625                    0.000000                      1.0
# NA_OIII_5007_2_W80            1303.662665                   0.000000                      0.0
# NA_OIII_5007_AMP              289.803833                    0.000000                      1.0
# NA_OIII_5007_COMB_DISP        317.784421                    0.000000                      0.0
# NA_OIII_5007_COMB_DISP_CORR   314.675667                    0.000000                      0.0
# NA_OIII_5007_COMB_DISP_RES    44.341437                     nan                           nan
# NA_OIII_5007_COMB_EW          65.904599                     0.000000                      1.0
# NA_OIII_5007_COMB_FLUX        -13.459471                    0.000000                      1.0
# NA_OIII_5007_COMB_FWHM        7.477947                      0.000000                      0.0
# NA_OIII_5007_COMB_FWHM_CORR   0.000000                      0.000000                      0.0
# NA_OIII_5007_COMB_LUM         43.906748                     0.000000                      1.0
# NA_OIII_5007_COMB_NPIX        39.000000                     0.000000                      0.0
# NA_OIII_5007_COMB_SNR         136.008869                    0.000000                      0.0
# NA_OIII_5007_COMB_VOFF        -24.572077                    0.000000                      0.0
# NA_OIII_5007_COMB_W80         727.308134                    0.000000                      0.0
# NA_OIII_5007_DISP             199.450230                    0.000000                      1.0
# NA_OIII_5007_DISP_CORR        194.458817                    0.000000                      1.0
# NA_OIII_5007_DISP_RES         44.341437                     nan                           nan
# NA_OIII_5007_EW               45.870351                     0.000000                      0.0
# NA_OIII_5007_FLUX             -13.616874                    0.000000                      0.0
# NA_OIII_5007_FWHM             6.824559                      0.000000                      0.0
# NA_OIII_5007_FWHM_CORR        0.000000                      0.000000                      0.0
# NA_OIII_5007_LUM              43.749345                     0.000000                      0.0
# NA_OIII_5007_NPIX             19.000000                     0.000000                      0.0
# NA_OIII_5007_SNR              172.565547                    0.000000                      0.0
# NA_OIII_5007_VOFF             -27.960575                    0.000000                      1.0
# NA_OIII_5007_W80              525.905444                    0.000000                      0.0
# NA_OPT_FEII_AMP               0.064947                      0.000000                      1.0
# NA_OPT_FEII_DISP              5.619008                      0.000000                      1.0
# NA_OPT_FEII_TEMPLATE_EW       0.028518                      0.000000                      1.0
# NA_OPT_FEII_TEMPLATE_FLUX     -16.814758                    0.000000                      1.0
# NA_OPT_FEII_TEMPLATE_LUM      40.551461                     0.000000                      1.0
# NA_OPT_FEII_VOFF              86.190050                     0.000000                      1.0
# POWER_AMP                     50.600280                     0.000000                      1.0
# POWER_SLOPE                   6.000000                      0.000000                      2.0
# RCHI_SQUARED                  2.387057                      0.000000                      0.0
# R_SQUARED                     0.998261                      0.000000                      0.0
# NOISE_STD                     1.499550
# RESID_STD                     2.930136
# --------------------------------------------------------------------------------------
#  - Done fitting 2-test!
#
# End process memory: 0.35043738
