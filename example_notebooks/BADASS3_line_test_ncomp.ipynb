# %% [markdown]
# ## Bayesian AGN Decomposition Analysis for SDSS Spectra (BADASS)
# ### Single Spectrum Line Test Example
#
# ####  Remington O. Sexton$^{1}$, Sara M. Doan$^{2}$, William Matzko$^{2}$ Michael A. Reefe$^{2}$,
# $^{1}$United States Naval Observatory, $^{2}$George Mason University

# %%
import glob
import time
import natsort
from IPython.display import clear_output
import os
import sys
import psutil
import pathlib
import natsort
# Import BADASS here
BADASS_DIR = pathlib.Path(os.getcwd()).resolve().parent
sys.path.insert(1,str(BADASS_DIR))
import badass as badass
import badass_check_input

from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# 2023-03-30 13:47:19.621516: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ### BADASS Options

# %%
options_file = "badass_ncomp_options.py"

if os.path.exists(options_file):
    print("\n Options file %s found.\n" % (options_file))
# Out:
#  Options file badass_ncomp_options.py found.

# %% [markdown]
# ### Run BADASS on a single spectrum
#
# The following is shows how to fit single SDSS spectra.

# %% [markdown]
# #### Directory Structure

# %%
nobj = 8 # Object in the spec_dir list
########################## Directory Structure #################################
spec_dir = '../example_spectra/' # folder with spectra in it
# Get full list of spectrum folders; these will be the working directories
spec_loc = natsort.natsorted( glob.glob(spec_dir+'*') )[nobj]

################################################################################
print(len(spec_loc))
print(spec_loc)
# Out:
# 25
# ../example_spectra/8-test

# %% [markdown]
# #### Choose Spectrum

# %%
file = glob.glob(spec_loc+'/*.fits')[0] # Get name of FITS spectra file
print(file)
# Out:
# ../example_spectra/8-test/spec-1701-53142-0483.fits

# %% [markdown]
# #### Run IRSA Dust Query
# To correct for Galactic extinction.  This only needs to be done once so that the data is stored locally.

# %%
badass_check_input.fetch_IRSA_dust(spec_loc)
# Out:
#  Fetching IRSA Dust for spectra...
#
#  Done fetching IRSA dust!

# %% [markdown]
# #### Run

# %%
import numpy as np
for i in range(1):
    np.random.seed()
    print("\n---------------------------------------------------------")
    print(" Begin Test %d of %d" % (i+1,10))
    print("---------------------------------------------------------")
    
    # Call the main function in BADASS
    badass.run_BADASS(pathlib.Path(file),
                      options_file = options_file,
                     )
        #
# Out:
# ---------------------------------------------------------
#  Begin Test 1 of 10
# ---------------------------------------------------------
# Start process memory: 0.48219341
#  Folder has not been created.  Creating MCMC_output folder...
#
#  > Starting fit for 8-test
#
#
# -----------------------------------------------------------
#  file:                        spec-1701-53142-0483.fits
#  SDSS redshift:               0.12047
#  fitting region:              (4400,5500) [A]
#  velocity scale:              68.97 [km/s/pixel]
#  Galactic E(B-V):             0.025
#  Flux Normalization:          1.0e-17
# -----------------------------------------------------------
# 	- Adding parameter for unexplained variance for reduced Chi-squared.
# 	- Fitting a SSP host-galaxy template.
# 	- Fitting additive legendre polynomial component.
# 	- Fitting Simple AGN power-law continuum.
#
#  Performing line testing for [['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA']]
# ----------------------------------------------------------------------------------------------------
#
#  Performing test of NCOMP 0 versus NCOMP 1 for ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA']...
#
# 	 Fitting NCOMP 0
# 	 Fitting NCOMP 1
#
#  Performing test of NCOMP 1 versus NCOMP 2 for ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA']...
#
# 	 Fitting NCOMP 2
#
#  Performing test of NCOMP 2 versus NCOMP 3 for ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA']...
#
# 	 Fitting NCOMP 3
#
#  Performing test of NCOMP 3 versus NCOMP 4 for ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA']...
#
# 	 Fitting NCOMP 4
#
#  Performing test of NCOMP 4 versus NCOMP 5 for ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA']...
#
# 	 Fitting NCOMP 5
#
#
# New Line List:
# NA_UNK_1
# NA_H_BETA
# NA_H_BETA_2
# NA_H_BETA_3
# NA_OIII_4960
# NA_OIII_4960_2
# NA_OIII_4960_3
# NA_OIII_5007
# NA_OIII_5007_2
# NA_OIII_5007_3
#
#
# NA_UNK_1
# 	 center : 5200
# 	 line_type : na
# 	 line_profile : gaussian
# 	 amp : free
# 	 disp : free
# 	 voff : free
# 	 ncomp : 1
# 	 center_pix : 726.0513029315961
# 	 disp_res_ang : 0.9710525197074276
# 	 disp_res_kms : 55.983504178881375
# NA_H_BETA
# 	 center : 4862.691
# 	 amp : free
# 	 disp : NA_OIII_5007_DISP
# 	 voff : free
# 	 line_type : na
# 	 label : H$\beta$
# 	 ncomp : 1
# 	 line_profile : gaussian
# 	 center_pix : 434.7840104757746
# 	 disp_res_ang : 0.8762110713244623
# 	 disp_res_kms : 54.01977440046548
# NA_H_BETA_2
# 	 center : 4862.691
# 	 amp : NA_H_BETA_AMP*NA_OIII_5007_2_AMP/NA_OIII_5007_AMP
# 	 disp : NA_OIII_5007_2_DISP
# 	 voff : NA_OIII_5007_2_VOFF
# 	 line_type : na
# 	 ncomp : 2
# 	 parent : NA_H_BETA
# 	 line_profile : gaussian
# 	 center_pix : 434.7840104757746
# 	 disp_res_ang : 0.8762110713244623
# 	 disp_res_kms : 54.01977440046548
# NA_H_BETA_3
# 	 center : 4862.691
# 	 amp : NA_H_BETA_AMP*NA_OIII_5007_3_AMP/NA_OIII_5007_AMP
# 	 disp : NA_OIII_5007_3_DISP
# 	 voff : NA_OIII_5007_3_VOFF
# 	 line_type : na
# 	 ncomp : 3
# 	 parent : NA_H_BETA
# 	 line_profile : gaussian
# 	 center_pix : 434.7840104757746
# 	 disp_res_ang : 0.8762110713244623
# 	 disp_res_kms : 54.01977440046548
# NA_OIII_4960
# 	 center : 4960.295
# 	 amp : (NA_OIII_5007_AMP/2.98)
# 	 disp : NA_OIII_5007_DISP
# 	 voff : NA_OIII_5007_VOFF
# 	 line_type : na
# 	 label : [O III]
# 	 ncomp : 1
# 	 line_profile : gaussian
# 	 center_pix : 521.0924946512623
# 	 disp_res_ang : 0.8870212540543747
# 	 disp_res_kms : 53.61017480839414
# NA_OIII_4960_2
# 	 center : 4960.295
# 	 amp : (NA_OIII_5007_2_AMP/2.98)
# 	 disp : NA_OIII_5007_2_DISP
# 	 voff : NA_OIII_5007_2_VOFF
# 	 line_type : na
# 	 ncomp : 2
# 	 parent : NA_OIII_4960
# 	 line_profile : gaussian
# 	 center_pix : 521.0924946512623
# 	 disp_res_ang : 0.8870212540543747
# 	 disp_res_kms : 53.61017480839414
# NA_OIII_4960_3
# 	 center : 4960.295
# 	 amp : (NA_OIII_5007_3_AMP/2.98)
# 	 disp : NA_OIII_5007_3_DISP
# 	 voff : NA_OIII_5007_3_VOFF
# 	 line_type : na
# 	 ncomp : 3
# 	 parent : NA_OIII_4960
# 	 line_profile : gaussian
# 	 center_pix : 521.0924946512623
# 	 disp_res_ang : 0.8870212540543747
# 	 disp_res_kms : 53.61017480839414
# NA_OIII_5007
# 	 center : 5008.24
# 	 amp : free
# 	 disp : free
# 	 voff : free
# 	 line_type : na
# 	 label : [O III]
# 	 ncomp : 1
# 	 line_profile : gaussian
# 	 center_pix : 562.8688088172953
# 	 disp_res_ang : 0.8925869962336651
# 	 disp_res_kms : 53.43011708299267
# NA_OIII_5007_2
# 	 center : 5008.24
# 	 amp : free
# 	 disp : free
# 	 voff : free
# 	 line_type : na
# 	 ncomp : 2
# 	 parent : NA_OIII_5007
# 	 line_profile : gaussian
# 	 center_pix : 562.8688088172953
# 	 disp_res_ang : 0.8925869962336651
# 	 disp_res_kms : 53.43011708299267
# NA_OIII_5007_3
# 	 center : 5008.24
# 	 amp : free
# 	 disp : free
# 	 voff : free
# 	 line_type : na
# 	 ncomp : 3
# 	 parent : NA_OIII_5007
# 	 line_profile : gaussian
# 	 center_pix : 562.8688088172953
# 	 disp_res_ang : 0.8925869962336651
# 	 disp_res_kms : 53.43011708299267
#
#  Test Results:
# +-----------------------------------------------+---------+---------+-------+--------+------------+---------+-----------+---------+
# |                      TEST                     | NCOMP_A | NCOMP_B | ANOVA | BADASS | CHI2_RATIO | F_RATIO | SSR_RATIO |   AON   |
# +-----------------------------------------------+---------+---------+-------+--------+------------+---------+-----------+---------+
# | ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA'] |   0.0   |   1.0   |  1.0  |  1.0   |   0.886    |  3.037  |   9.226   |  99.581 |
# | ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA'] |   1.0   |   2.0   |  1.0  |  1.0   |   0.846    |  1.953  |   3.815   | 105.398 |
# | ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA'] |   2.0   |   3.0   |  1.0  |  1.0   |   0.598    |   2.11  |   4.452   |  97.895 |
# | ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA'] |   3.0   |   4.0   |  0.0  |  0.0   |   -1.488   |  0.474  |   0.224   | 105.424 |
# | ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA'] |   4.0   |   5.0   |  1.0  |  1.0   |   0.633    |  2.185  |   4.773   |  97.893 |
# +-----------------------------------------------+---------+---------+-------+--------+------------+---------+-----------+---------+
#  - Line testing complete for 8-test!
#
# ----------------------------------------------------------------------------------------------------
#
#  Initializing parameters...
# ----------------------------------------------------------------------------------------------------
# 	- Adding parameter for unexplained variance for reduced Chi-squared.
# 	- Fitting a SSP host-galaxy template.
# 	- Fitting additive legendre polynomial component.
# 	- Fitting Simple AGN power-law continuum.
#
#  - ('NA_OIII_5007_4_DISP', 'NA_OIII_5007_3_DISP') soft constraint removed because one or more free parameters is not available.
#
#  - ('NA_OIII_5007_5_DISP', 'NA_OIII_5007_4_DISP') soft constraint removed because one or more free parameters is not available.
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Line List:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
# NA_H_BETA
#                               amp                           free
#                               center                        4862.691
#                               center_pix                    434.7840104757746
#                               disp                          NA_OIII_5007_DISP
#                               disp_res_ang                  0.8762110713244623
#                               disp_res_kms                  54.01977440046548
#                               label                         H$\beta$
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          free
# NA_H_BETA_2
#                               amp                           NA_H_BETA_AMP*NA_OIII_5007_2_AMP/NA_OIII_5007_AMP
#                               center                        4862.691
#                               center_pix                    434.7840104757746
#                               disp                          NA_OIII_5007_2_DISP
#                               disp_res_ang                  0.8762110713244623
#                               disp_res_kms                  54.01977440046548
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         2
#                               parent                        NA_H_BETA
#                               voff                          NA_OIII_5007_2_VOFF
# NA_H_BETA_3
#                               amp                           NA_H_BETA_AMP*NA_OIII_5007_3_AMP/NA_OIII_5007_AMP
#                               center                        4862.691
#                               center_pix                    434.7840104757746
#                               disp                          NA_OIII_5007_3_DISP
#                               disp_res_ang                  0.8762110713244623
#                               disp_res_kms                  54.01977440046548
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         3
#                               parent                        NA_H_BETA
#                               voff                          NA_OIII_5007_3_VOFF
# NA_OIII_4960
#                               amp                           (NA_OIII_5007_AMP/2.98)
#                               center                        4960.295
#                               center_pix                    521.0924946512623
#                               disp                          NA_OIII_5007_DISP
#                               disp_res_ang                  0.8870212540543747
#                               disp_res_kms                  53.61017480839414
#                               label                         [O III]
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          NA_OIII_5007_VOFF
# NA_OIII_4960_2
#                               amp                           (NA_OIII_5007_2_AMP/2.98)
#                               center                        4960.295
#                               center_pix                    521.0924946512623
#                               disp                          NA_OIII_5007_2_DISP
#                               disp_res_ang                  0.8870212540543747
#                               disp_res_kms                  53.61017480839414
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         2
#                               parent                        NA_OIII_4960
#                               voff                          NA_OIII_5007_2_VOFF
# NA_OIII_4960_3
#                               amp                           (NA_OIII_5007_3_AMP/2.98)
#                               center                        4960.295
#                               center_pix                    521.0924946512623
#                               disp                          NA_OIII_5007_3_DISP
#                               disp_res_ang                  0.8870212540543747
#                               disp_res_kms                  53.61017480839414
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         3
#                               parent                        NA_OIII_4960
#                               voff                          NA_OIII_5007_3_VOFF
# NA_OIII_5007
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    562.8688088172953
#                               disp                          free
#                               disp_res_ang                  0.8925869962336651
#                               disp_res_kms                  53.43011708299267
#                               label                         [O III]
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          free
# NA_OIII_5007_2
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    562.8688088172953
#                               disp                          free
#                               disp_res_ang                  0.8925869962336651
#                               disp_res_kms                  53.43011708299267
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         2
#                               parent                        NA_OIII_5007
#                               voff                          free
# NA_OIII_5007_3
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    562.8688088172953
#                               disp                          free
#                               disp_res_ang                  0.8925869962336651
#                               disp_res_kms                  53.43011708299267
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         3
#                               parent                        NA_OIII_5007
#                               voff                          free
# NA_UNK_1
#                               amp                           free
#                               center                        5200
#                               center_pix                    726.0513029315961
#                               disp                          free
#                               disp_res_ang                  0.9710525197074276
#                               disp_res_kms                  55.983504178881375
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          free
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Number of Free Line Parameters: 14
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  All Free Parameters:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
# APOLY_COEFF_1
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_2
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_3
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_4
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_5
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_6
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_7
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# HOST_TEMP_DISP
#                               init                          100.0
#                               plim                          (0.001, 500.0)
# HOST_TEMP_VEL
#                               init                          0.0
#                               plim                          (-500.0, 500)
# NA_H_BETA_AMP
#                               init                          16.605020510219827
#                               plim                          (0.0, 370.12206945539856)
# NA_H_BETA_VOFF
#                               init                          429.44859155572334
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_2_AMP
#                               init                          59.23746796976255
#                               plim                          (0.0, 370.12206945539856)
# NA_OIII_5007_2_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_OIII_5007_2_VOFF
#                               init                          78.1708748934855
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_3_AMP
#                               init                          59.23746796976255
#                               plim                          (0.0, 370.12206945539856)
# NA_OIII_5007_3_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_OIII_5007_3_VOFF
#                               init                          78.1708748934855
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_AMP
#                               init                          59.23746796976255
#                               plim                          (0.0, 370.12206945539856)
# NA_OIII_5007_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_OIII_5007_VOFF
#                               init                          78.1708748934855
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_UNK_1_AMP
#                               init                          24.127866412860623
#                               plim                          (0.0, 370.12206945539856)
# NA_UNK_1_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_UNK_1_VOFF
#                               init                          480.0237561801382
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NOISE_SCALE
#                               init                          1.0
#                               plim                          (0.0001, 100.0)
#                               prior                         {'type': 'jeffreys'}
# POWER_AMP
#                               init                          9.815412870522255
#                               plim                          (0, 277.5915520915489)
# POWER_SLOPE
#                               init                          -1.0
#                               plim                          (-6.0, 6.0)
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Total number of free parameters: 26
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Soft Constraints:
#
#            NA_OIII_5007_2_DISP > NA_OIII_5007_DISP
#            NA_OIII_5007_3_DISP > NA_OIII_5007_2_DISP
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# basinhopping step 0: f 37951.6
# warning: basinhopping: local minimization failure
# basinhopping step 1: f 37951.6 trial_f inf accepted 0  lowest_f 37951.6
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -56.3369 trial_f -56.3369 accepted 1  lowest_f -56.3369
# found new global minimum on step 2 with function value -56.3369
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -286.417 trial_f -286.417 accepted 1  lowest_f -286.417
# found new global minimum on step 3 with function value -286.417
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -641.021 trial_f -641.021 accepted 1  lowest_f -641.021
# found new global minimum on step 4 with function value -641.021
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -867.993 trial_f -867.993 accepted 1  lowest_f -867.993
# found new global minimum on step 5 with function value -867.993
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -903.577 trial_f -903.577 accepted 1  lowest_f -903.577
# found new global minimum on step 6 with function value -903.577
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -917.719 trial_f -917.719 accepted 1  lowest_f -917.719
# found new global minimum on step 7 with function value -917.719
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -917.719 trial_f -914.114 accepted 0  lowest_f -917.719
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -917.719 trial_f -909.657 accepted 0  lowest_f -917.719
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -918.914 trial_f -918.914 accepted 1  lowest_f -918.914
# found new global minimum on step 10 with function value -918.914
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -918.914 trial_f -911.829 accepted 0  lowest_f -918.914
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -918.914 trial_f -910.307 accepted 0  lowest_f -918.914
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -921.352 trial_f -921.352 accepted 1  lowest_f -921.352
# found new global minimum on step 13 with function value -921.352
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -921.352 trial_f -915.712 accepted 0  lowest_f -921.352
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -921.251 trial_f -921.251 accepted 1  lowest_f -921.352
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -921.251 trial_f -908.787 accepted 0  lowest_f -921.352
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -921.251 trial_f -917.532 accepted 0  lowest_f -921.352
# warning: basinhopping: local minimization failure
# basinhopping step 18: f -921.535 trial_f -921.535 accepted 1  lowest_f -921.535
# found new global minimum on step 18 with function value -921.535
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -926.648 trial_f -926.648 accepted 1  lowest_f -926.648
# found new global minimum on step 19 with function value -926.648
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -957.238 trial_f -957.238 accepted 1  lowest_f -957.238
# found new global minimum on step 20 with function value -957.238
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -957.238 trial_f -942.117 accepted 0  lowest_f -957.238
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -957.238 trial_f -943.112 accepted 0  lowest_f -957.238
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -957.978 trial_f -957.978 accepted 1  lowest_f -957.978
# found new global minimum on step 23 with function value -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -957.978 trial_f -940.894 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -957.978 trial_f -952.027 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -957.978 trial_f -950.452 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -957.978 trial_f -943.383 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 28: f -957.978 trial_f -954.616 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 29: f -957.978 trial_f -947.448 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 30: f -957.978 trial_f -954.523 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 31: f -957.978 trial_f -938.067 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 32: f -957.978 trial_f -950.533 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 33: f -957.978 trial_f -956.644 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 34: f -957.978 trial_f -955.362 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 35: f -957.978 trial_f -955.484 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 36: f -957.978 trial_f -952.96 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 37: f -957.978 trial_f -951.706 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 38: f -957.978 trial_f -954.407 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 39: f -957.978 trial_f -944.151 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 40: f -957.978 trial_f -947.736 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 41: f -957.978 trial_f -946.937 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 42: f -957.978 trial_f -953.929 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 43: f -957.978 trial_f -955.06 accepted 0  lowest_f -957.978
# warning: basinhopping: local minimization failure
# basinhopping step 44: f -958.497 trial_f -958.497 accepted 1  lowest_f -958.497
# found new global minimum on step 44 with function value -958.497
# warning: basinhopping: local minimization failure
# basinhopping step 45: f -958.497 trial_f -936.431 accepted 0  lowest_f -958.497
# warning: basinhopping: local minimization failure
# basinhopping step 46: f -956.084 trial_f -956.084 accepted 1  lowest_f -958.497
# warning: basinhopping: local minimization failure
# basinhopping step 47: f -958.534 trial_f -958.534 accepted 1  lowest_f -958.534
# found new global minimum on step 47 with function value -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 48: f -958.534 trial_f -956.54 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 49: f -958.534 trial_f -938.222 accepted 0  lowest_f -958.534
# adaptive stepsize: acceptance rate 0.320000 target 0.500000 new stepsize 0.9 old stepsize 1
# warning: basinhopping: local minimization failure
# basinhopping step 50: f -958.534 trial_f -953.476 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 51: f -958.534 trial_f -956.056 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 52: f -958.311 trial_f -958.311 accepted 1  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 53: f -956.01 trial_f -956.01 accepted 1  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 54: f -958.147 trial_f -958.147 accepted 1  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 55: f -958.147 trial_f -955.149 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 56: f -958.147 trial_f -953.975 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 57: f -958.147 trial_f -956.292 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 58: f -958.147 trial_f -957.486 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 59: f -958.147 trial_f -957.1 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 60: f -958.147 trial_f -956.316 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 61: f -958.147 trial_f -953.151 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 62: f -958.147 trial_f -955.988 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 63: f -958.108 trial_f -958.108 accepted 1  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 64: f -958.108 trial_f -957.294 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 65: f -958.108 trial_f -956.22 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 66: f -957.698 trial_f -957.698 accepted 1  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 67: f -957.698 trial_f -954.881 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 68: f -957.698 trial_f -955.338 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 69: f -957.698 trial_f -954.361 accepted 0  lowest_f -958.534
# warning: basinhopping: local minimization failure
# basinhopping step 70: f -958.719 trial_f -958.719 accepted 1  lowest_f -958.719
# found new global minimum on step 70 with function value -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 71: f -958.719 trial_f -951.301 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 72: f -958.719 trial_f -956.506 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 73: f -958.719 trial_f -958.591 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 74: f -958.719 trial_f -955.08 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 75: f -958.719 trial_f -957.41 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 76: f -958.719 trial_f -958.472 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 77: f -958.719 trial_f -951.205 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 78: f -958.719 trial_f -956.237 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 79: f -958.719 trial_f -956.117 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 80: f -958.719 trial_f -957.461 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 81: f -958.719 trial_f -950.204 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 82: f -958.125 trial_f -958.125 accepted 1  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 83: f -958.125 trial_f -954.66 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 84: f -958.125 trial_f -950.953 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 85: f -958.125 trial_f -954.424 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 86: f -958.125 trial_f -953.528 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 87: f -958.125 trial_f -956.514 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 88: f -958.125 trial_f -955.82 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 89: f -958.125 trial_f -954.543 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 90: f -958.125 trial_f -956.288 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 91: f -958.125 trial_f -953.73 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 92: f -958.125 trial_f -954.721 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 93: f -958.534 trial_f -958.534 accepted 1  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 94: f -958.534 trial_f -955.38 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 95: f -958.534 trial_f -956.431 accepted 0  lowest_f -958.719
# warning: basinhopping: local minimization failure
# basinhopping step 96: f -957.815 trial_f -957.815 accepted 1  lowest_f -958.719
#
#  Performing Monte Carlo bootstrapping...
# 	   Completed 1 of 25 iterations.
# 	   Completed 2 of 25 iterations.
# 	   Completed 3 of 25 iterations.
# 	   Completed 4 of 25 iterations.
# 	   Completed 5 of 25 iterations.
# 	   Completed 6 of 25 iterations.
# 	   Completed 7 of 25 iterations.
# 	   Completed 8 of 25 iterations.
# 	   Completed 9 of 25 iterations.
# 	   Completed 10 of 25 iterations.
# 	   Completed 11 of 25 iterations.
# 	   Completed 12 of 25 iterations.
# 	   Completed 13 of 25 iterations.
# 	   Completed 14 of 25 iterations.
# 	   Completed 15 of 25 iterations.
# 	   Completed 16 of 25 iterations.
# 	   Completed 17 of 25 iterations.
# 	   Completed 18 of 25 iterations.
# 	   Completed 19 of 25 iterations.
# 	   Completed 20 of 25 iterations.
# 	   Completed 21 of 25 iterations.
# 	   Completed 22 of 25 iterations.
# 	   Completed 23 of 25 iterations.
# 	   Completed 24 of 25 iterations.
# 	   Completed 25 of 25 iterations.
#
#  Maximum Likelihood Best-fit Parameters:
# --------------------------------------------------------------------------------------
#
# Parameter                     Best-fit Value                +/- 1-sigma                   Flag
# --------------------------------------------------------------------------------------
# APOLY_COEFF_1                 6.373469                      0.265711                      0
# APOLY_COEFF_2                 -1.646261                     0.075997                      0
# APOLY_COEFF_3                 0.204580                      0.027818                      0
# APOLY_COEFF_4                 0.013980                      0.001696                      0
# APOLY_COEFF_5                 -0.228678                     0.026879                      0
# APOLY_COEFF_6                 -0.093785                     0.026435                      0
# APOLY_COEFF_7                 -0.618041                     0.106856                      0
# HOST_TEMP_DISP                160.071991                    15.399730                     0
# HOST_TEMP_VEL                 355.966735                    11.204625                     0
# LOG_LIKE                      -786.861871                   36.050560                     0
# L_CONT_AGN_5100               43.246293                     0.023306                      0
# L_CONT_HOST_5100              43.411300                     0.014065                      0
# L_CONT_TOT_5100               43.586803                     0.001355                      0
# NA_H_BETA_2_AMP               0.000370                      1.030214                      0
# NA_H_BETA_2_DISP              473.992157                    38.153483                     0
# NA_H_BETA_2_EW                0.000385                      0.000111                      0
# NA_H_BETA_2_FLUX              -19.143226                    0.093466                      1
# NA_H_BETA_2_FWHM              1116.672350                   89.840084                     0
# NA_H_BETA_2_LUM               36.434399                     0.093466                      0
# NA_H_BETA_2_NPIX              0.000000                      0.000000                      0
# NA_H_BETA_2_SNR               0.000209                      0.000052                      0
# NA_H_BETA_2_VOFF              9.235402                      1.018392                      0
# NA_H_BETA_2_W80               1244.755331                   99.971601                     0
# NA_H_BETA_3_AMP               6.935868                      1.201838                      0
# NA_H_BETA_3_DISP              1000.000000                   0.000000                      2
# NA_H_BETA_3_EW                14.674023                     0.292544                      0
# NA_H_BETA_3_FLUX              -14.548899                    0.007973                      0
# NA_H_BETA_3_FWHM              2355.446964                   0.001583                      0
# NA_H_BETA_3_LUM               41.028725                     0.007973                      0
# NA_H_BETA_3_NPIX              47.000000                     0.266469                      0
# NA_H_BETA_3_SNR               3.962950                      0.072219                      0
# NA_H_BETA_3_VOFF              -999.944894                   0.037372                      0
# NA_H_BETA_3_W80               2616.682259                   0.002114                      0
# NA_H_BETA_AMP                 20.160581                     0.369503                      0
# NA_H_BETA_COMB_DISP           975.927562                    3.774411                      0
# NA_H_BETA_COMB_EW             35.121271                     0.563499                      0
# NA_H_BETA_COMB_FLUX           -14.180602                    0.006307                      0
# NA_H_BETA_COMB_FWHM           1264.642216                   9.070870                      0
# NA_H_BETA_COMB_LUM            41.397023                     0.006307                      0
# NA_H_BETA_COMB_NPIX           59.000000                     0.443560                      0
# NA_H_BETA_COMB_SNR            12.996442                     0.219874                      0
# NA_H_BETA_COMB_VOFF           -262.763828                   8.310749                      0
# NA_H_BETA_COMB_W80            2526.803800                   9.933611                      0
# NA_H_BETA_DISP                458.590815                    3.182899                      0
# NA_H_BETA_EW                  20.516446                     0.340972                      0
# NA_H_BETA_FLUX                -14.420182                    0.006767                      0
# NA_H_BETA_FWHM                1080.607531                   7.651292                      0
# NA_H_BETA_LUM                 41.157443                     0.006767                      0
# NA_H_BETA_NPIX                30.000000                     0.480384                      0
# NA_H_BETA_SNR                 11.487408                     0.212230                      0
# NA_H_BETA_VOFF                287.542949                    11.107183                     0
# NA_H_BETA_W80                 1206.570649                   8.574489                      0
# ...
# ------------------------------------------------
# MCMC iteration: 2300
#
# Iteration = 2300
# ------------------------------------------------
# Parameter                     Current Value
# ------------------------------------------------
# APOLY_COEFF_1                 3.8105
# APOLY_COEFF_2                 -0.9471
# APOLY_COEFF_3                 0.1056
# APOLY_COEFF_4                 0.1013
# APOLY_COEFF_5                 -0.2748
# APOLY_COEFF_6                 -0.1689
# APOLY_COEFF_7                 -0.5720
# HOST_TEMP_DISP                176.0602
# HOST_TEMP_VEL                 355.4041
# NA_H_BETA_AMP                 19.5010
# NA_H_BETA_VOFF                286.6133
# NA_OIII_5007_2_AMP            3.9706
# NA_OIII_5007_2_DISP           499.9543
# NA_OIII_5007_2_VOFF           -63.6878
# NA_OIII_5007_3_AMP            52.8860
# NA_OIII_5007_3_DISP           997.8849
# NA_OIII_5007_3_VOFF           -996.1627
# NA_OIII_5007_AMP              150.9003
# NA_OIII_5007_DISP             455.9704
# NA_OIII_5007_VOFF             117.8590
# NA_UNK_1_AMP                  4.0261
# NA_UNK_1_DISP                 231.6306
# NA_UNK_1_VOFF                 402.4803
# NOISE_SCALE                   1.5529
# POWER_AMP                     7.9075
# POWER_SLOPE                   -2.8729
# ------------------------------------------------
# MCMC iteration: 2400
#
# Iteration = 2400
# ------------------------------------------------
# Parameter                     Current Value
# ------------------------------------------------
# APOLY_COEFF_1                 3.8833
# APOLY_COEFF_2                 -0.9576
# APOLY_COEFF_3                 0.1158
# APOLY_COEFF_4                 0.1028
# APOLY_COEFF_5                 -0.2952
# APOLY_COEFF_6                 -0.1784
# APOLY_COEFF_7                 -0.5364
# HOST_TEMP_DISP                172.8516
# HOST_TEMP_VEL                 352.9363
# NA_H_BETA_AMP                 19.4339
# NA_H_BETA_VOFF                290.0917
# NA_OIII_5007_2_AMP            5.1303
# NA_OIII_5007_2_DISP           502.4122
# NA_OIII_5007_2_VOFF           -74.5638
# NA_OIII_5007_3_AMP            52.8829
# NA_OIII_5007_3_DISP           998.0005
# NA_OIII_5007_3_VOFF           -995.7529
# NA_OIII_5007_AMP              149.8152
# NA_OIII_5007_DISP             455.2671
# NA_OIII_5007_VOFF             119.5666
# NA_UNK_1_AMP                  4.1419
# NA_UNK_1_DISP                 229.8518
# NA_UNK_1_VOFF                 394.0761
# NOISE_SCALE                   1.5500
# POWER_AMP                     7.9310
# POWER_SLOPE                   -2.9722
# ------------------------------------------------
# MCMC iteration: 2500
#
# Iteration = 2500
# ------------------------------------------------
# Parameter                     Current Value
# ------------------------------------------------
# APOLY_COEFF_1                 3.8299
# APOLY_COEFF_2                 -0.9665
# APOLY_COEFF_3                 0.1033
# APOLY_COEFF_4                 0.0986
# APOLY_COEFF_5                 -0.2925
# APOLY_COEFF_6                 -0.1686
# APOLY_COEFF_7                 -0.5452
# HOST_TEMP_DISP                173.5064
# HOST_TEMP_VEL                 349.6290
# NA_H_BETA_AMP                 19.4243
# NA_H_BETA_VOFF                291.0059
# NA_OIII_5007_2_AMP            6.0323
# NA_OIII_5007_2_DISP           500.9504
# NA_OIII_5007_2_VOFF           -96.3087
# NA_OIII_5007_3_AMP            52.8460
# NA_OIII_5007_3_DISP           997.9304
# NA_OIII_5007_3_VOFF           -995.9036
# NA_OIII_5007_AMP              149.6996
# NA_OIII_5007_DISP             454.1946
# NA_OIII_5007_VOFF             122.2596
# NA_UNK_1_AMP                  4.1803
# NA_UNK_1_DISP                 228.5382
# NA_UNK_1_VOFF                 392.0646
# NOISE_SCALE                   1.5464
# POWER_AMP                     7.9920
# POWER_SLOPE                   -3.1106
# ------------------------------------------------
# MCMC iteration: 2600
#
# Iteration = 2600
# ------------------------------------------------
# Parameter                     Current Value
# ------------------------------------------------
# APOLY_COEFF_1                 3.8567
# APOLY_COEFF_2                 -0.9389
# APOLY_COEFF_3                 0.0929
# APOLY_COEFF_4                 0.0883
# APOLY_COEFF_5                 -0.2910
# APOLY_COEFF_6                 -0.1663
# APOLY_COEFF_7                 -0.5498
# HOST_TEMP_DISP                176.8121
# HOST_TEMP_VEL                 350.0799
# NA_H_BETA_AMP                 19.3073
# NA_H_BETA_VOFF                296.5912
# NA_OIII_5007_2_AMP            7.4606
# NA_OIII_5007_2_DISP           501.1389
# NA_OIII_5007_2_VOFF           -121.7526
# NA_OIII_5007_3_AMP            52.8485
# NA_OIII_5007_3_DISP           998.1417
# NA_OIII_5007_3_VOFF           -996.0592
# NA_OIII_5007_AMP              149.0974
# NA_OIII_5007_DISP             453.6794
# NA_OIII_5007_VOFF             123.6863
# NA_UNK_1_AMP                  4.1681
# NA_UNK_1_DISP                 219.3011
# NA_UNK_1_VOFF                 393.4343
# NOISE_SCALE                   1.5456
# POWER_AMP                     8.1736
# POWER_SLOPE                   -2.8620
# ------------------------------------------------
# MCMC iteration: 2700
#
# Iteration = 2700
# ------------------------------------------------
# Parameter                     Current Value
# ------------------------------------------------
# APOLY_COEFF_1                 3.7831
# APOLY_COEFF_2                 -0.9295
# APOLY_COEFF_3                 0.1044
# APOLY_COEFF_4                 0.0787
# APOLY_COEFF_5                 -0.3213
# APOLY_COEFF_6                 -0.1920
# APOLY_COEFF_7                 -0.5304
# HOST_TEMP_DISP                175.8072
# HOST_TEMP_VEL                 353.2011
# NA_H_BETA_AMP                 19.3193
# NA_H_BETA_VOFF                299.8781
# NA_OIII_5007_2_AMP            8.1832
# NA_OIII_5007_2_DISP           505.4557
# NA_OIII_5007_2_VOFF           -142.4667
# NA_OIII_5007_3_AMP            52.7209
# NA_OIII_5007_3_DISP           997.8541
# NA_OIII_5007_3_VOFF           -996.0348
# NA_OIII_5007_AMP              148.9151
# NA_OIII_5007_DISP             453.2052
# NA_OIII_5007_VOFF             124.6450
# NA_UNK_1_AMP                  4.2105
# NA_UNK_1_DISP                 224.4426
# NA_UNK_1_VOFF                 391.4688
# NOISE_SCALE                   1.5410
# POWER_AMP                     8.0556
# POWER_SLOPE                   -2.7448
# ------------------------------------------------
# MCMC iteration: 2800
#
# Iteration = 2800
# ------------------------------------------------
# Parameter                     Current Value
# ------------------------------------------------
# APOLY_COEFF_1                 3.6975
# APOLY_COEFF_2                 -0.9292
# APOLY_COEFF_3                 0.0924
# APOLY_COEFF_4                 0.0773
# APOLY_COEFF_5                 -0.3018
# APOLY_COEFF_6                 -0.1897
# APOLY_COEFF_7                 -0.5630
# HOST_TEMP_DISP                176.6175
# HOST_TEMP_VEL                 355.6219
# NA_H_BETA_AMP                 19.2019
# NA_H_BETA_VOFF                301.0262
# NA_OIII_5007_2_AMP            9.0973
# NA_OIII_5007_2_DISP           508.3061
# NA_OIII_5007_2_VOFF           -180.2766
# NA_OIII_5007_3_AMP            52.6507
# NA_OIII_5007_3_DISP           997.5813
# NA_OIII_5007_3_VOFF           -995.8876
# NA_OIII_5007_AMP              148.2757
# NA_OIII_5007_DISP             452.2601
# NA_OIII_5007_VOFF             127.3567
# NA_UNK_1_AMP                  4.2881
# NA_UNK_1_DISP                 230.3324
# NA_UNK_1_VOFF                 388.3517
# NOISE_SCALE                   1.5419
# POWER_AMP                     7.9878
# POWER_SLOPE                   -2.7227
# ------------------------------------------------
# MCMC iteration: 2900
#
# Iteration = 2900
# ------------------------------------------------
# Parameter                     Current Value
# ------------------------------------------------
# APOLY_COEFF_1                 3.7686
# APOLY_COEFF_2                 -0.9218
# APOLY_COEFF_3                 0.0872
# APOLY_COEFF_4                 0.0841
# APOLY_COEFF_5                 -0.2948
# APOLY_COEFF_6                 -0.1792
# APOLY_COEFF_7                 -0.5856
# HOST_TEMP_DISP                176.3629
# HOST_TEMP_VEL                 357.0450
# NA_H_BETA_AMP                 19.1075
# NA_H_BETA_VOFF                302.4051
# NA_OIII_5007_2_AMP            9.9729
# NA_OIII_5007_2_DISP           505.4906
# NA_OIII_5007_2_VOFF           -198.4002
# NA_OIII_5007_3_AMP            52.6725
# NA_OIII_5007_3_DISP           997.6781
# NA_OIII_5007_3_VOFF           -995.6806
# NA_OIII_5007_AMP              148.1341
# NA_OIII_5007_DISP             450.9547
# NA_OIII_5007_VOFF             130.1109
# NA_UNK_1_AMP                  4.3001
# NA_UNK_1_DISP                 232.6632
# NA_UNK_1_VOFF                 388.9445
# NOISE_SCALE                   1.5479
# POWER_AMP                     8.0659
# POWER_SLOPE                   -2.6884
# ------------------------------------------------
# MCMC iteration: 3000
#
# Iteration = 3000
# ------------------------------------------------
# Parameter                     Current Value
# ------------------------------------------------
# APOLY_COEFF_1                 3.8101
# APOLY_COEFF_2                 -0.9118
# APOLY_COEFF_3                 0.0916
# APOLY_COEFF_4                 0.1051
# APOLY_COEFF_5                 -0.2855
# APOLY_COEFF_6                 -0.1888
# APOLY_COEFF_7                 -0.5848
# HOST_TEMP_DISP                176.2848
# HOST_TEMP_VEL                 358.4691
# NA_H_BETA_AMP                 18.9508
# NA_H_BETA_VOFF                305.0988
# NA_OIII_5007_2_AMP            11.8003
# NA_OIII_5007_2_DISP           493.2099
# NA_OIII_5007_2_VOFF           -222.2650
# NA_OIII_5007_3_AMP            52.4930
# NA_OIII_5007_3_DISP           997.9374
# NA_OIII_5007_3_VOFF           -995.9159
# NA_OIII_5007_AMP              147.3665
# NA_OIII_5007_DISP             448.9229
# NA_OIII_5007_VOFF             134.6970
# NA_UNK_1_AMP                  4.3046
# NA_UNK_1_DISP                 227.8215
# NA_UNK_1_VOFF                 387.0460
# NOISE_SCALE                   1.5481
# POWER_AMP                     7.9748
# POWER_SLOPE                   -2.8844
# ------------------------------------------------
#
#  emcee Runtime = 0:28:30.
#
#
#  > Fitting MCMC chains...
#
#  Generating model parameter distributions...
#
# 		  NOISE_SCALE
# 		  HOST_TEMP_VEL
# 		  HOST_TEMP_DISP
# 		  APOLY_COEFF_1
# 		  APOLY_COEFF_2
# 		  APOLY_COEFF_3
# 		  APOLY_COEFF_4
# 		  APOLY_COEFF_5
# 		  APOLY_COEFF_6
# 		  APOLY_COEFF_7
# 		  POWER_AMP
# 		  POWER_SLOPE
# 		  NA_UNK_1_VOFF
# 		  NA_UNK_1_AMP
# 		  NA_UNK_1_DISP
# 		  NA_H_BETA_VOFF
# 		  NA_H_BETA_AMP
# 		  NA_OIII_5007_VOFF
# 		  NA_OIII_5007_AMP
# 		  NA_OIII_5007_DISP
# 		  NA_OIII_5007_2_VOFF
# 		  NA_OIII_5007_2_AMP
# 		  NA_OIII_5007_2_DISP
# 		  NA_OIII_5007_3_VOFF
# 		  NA_OIII_5007_3_AMP
# 		  NA_OIII_5007_3_DISP
#
#  Generating model flux distributions...
#
# 		  NA_UNK_1_FLUX
# 		  NA_H_BETA_FLUX
# 		  NA_H_BETA_2_FLUX
# 		  NA_H_BETA_3_FLUX
# 		  NA_OIII_4960_FLUX
# 		  NA_OIII_4960_2_FLUX
# 		  NA_OIII_4960_3_FLUX
# 		  NA_OIII_5007_FLUX
# 		  NA_OIII_5007_2_FLUX
# 		  NA_OIII_5007_3_FLUX
# 		  NA_H_BETA_COMB_FLUX
# 		  NA_OIII_4960_COMB_FLUX
# 		  NA_OIII_5007_COMB_FLUX
#
#  Generating model luminosity distributions...
#
# 		  NA_UNK_1_LUM
# 		  NA_H_BETA_LUM
# 		  NA_H_BETA_2_LUM
# 		  NA_H_BETA_3_LUM
# 		  NA_OIII_4960_LUM
# 		  NA_OIII_4960_2_LUM
# 		  NA_OIII_4960_3_LUM
# 		  NA_OIII_5007_LUM
# 		  NA_OIII_5007_2_LUM
# 		  NA_OIII_5007_3_LUM
# 		  NA_H_BETA_COMB_LUM
# 		  NA_OIII_4960_COMB_LUM
# 		  NA_OIII_5007_COMB_LUM
# 		  L_CONT_TOT_5100
# 		  L_CONT_AGN_5100
# 		  L_CONT_HOST_5100
#
#  Generating model equivalent width distributions...
#
# 		  NA_UNK_1_EW
# 		  NA_H_BETA_EW
# 		  NA_H_BETA_2_EW
# 		  NA_H_BETA_3_EW
# 		  NA_OIII_4960_EW
# 		  NA_OIII_4960_2_EW
# 		  NA_OIII_4960_3_EW
# 		  NA_OIII_5007_EW
# 		  NA_OIII_5007_2_EW
# 		  NA_OIII_5007_3_EW
# 		  NA_H_BETA_COMB_EW
# 		  NA_OIII_4960_COMB_EW
# 		  NA_OIII_5007_COMB_EW
#
#  Generating model integrated velocity moment distributions...
#
# 		  NA_UNK_1_FWHM
# 		  NA_UNK_1_W80
# 		  NA_H_BETA_FWHM
# 		  NA_H_BETA_W80
# 		  NA_H_BETA_2_FWHM
# 		  NA_H_BETA_2_W80
# 		  NA_H_BETA_3_FWHM
# 		  NA_H_BETA_3_W80
# 		  NA_OIII_4960_FWHM
# 		  NA_OIII_4960_W80
# 		  NA_OIII_4960_2_FWHM
# 		  NA_OIII_4960_2_W80
# 		  NA_OIII_4960_3_FWHM
# 		  NA_OIII_4960_3_W80
# 		  NA_OIII_5007_FWHM
# 		  NA_OIII_5007_W80
# 		  NA_OIII_5007_2_FWHM
# 		  NA_OIII_5007_2_W80
# 		  NA_OIII_5007_3_FWHM
# 		  NA_OIII_5007_3_W80
# 		  NA_H_BETA_COMB_FWHM
# 		  NA_H_BETA_COMB_W80
# 		  NA_H_BETA_COMB_DISP
# 		  NA_H_BETA_COMB_VOFF
# 		  NA_OIII_4960_COMB_FWHM
# 		  NA_OIII_4960_COMB_W80
# 		  NA_OIII_4960_COMB_DISP
# 		  NA_OIII_4960_COMB_VOFF
# 		  NA_OIII_5007_COMB_FWHM
# 		  NA_OIII_5007_COMB_W80
# 		  NA_OIII_5007_COMB_DISP
# 		  NA_OIII_5007_COMB_VOFF
# 		  NA_UNK_1_NPIX
# 		  NA_H_BETA_NPIX
# 		  NA_H_BETA_2_NPIX
# 		  NA_H_BETA_3_NPIX
# 		  NA_OIII_4960_NPIX
# 		  NA_OIII_4960_2_NPIX
# 		  NA_OIII_4960_3_NPIX
# 		  NA_OIII_5007_NPIX
# 		  NA_OIII_5007_2_NPIX
# 		  NA_OIII_5007_3_NPIX
# 		  NA_H_BETA_COMB_NPIX
# 		  NA_OIII_4960_COMB_NPIX
# 		  NA_OIII_5007_COMB_NPIX
# 		  NA_UNK_1_SNR
# 		  NA_H_BETA_SNR
# 		  NA_H_BETA_2_SNR
# 		  NA_H_BETA_3_SNR
# 		  NA_OIII_4960_SNR
# 		  NA_OIII_4960_2_SNR
# 		  NA_OIII_4960_3_SNR
# 		  NA_OIII_5007_SNR
# 		  NA_OIII_5007_2_SNR
# 		  NA_OIII_5007_3_SNR
# 		  NA_H_BETA_COMB_SNR
# 		  NA_OIII_4960_COMB_SNR
# 		  NA_OIII_5007_COMB_SNR
# 		  R_SQUARED
# 		  RCHI_SQUARED
#
#  > Saving Data...
#
#  Cleaning up...
# ----------------------------------------------------------------------------------------------------
#
#  Total Runtime = 2:41:04
#  - Done fitting spec-1701-53142-0483!
#
# End process memory: 0.75667456
