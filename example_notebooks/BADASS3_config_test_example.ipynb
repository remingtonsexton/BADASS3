# %% [markdown]
# ## Bayesian AGN Decomposition Analysis for SDSS Spectra (BADASS)
# ### Single Spectrum Configuration Test Example
#
# This notebook shows how to perform configuration testing.  Configuration testing is different from line testing.  Line testing performs tests on individual lines, whereas configurations can be multiple different lines simultaenously.  As a result, configuration testing requires the user to explicitly define which lines to test and the order to test them in.  BADASS will *not* discriminate between simple and complex models, but instead performs the fits in the order the user supplies them, and then will choose the best one.  It is up to the user to order the configurations in increasing complexity if the user wishes to test in such a way similar to the line test.
#
# In this example, we showcase how the configuration test is best utilized, and where the line test would fail.  Here we determine the best configuration to fit to the superposition of broad and narrow lines for the H$\alpha$/[NII] region.  The line test would fail in this regard because the line test cannot test broad and narrow lines simultaenously.
#
#
# ####  Remington O. Sexton$^{1}$, Sara M. Doan$^{2}$, William Matzko$^{2}$ Michael A. Reefe$^{2}$,
# $^{1}$United States Naval Observatory, $^{2}$George Mason University

# %%
import glob
import time
import natsort
from IPython.display import clear_output
import os
import sys
import psutil
import pathlib
import natsort
# Import BADASS here
BADASS_DIR = pathlib.Path(os.getcwd()).resolve().parent
sys.path.insert(1,str(BADASS_DIR))
import badass as badass
import badass_check_input
import badass_config_options

from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ### BADASS Options

# %%
options_file = "badass_config_options.py"

if os.path.exists(options_file):
    print("\n Options file %s found.\n" % (options_file))
# Out:
#  Options file badass_config_options.py found.

# %% [markdown]
# ### Run BADASS on a single spectrum
#
# The following is shows how to fit single SDSS spectra.

# %% [markdown]
# #### Directory Structure

# %%
nobj = 2 # Object in the spec_dir list
########################## Directory Structure #################################
spec_dir = '../example_spectra/' # folder with spectra in it
# Get full list of spectrum folders; these will be the working directories
spec_loc = natsort.natsorted( glob.glob(spec_dir+'*') )[nobj]

################################################################################
print(len(spec_loc))
print(spec_loc)
# Out:
# 25
# ../example_spectra/2-test

# %% [markdown]
# #### Choose Spectrum

# %%
file = glob.glob(spec_loc+'/*.fits')[0] # Get name of FITS spectra file
print(file)
# Out:
# ../example_spectra/2-test/spec-2756-54508-0579.fits

# %% [markdown]
# #### Run IRSA Dust Query
# To correct for Galactic extinction.  This only needs to be done once so that the data is stored locally.

# %%
badass_check_input.fetch_IRSA_dust(spec_loc)
# Out:
#  Fetching IRSA Dust for spectra...
#
#  Done fetching IRSA dust!

# %% [markdown]
# #### Run

# %%
import numpy as np
import importlib
importlib.reload(badass)
importlib.reload(badass_config_options)
if 1:
# for i in range(1):
#     np.random.seed()
#     print("\n---------------------------------------------------------")
#     print(" Begin Test %d of %d" % (i+1,10))
#     print("---------------------------------------------------------")
    
    # Call the main function in BADASS
    badass.run_BADASS(pathlib.Path(file), 
                      options_file = options_file,
                     )
        #
# Out:
# Start process memory: 0.26570342
#  Storing MCMC_output in ../example_spectra/2-test/MCMC_output_3/
#
#  > Starting fit for 2-test
#
#  Input fitting region exceeds available wavelength range.  BADASS will adjust your fitting range automatically...
# 		- Input fitting range: (4400, 5500)
# 		- Available wavelength range: (2218, 5354)
# 		- New fitting region is (4400, 5355).
#
#
#
# -----------------------------------------------------------
#  file:                        spec-2756-54508-0579.fits
#  SDSS redshift:               0.71967
#  fitting region:              (4400,5355) [A]
#  velocity scale:              69.15 [km/s/pixel]
#  Galactic E(B-V):             0.032
#  Flux Normalization:          1.0e-17
# -----------------------------------------------------------
# 	- Adding parameter for unexplained variance for reduced Chi-squared.
# 	- Fitting a SSP host-galaxy template.
# 	- Fitting additive legendre polynomial component.
# 	- Fitting Simple AGN power-law continuum.
#
#  - ('BR_MGII_2799_DISP', 'NA_MGII_2799_DISP') soft constraint removed because one or more free parameters is not available.
#
#  - ('OUT_NII_6585_DISP', 'NA_NII_6585_DISP') soft constraint removed because one or more free parameters is not available.
#
#  Performing configuration testing for 5 configurations...
# ----------------------------------------------------------------------------------------------------
#
#  Performing test of configuration 1 versus configuration 2...
#
# 	 Fitting CONFIG 1
# -------------------------------------------------------
#
#
# NOISE_SCALE
# 	 init = 1.0
# 	 plim = (0.0001, 100.0)
# 	 prior = {'type': 'jeffreys'}
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_3
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 29.131762146250143
# 	 plim = (0, 609.5398772334967)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 126.06889615498525
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 395.25313466585817
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = NA_OIII_5007_DISP
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
#
#
#
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# basinhopping step 0: f 10695.5
# basinhopping step 1: f -564.622 trial_f -564.622 accepted 1  lowest_f -564.622
# found new global minimum on step 1 with function value -564.622
# basinhopping step 2: f -564.622 trial_f -150.065 accepted 0  lowest_f -564.622
# basinhopping step 3: f -564.542 trial_f -564.542 accepted 1  lowest_f -564.622
# basinhopping step 4: f -564.542 trial_f 4495.75 accepted 0  lowest_f -564.622
# basinhopping step 5: f -564.542 trial_f -562.211 accepted 0  lowest_f -564.622
# basinhopping step 6: f -564.376 trial_f -564.376 accepted 1  lowest_f -564.622
# basinhopping step 7: f -564.376 trial_f -560.578 accepted 0  lowest_f -564.622
# basinhopping step 8: f -564.376 trial_f -411.993 accepted 0  lowest_f -564.622
# basinhopping step 9: f -564.376 trial_f -563.407 accepted 0  lowest_f -564.622
# basinhopping step 10: f -563.085 trial_f -563.085 accepted 1  lowest_f -564.622
# basinhopping step 11: f -563.085 trial_f -527.76 accepted 0  lowest_f -564.622
# basinhopping step 12: f -563.085 trial_f 7552.96 accepted 0  lowest_f -564.622
# basinhopping step 13: f -563.085 trial_f 1303.59 accepted 0  lowest_f -564.622
# basinhopping step 14: f -563.828 trial_f -563.828 accepted 1  lowest_f -564.622
# basinhopping step 15: f -562.791 trial_f -562.791 accepted 1  lowest_f -564.622
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -562.791 trial_f inf accepted 0  lowest_f -564.622
# basinhopping step 17: f -563.442 trial_f -563.442 accepted 1  lowest_f -564.622
# basinhopping step 18: f -563.442 trial_f -561.539 accepted 0  lowest_f -564.622
# basinhopping step 19: f -563.442 trial_f -561.457 accepted 0  lowest_f -564.622
# basinhopping step 20: f -564.575 trial_f -564.575 accepted 1  lowest_f -564.622
# basinhopping step 21: f -563.965 trial_f -563.965 accepted 1  lowest_f -564.622
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -563.965 trial_f inf accepted 0  lowest_f -564.622
# basinhopping step 23: f -563.965 trial_f -274.887 accepted 0  lowest_f -564.622
# basinhopping step 24: f -563.965 trial_f -555.262 accepted 0  lowest_f -564.622
# basinhopping step 25: f -563.965 trial_f -562.616 accepted 0  lowest_f -564.622
# basinhopping step 26: f -563.965 trial_f -561.827 accepted 0  lowest_f -564.622
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -563.965 trial_f inf accepted 0  lowest_f -564.622
#
#
#  R-Squared = 0.9850
#
#
#  reduced Chi-Squared = 20.0765
#
#
#  Root Mean Squared Error = 0.1476
#
#
#  Mean Absolute Error = 0.0951
#
#
# -------------------------------------------------------
# 	 Fitting CONFIG 2
# -------------------------------------------------------
# NOISE_SCALE
# 	 init = 1.0
# 	 plim = (0.0001, 100.0)
# 	 prior = {'type': 'jeffreys'}
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_3
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 29.131762146250143
# 	 plim = (0, 609.5398772334967)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 126.06889615498525
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 395.25313466585817
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# BR_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# BR_H_BETA_AMP
# 	 init = 126.06889615498525
# 	 plim = (0.0, 812.7198363113289)
# BR_H_BETA_DISP
# 	 init = 500.0
# 	 plim = (300, 3000)
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = NA_OIII_5007_DISP
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
# BR_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = br
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
#
#
#
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# warning: basinhopping: local minimization failure
# basinhopping step 0: f -857.905
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0682
#  Current RMSE: 0.0682
#  Accepted count: 1
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -857.905 trial_f inf accepted 0  lowest_f -857.905
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0682
#  Current RMSE: 0.0942
#  Accepted count: 1
#  Basinhop count: 1
#
#
# basinhopping step 2: f -857.905 trial_f -593.415 accepted 0  lowest_f -857.905
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0682
#  Current RMSE: 0.0700
#  Accepted count: 1
#  Basinhop count: 2
#
#
# basinhopping step 3: f -857.905 trial_f -411.847 accepted 0  lowest_f -857.905
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0682
#  Current RMSE: 0.0695
#  Accepted count: 1
#  Basinhop count: 3
#
#
# basinhopping step 4: f -957.755 trial_f -957.755 accepted 1  lowest_f -957.755
# found new global minimum on step 4 with function value -957.755
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.0678
#  Accepted count: 2
#  Basinhop count: 0
#
#
# basinhopping step 5: f -957.755 trial_f -458.931 accepted 0  lowest_f -957.755
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.0735
#  Accepted count: 2
#  Basinhop count: 1
#
#
# basinhopping step 6: f -1312.7 trial_f -1312.7 accepted 1  lowest_f -1312.7
# found new global minimum on step 6 with function value -1312.7
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.0681
#  Accepted count: 3
#  Basinhop count: 0
#
#
# basinhopping step 7: f -1312.7 trial_f -531.667 accepted 0  lowest_f -1312.7
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.0775
#  Accepted count: 3
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -1312.7 trial_f inf accepted 0  lowest_f -1312.7
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.2016
#  Accepted count: 3
#  Basinhop count: 2
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -1312.7 trial_f inf accepted 0  lowest_f -1312.7
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.1145
#  Accepted count: 3
#  Basinhop count: 3
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -1312.7 trial_f inf accepted 0  lowest_f -1312.7
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.2211
#  Accepted count: 3
#  Basinhop count: 4
#
#
# basinhopping step 11: f -1312.7 trial_f -1296.48 accepted 0  lowest_f -1312.7
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.0710
#  Accepted count: 3
#  Basinhop count: 5
#
#
# basinhopping step 12: f -1313.3 trial_f -1313.3 accepted 1  lowest_f -1313.3
# found new global minimum on step 12 with function value -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.0702
#  Accepted count: 4
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.1054
#  Accepted count: 4
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.0854
#  Accepted count: 4
#  Basinhop count: 2
#
#
# basinhopping step 15: f -1313.3 trial_f -530.383 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.0686
#  Accepted count: 4
#  Basinhop count: 3
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.1225
#  Accepted count: 4
#  Basinhop count: 4
#
#
# basinhopping step 17: f -1313.3 trial_f -210.444 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0678
#  Current RMSE: 0.0688
#  Accepted count: 4
#  Basinhop count: 5
#
#
# basinhopping step 18: f -1313.3 trial_f -751.075 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.0674
#  Accepted count: 4
#  Basinhop count: 6
#
#
# basinhopping step 19: f -1313.3 trial_f -1308.27 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.0681
#  Accepted count: 4
#  Basinhop count: 7
#
#
# basinhopping step 20: f -1313.3 trial_f -1288.52 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.0741
#  Accepted count: 4
#  Basinhop count: 8
#
#
# basinhopping step 21: f -1313.3 trial_f -1028.54 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.0710
#  Accepted count: 4
#  Basinhop count: 9
#
#
# basinhopping step 22: f -1313.3 trial_f -453.835 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.0678
#  Accepted count: 4
#  Basinhop count: 10
#
#
# basinhopping step 23: f -1313.3 trial_f -1273.05 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.0715
#  Accepted count: 4
#  Basinhop count: 11
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.1762
#  Accepted count: 4
#  Basinhop count: 12
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.1185
#  Accepted count: 4
#  Basinhop count: 13
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.1993
#  Accepted count: 4
#  Basinhop count: 14
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0674
#  Current RMSE: 0.0997
#  Accepted count: 4
#  Basinhop count: 15
#
#
# basinhopping step 28: f -1313.3 trial_f -1282.79 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0672
#  Accepted count: 4
#  Basinhop count: 16
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 29: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.1240
#  Accepted count: 4
#  Basinhop count: 17
#
#
# basinhopping step 30: f -1313.3 trial_f -1009.11 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0684
#  Accepted count: 4
#  Basinhop count: 18
#
#
# basinhopping step 31: f -1313.3 trial_f -624.433 accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0680
#  Accepted count: 4
#  Basinhop count: 19
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 32: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.1418
#  Accepted count: 4
#  Basinhop count: 20
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 33: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.1117
#  Accepted count: 4
#  Basinhop count: 21
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 34: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0957
#  Accepted count: 4
#  Basinhop count: 22
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 35: f -1313.3 trial_f inf accepted 0  lowest_f -1313.3
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.1289
#  Accepted count: 4
#  Basinhop count: 23
#
#
# basinhopping step 36: f -1314.29 trial_f -1314.29 accepted 1  lowest_f -1314.29
# found new global minimum on step 36 with function value -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0679
#  Accepted count: 5
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 37: f -1314.29 trial_f -1152.94 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0686
#  Accepted count: 5
#  Basinhop count: 1
#
#
# basinhopping step 38: f -1314.29 trial_f -981.814 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0705
#  Accepted count: 5
#  Basinhop count: 2
#
#
# basinhopping step 39: f -1314.29 trial_f -231.613 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0734
#  Accepted count: 5
#  Basinhop count: 3
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 40: f -1314.29 trial_f inf accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0928
#  Accepted count: 5
#  Basinhop count: 4
#
#
# basinhopping step 41: f -1314.29 trial_f -1303.72 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0689
#  Accepted count: 5
#  Basinhop count: 5
#
#
# basinhopping step 42: f -1314.29 trial_f -620.141 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0679
#  Accepted count: 5
#  Basinhop count: 6
#
#
# basinhopping step 43: f -1314.29 trial_f -875.673 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0672
#  Accepted count: 5
#  Basinhop count: 7
#
#
# basinhopping step 44: f -1314.29 trial_f -1251.1 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0673
#  Accepted count: 5
#  Basinhop count: 8
#
#
# basinhopping step 45: f -1314.29 trial_f -1041.98 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0702
#  Accepted count: 5
#  Basinhop count: 9
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 46: f -1314.29 trial_f -1300.55 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0687
#  Accepted count: 5
#  Basinhop count: 10
#
#
# basinhopping step 47: f -1314.29 trial_f -232.113 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0728
#  Accepted count: 5
#  Basinhop count: 11
#
#
# basinhopping step 48: f -1314.29 trial_f -1298.94 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0679
#  Accepted count: 5
#  Basinhop count: 12
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 49: f -1314.29 trial_f inf accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0883
#  Accepted count: 5
#  Basinhop count: 13
#
#
# adaptive stepsize: acceptance rate 0.080000 target 0.500000 new stepsize 9 old stepsize 10
# basinhopping step 50: f -1314.29 trial_f -1310.03 accepted 0  lowest_f -1314.29
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0672
#  Current RMSE: 0.0681
#  Accepted count: 5
#  Basinhop count: 14
#
#
# basinhopping step 51: f -1317.33 trial_f -1317.33 accepted 1  lowest_f -1317.33
# found new global minimum on step 51 with function value -1317.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 6
#  Basinhop count: 0
#
#
# basinhopping step 52: f -1317.33 trial_f -1316.28 accepted 0  lowest_f -1317.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0658
#  Current RMSE: 0.0658
#  Accepted count: 6
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 53: f -1317.33 trial_f inf accepted 0  lowest_f -1317.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0658
#  Current RMSE: 0.0727
#  Accepted count: 6
#  Basinhop count: 2
#
#
# basinhopping step 54: f -1317.33 trial_f -1070.06 accepted 0  lowest_f -1317.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0658
#  Current RMSE: 0.0679
#  Accepted count: 6
#  Basinhop count: 3
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 55: f -1317.33 trial_f inf accepted 0  lowest_f -1317.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0658
#  Current RMSE: 0.0745
#  Accepted count: 6
#  Basinhop count: 4
#
#
# basinhopping step 56: f -1317.33 trial_f -1017.76 accepted 0  lowest_f -1317.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0655
#  Accepted count: 6
#  Basinhop count: 5
#
#
# basinhopping step 57: f -1317.33 trial_f 99.9563 accepted 0  lowest_f -1317.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0710
#  Accepted count: 6
#  Basinhop count: 6
#
#
# basinhopping step 58: f -1317.33 trial_f -1268.78 accepted 0  lowest_f -1317.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0701
#  Accepted count: 6
#  Basinhop count: 7
#
#
# basinhopping step 59: f -1321.33 trial_f -1321.33 accepted 1  lowest_f -1321.33
# found new global minimum on step 59 with function value -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0675
#  Accepted count: 7
#  Basinhop count: 0
#
#
# basinhopping step 60: f -1321.33 trial_f -1307.1 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0680
#  Accepted count: 7
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 61: f -1321.33 trial_f -1245.57 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0656
#  Accepted count: 7
#  Basinhop count: 2
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 62: f -1321.33 trial_f inf accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.1860
#  Accepted count: 7
#  Basinhop count: 3
#
#
# basinhopping step 63: f -1320.72 trial_f -1320.72 accepted 1  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0676
#  Accepted count: 8
#  Basinhop count: 4
#
#
# basinhopping step 64: f -1320.72 trial_f -1309.29 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0677
#  Accepted count: 8
#  Basinhop count: 5
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 65: f -1320.72 trial_f inf accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.1235
#  Accepted count: 8
#  Basinhop count: 6
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 66: f -1320.72 trial_f inf accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0968
#  Accepted count: 8
#  Basinhop count: 7
#
#
# basinhopping step 67: f -1320.72 trial_f -1311.26 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0696
#  Accepted count: 8
#  Basinhop count: 8
#
#
# basinhopping step 68: f -1320.72 trial_f -1280.4 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0685
#  Accepted count: 8
#  Basinhop count: 9
#
#
# basinhopping step 69: f -1320.72 trial_f -685.286 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0682
#  Accepted count: 8
#  Basinhop count: 10
#
#
# basinhopping step 70: f -1320.72 trial_f -1220.99 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0673
#  Accepted count: 8
#  Basinhop count: 11
#
#
# basinhopping step 71: f -1320.72 trial_f -1251.74 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0714
#  Accepted count: 8
#  Basinhop count: 12
#
#
# basinhopping step 72: f -1320.72 trial_f -944.516 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0694
#  Accepted count: 8
#  Basinhop count: 13
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 73: f -1320.72 trial_f inf accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0770
#  Accepted count: 8
#  Basinhop count: 14
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 74: f -1320.72 trial_f inf accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.1050
#  Accepted count: 8
#  Basinhop count: 15
#
#
# basinhopping step 75: f -1320.72 trial_f -1308.6 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0683
#  Accepted count: 8
#  Basinhop count: 16
#
#
# basinhopping step 76: f -1320.72 trial_f -177.239 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0719
#  Accepted count: 8
#  Basinhop count: 17
#
#
# basinhopping step 77: f -1320.72 trial_f -1213.58 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0704
#  Accepted count: 8
#  Basinhop count: 18
#
#
# basinhopping step 78: f -1320.72 trial_f -1275.35 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0723
#  Accepted count: 8
#  Basinhop count: 19
#
#
# basinhopping step 79: f -1320.72 trial_f -1101.06 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0673
#  Accepted count: 8
#  Basinhop count: 20
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 80: f -1320.72 trial_f inf accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.3031
#  Accepted count: 8
#  Basinhop count: 21
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 81: f -1320.72 trial_f inf accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.1956
#  Accepted count: 8
#  Basinhop count: 22
#
#
# basinhopping step 82: f -1320.72 trial_f -1312.89 accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0660
#  Accepted count: 8
#  Basinhop count: 23
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 83: f -1320.72 trial_f inf accepted 0  lowest_f -1321.33
#  Fit Status: False
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0971
#  Accepted count: 8
#  Basinhop count: 24
#
#
# basinhopping step 84: f -1320.72 trial_f -1314.38 accepted 0  lowest_f -1321.33
#  Fit Status: True
#  Force threshold: 0.1476
#  Lowest RMSE: 0.0655
#  Current RMSE: 0.0676
#  Accepted count: 8
#  Basinhop count: 25
#
#
#
#
#  R-Squared = 0.9969
#
#
#  reduced Chi-Squared = 3.3636
#
#
#  Root Mean Squared Error = 0.0676
#
#
#  Mean Absolute Error = 0.0426
#
#
# -------------------------------------------------------
#
#  Performing test of configuration 2 versus configuration 3...
#
# 	 Fitting CONFIG 3
# -------------------------------------------------------
# NOISE_SCALE
# 	 init = 1.0
# 	 plim = (0.0001, 100.0)
# 	 prior = {'type': 'jeffreys'}
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_3
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 29.131762146250143
# 	 plim = (0, 609.5398772334967)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 63.03444807749263
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 197.62656733292908
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# NA_OIII_5007_2_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_2_AMP
# 	 init = 197.62656733292908
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_2_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# BR_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# BR_H_BETA_AMP
# 	 init = 126.06889615498525
# 	 plim = (0.0, 812.7198363113289)
# BR_H_BETA_DISP
# 	 init = 500.0
# 	 plim = (300, 3000)
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = NA_OIII_5007_DISP
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
# NA_H_BETA_2
# 	 center = 4862.691
# 	 amp = NA_H_BETA_AMP*(NA_OIII_5007_2_AMP/NA_OIII_5007_AMP)
# 	 disp = NA_OIII_5007_2_DISP
# 	 voff = NA_OIII_5007_2_VOFF
# 	 line_type = na
# 	 ncomp = 2
# 	 parent = NA_H_BETA
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960_2
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_2_AMP/2.98)
# 	 disp = NA_OIII_5007_2_DISP
# 	 voff = NA_OIII_5007_2_VOFF
# 	 line_type = na
# 	 ncomp = 2
# 	 parent = NA_OIII_4960
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007_2
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 ncomp = 2
# 	 parent = NA_OIII_5007
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
# BR_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = br
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
#
#
# NA_H_BETA_COMB
# 	 lines = ['NA_H_BETA', 'NA_H_BETA_2']
# 	 center = 4862.691
# 	 center_pix = 435.21099039301293
# 	 disp_res_kms = 44.80172932021387
# 	 line_profile = gaussian
# NA_OIII_4960_COMB
# 	 lines = ['NA_OIII_4960', 'NA_OIII_4960_2']
# 	 center = 4960.295
# 	 center_pix = 521.5197602739727
# 	 disp_res_kms = 44.41780368529158
# 	 line_profile = gaussian
# NA_OIII_5007_COMB
# 	 lines = ['NA_OIII_5007', 'NA_OIII_5007_2']
# 	 center = 5008.24
# 	 center_pix = 563.2959830508472
# 	 disp_res_kms = 44.341436837197556
# 	 line_profile = gaussian
#
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# warning: basinhopping: local minimization failure
# basinhopping step 0: f -1239.97
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0514
#  Accepted count: 1
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -1239.97 trial_f inf accepted 0  lowest_f -1239.97
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.1013
#  Accepted count: 1
#  Basinhop count: 1
#
#
# basinhopping step 2: f -1428.31 trial_f -1428.31 accepted 1  lowest_f -1428.31
# found new global minimum on step 2 with function value -1428.31
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0522
#  Accepted count: 2
#  Basinhop count: 0
#
#
# basinhopping step 3: f -1428.31 trial_f -453.114 accepted 0  lowest_f -1428.31
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0531
#  Accepted count: 2
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -1428.31 trial_f inf accepted 0  lowest_f -1428.31
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0988
#  Accepted count: 2
#  Basinhop count: 2
#
#
# basinhopping step 5: f -1428.31 trial_f -1307.85 accepted 0  lowest_f -1428.31
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0516
#  Accepted count: 2
#  Basinhop count: 3
#
#
# basinhopping step 6: f -1428.31 trial_f -1251.01 accepted 0  lowest_f -1428.31
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0529
#  Accepted count: 2
#  Basinhop count: 4
#
#
# basinhopping step 7: f -1442.4 trial_f -1442.4 accepted 1  lowest_f -1442.4
# found new global minimum on step 7 with function value -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0516
#  Accepted count: 3
#  Basinhop count: 0
#
#
# basinhopping step 8: f -1442.4 trial_f -1398.15 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0515
#  Accepted count: 3
#  Basinhop count: 1
#
#
# basinhopping step 9: f -1442.4 trial_f -1242.61 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0530
#  Accepted count: 3
#  Basinhop count: 2
#
#
# basinhopping step 10: f -1442.4 trial_f -1351.77 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0521
#  Accepted count: 3
#  Basinhop count: 3
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.2045
#  Accepted count: 3
#  Basinhop count: 4
#
#
# basinhopping step 12: f -1442.4 trial_f -835.247 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0561
#  Accepted count: 3
#  Basinhop count: 5
#
#
# basinhopping step 13: f -1442.4 trial_f -1441.83 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0516
#  Accepted count: 3
#  Basinhop count: 6
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.1023
#  Accepted count: 3
#  Basinhop count: 7
#
#
# basinhopping step 15: f -1442.4 trial_f -1400.39 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0528
#  Accepted count: 3
#  Basinhop count: 8
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.1375
#  Accepted count: 3
#  Basinhop count: 9
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.2139
#  Accepted count: 3
#  Basinhop count: 10
#
#
# basinhopping step 18: f -1442.4 trial_f -1441.82 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0522
#  Accepted count: 3
#  Basinhop count: 11
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.1104
#  Accepted count: 3
#  Basinhop count: 12
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.1314
#  Accepted count: 3
#  Basinhop count: 13
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.1239
#  Accepted count: 3
#  Basinhop count: 14
#
#
# basinhopping step 22: f -1442.4 trial_f -1321.8 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.0514
#  Accepted count: 3
#  Basinhop count: 15
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0514
#  Current RMSE: 0.2423
#  Accepted count: 3
#  Basinhop count: 16
#
#
# basinhopping step 24: f -1442.4 trial_f -733.428 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0508
#  Accepted count: 3
#  Basinhop count: 17
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0675
#  Accepted count: 3
#  Basinhop count: 18
#
#
# basinhopping step 26: f -1442.4 trial_f -1128.73 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0526
#  Accepted count: 3
#  Basinhop count: 19
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.1022
#  Accepted count: 3
#  Basinhop count: 20
#
#
# basinhopping step 28: f -1442.4 trial_f -427.07 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0547
#  Accepted count: 3
#  Basinhop count: 21
#
#
# basinhopping step 29: f -1442.4 trial_f -791.779 accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0586
#  Accepted count: 3
#  Basinhop count: 22
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 30: f -1442.4 trial_f inf accepted 0  lowest_f -1442.4
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.1059
#  Accepted count: 3
#  Basinhop count: 23
#
#
# basinhopping step 31: f -1445.56 trial_f -1445.56 accepted 1  lowest_f -1445.56
# found new global minimum on step 31 with function value -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0514
#  Accepted count: 4
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 32: f -1445.56 trial_f inf accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.2265
#  Accepted count: 4
#  Basinhop count: 1
#
#
# basinhopping step 33: f -1445.56 trial_f -1132.24 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0530
#  Accepted count: 4
#  Basinhop count: 2
#
#
# basinhopping step 34: f -1445.56 trial_f -823.418 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0510
#  Accepted count: 4
#  Basinhop count: 3
#
#
# basinhopping step 35: f -1445.56 trial_f -1220.36 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0510
#  Accepted count: 4
#  Basinhop count: 4
#
#
# basinhopping step 36: f -1445.56 trial_f -1281.11 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0513
#  Accepted count: 4
#  Basinhop count: 5
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 37: f -1445.56 trial_f inf accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.1395
#  Accepted count: 4
#  Basinhop count: 6
#
#
# basinhopping step 38: f -1445.56 trial_f -1431.46 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0512
#  Accepted count: 4
#  Basinhop count: 7
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 39: f -1445.56 trial_f inf accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.3804
#  Accepted count: 4
#  Basinhop count: 8
#
#
# basinhopping step 40: f -1445.56 trial_f -520.53 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0535
#  Accepted count: 4
#  Basinhop count: 9
#
#
# basinhopping step 41: f -1445.56 trial_f -1419.85 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0512
#  Accepted count: 4
#  Basinhop count: 10
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 42: f -1445.56 trial_f inf accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.2568
#  Accepted count: 4
#  Basinhop count: 11
#
#
# basinhopping step 43: f -1445.56 trial_f -1391.78 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0515
#  Accepted count: 4
#  Basinhop count: 12
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 44: f -1445.56 trial_f inf accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0748
#  Accepted count: 4
#  Basinhop count: 13
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 45: f -1445.56 trial_f inf accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.2456
#  Accepted count: 4
#  Basinhop count: 14
#
#
# basinhopping step 46: f -1445.56 trial_f -696.232 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0521
#  Accepted count: 4
#  Basinhop count: 15
#
#
# basinhopping step 47: f -1445.56 trial_f -1432.63 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0531
#  Accepted count: 4
#  Basinhop count: 16
#
#
# basinhopping step 48: f -1445.56 trial_f -1433.09 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.0516
#  Accepted count: 4
#  Basinhop count: 17
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 49: f -1445.56 trial_f inf accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0508
#  Current RMSE: 0.1286
#  Accepted count: 4
#  Basinhop count: 18
#
#
# adaptive stepsize: acceptance rate 0.060000 target 0.500000 new stepsize 9 old stepsize 10
# basinhopping step 50: f -1445.56 trial_f -772.068 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.0507
#  Accepted count: 4
#  Basinhop count: 19
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 51: f -1445.56 trial_f inf accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.1083
#  Accepted count: 4
#  Basinhop count: 20
#
#
# basinhopping step 52: f -1445.56 trial_f -1272.18 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.0519
#  Accepted count: 4
#  Basinhop count: 21
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 53: f -1445.56 trial_f 1.84693e+06 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.0788
#  Accepted count: 4
#  Basinhop count: 22
#
#
# basinhopping step 54: f -1445.56 trial_f -1443.31 accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.0515
#  Accepted count: 4
#  Basinhop count: 23
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 55: f -1445.56 trial_f inf accepted 0  lowest_f -1445.56
#  Fit Status: False
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.2583
#  Accepted count: 4
#  Basinhop count: 24
#
#
# basinhopping step 56: f -1445.56 trial_f -636.465 accepted 0  lowest_f -1445.56
#  Fit Status: True
#  Force threshold: 0.0676
#  Lowest RMSE: 0.0507
#  Current RMSE: 0.0537
#  Accepted count: 4
#  Basinhop count: 25
#
#
#
#
#  R-Squared = 0.9982
#
#
#  reduced Chi-Squared = 2.4880
#
#
#  Root Mean Squared Error = 0.0514
#
#
#  Mean Absolute Error = 0.0366
#
#
# -------------------------------------------------------
#
#  Performing test of configuration 3 versus configuration 4...
#
# 	 Fitting CONFIG 4
# -------------------------------------------------------
# NOISE_SCALE
# 	 init = 1.0
# 	 plim = (0.0001, 100.0)
# 	 prior = {'type': 'jeffreys'}
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_3
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 29.131762146250143
# 	 plim = (0, 609.5398772334967)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 42.02296538499508
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 131.7510448886194
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# NA_OIII_5007_2_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_2_AMP
# 	 init = 131.7510448886194
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_2_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# NA_OIII_5007_3_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_3_AMP
# 	 init = 131.7510448886194
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_3_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# BR_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# BR_H_BETA_AMP
# 	 init = 126.06889615498525
# 	 plim = (0.0, 812.7198363113289)
# BR_H_BETA_DISP
# 	 init = 500.0
# 	 plim = (300, 3000)
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = NA_OIII_5007_DISP
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
# NA_H_BETA_2
# 	 center = 4862.691
# 	 amp = NA_H_BETA_AMP*(NA_OIII_5007_2_AMP/NA_OIII_5007_AMP)
# 	 disp = NA_OIII_5007_2_DISP
# 	 voff = NA_OIII_5007_2_VOFF
# 	 line_type = na
# 	 ncomp = 2
# 	 parent = NA_H_BETA
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# ...
#  Lowest RMSE: 0.0680
#  Current RMSE: 0.2594
#  Accepted count: 2
#  Basinhop count: 2
#
#
# basinhopping step 7: f -1294.55 trial_f -1111.68 accepted 0  lowest_f -1294.55
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0680
#  Current RMSE: 0.0682
#  Accepted count: 2
#  Basinhop count: 3
#
#
# basinhopping step 8: f -1294.55 trial_f -1291.98 accepted 0  lowest_f -1294.55
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0633
#  Accepted count: 2
#  Basinhop count: 4
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -1294.55 trial_f inf accepted 0  lowest_f -1294.55
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0947
#  Accepted count: 2
#  Basinhop count: 5
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -1294.55 trial_f inf accepted 0  lowest_f -1294.55
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0942
#  Accepted count: 2
#  Basinhop count: 6
#
#
# basinhopping step 11: f -1294.55 trial_f -664.246 accepted 0  lowest_f -1294.55
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0766
#  Accepted count: 2
#  Basinhop count: 7
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -1294.55 trial_f inf accepted 0  lowest_f -1294.55
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0852
#  Accepted count: 2
#  Basinhop count: 8
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -1294.55 trial_f inf accepted 0  lowest_f -1294.55
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0917
#  Accepted count: 2
#  Basinhop count: 9
#
#
# basinhopping step 14: f -1295.72 trial_f -1295.72 accepted 1  lowest_f -1295.72
# found new global minimum on step 14 with function value -1295.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0669
#  Accepted count: 3
#  Basinhop count: 0
#
#
# basinhopping step 15: f -1295.72 trial_f -1260.38 accepted 0  lowest_f -1295.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0681
#  Accepted count: 3
#  Basinhop count: 1
#
#
# basinhopping step 16: f -1301.81 trial_f -1301.81 accepted 1  lowest_f -1301.81
# found new global minimum on step 16 with function value -1301.81
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0677
#  Accepted count: 4
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -1301.81 trial_f inf accepted 0  lowest_f -1301.81
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.1165
#  Accepted count: 4
#  Basinhop count: 1
#
#
# basinhopping step 18: f -1312.35 trial_f -1312.35 accepted 1  lowest_f -1312.35
# found new global minimum on step 18 with function value -1312.35
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0633
#  Current RMSE: 0.0649
#  Accepted count: 5
#  Basinhop count: 0
#
#
# basinhopping step 19: f -1317.28 trial_f -1317.28 accepted 1  lowest_f -1317.28
# found new global minimum on step 19 with function value -1317.28
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0625
#  Current RMSE: 0.0625
#  Accepted count: 6
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -1317.28 trial_f inf accepted 0  lowest_f -1317.28
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0625
#  Current RMSE: 0.1246
#  Accepted count: 6
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -1317.28 trial_f -1184.6 accepted 0  lowest_f -1317.28
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0506
#  Current RMSE: 0.0506
#  Accepted count: 6
#  Basinhop count: 2
#
#
# basinhopping step 22: f -1317.28 trial_f -1241.64 accepted 0  lowest_f -1317.28
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0506
#  Current RMSE: 0.0511
#  Accepted count: 6
#  Basinhop count: 3
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -1317.28 trial_f inf accepted 0  lowest_f -1317.28
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0506
#  Current RMSE: 0.3085
#  Accepted count: 6
#  Basinhop count: 4
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -1317.28 trial_f inf accepted 0  lowest_f -1317.28
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0506
#  Current RMSE: 0.1200
#  Accepted count: 6
#  Basinhop count: 5
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -1317.28 trial_f -662.512 accepted 0  lowest_f -1317.28
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0506
#  Current RMSE: 0.0604
#  Accepted count: 6
#  Basinhop count: 6
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -1317.28 trial_f -922.078 accepted 0  lowest_f -1317.28
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.0502
#  Accepted count: 6
#  Basinhop count: 7
#
#
# basinhopping step 27: f -1436.01 trial_f -1436.01 accepted 1  lowest_f -1436.01
# found new global minimum on step 27 with function value -1436.01
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.0509
#  Accepted count: 7
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 28: f -1436.01 trial_f inf accepted 0  lowest_f -1436.01
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.1404
#  Accepted count: 7
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 29: f -1436.01 trial_f inf accepted 0  lowest_f -1436.01
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.1054
#  Accepted count: 7
#  Basinhop count: 2
#
#
# basinhopping step 30: f -1448.49 trial_f -1448.49 accepted 1  lowest_f -1448.49
# found new global minimum on step 30 with function value -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.0507
#  Accepted count: 8
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 31: f -1448.49 trial_f -170.767 accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.1449
#  Accepted count: 8
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 32: f -1448.49 trial_f -206.147 accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.2072
#  Accepted count: 8
#  Basinhop count: 2
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 33: f -1448.49 trial_f -613.521 accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.0505
#  Accepted count: 8
#  Basinhop count: 3
#
#
# basinhopping step 34: f -1448.49 trial_f -589.113 accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.0506
#  Accepted count: 8
#  Basinhop count: 4
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 35: f -1448.49 trial_f inf accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.1483
#  Accepted count: 8
#  Basinhop count: 5
#
#
# basinhopping step 36: f -1448.49 trial_f -1057.16 accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.0645
#  Accepted count: 8
#  Basinhop count: 6
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 37: f -1448.49 trial_f inf accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.4101
#  Accepted count: 8
#  Basinhop count: 7
#
#
# basinhopping step 38: f -1448.49 trial_f -911.705 accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.0504
#  Accepted count: 8
#  Basinhop count: 8
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 39: f -1448.49 trial_f inf accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.2234
#  Accepted count: 8
#  Basinhop count: 9
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 40: f -1448.49 trial_f inf accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.2251
#  Accepted count: 8
#  Basinhop count: 10
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 41: f -1448.49 trial_f -312.96 accepted 0  lowest_f -1448.49
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0502
#  Current RMSE: 0.1159
#  Accepted count: 8
#  Basinhop count: 11
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 42: f -1478.72 trial_f -1478.72 accepted 1  lowest_f -1478.72
# found new global minimum on step 42 with function value -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0471
#  Current RMSE: 0.0471
#  Accepted count: 9
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 43: f -1478.72 trial_f inf accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0471
#  Current RMSE: 0.5373
#  Accepted count: 9
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 44: f -1478.72 trial_f -1433.09 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0470
#  Accepted count: 9
#  Basinhop count: 2
#
#
# basinhopping step 45: f -1478.72 trial_f -835.1 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0755
#  Accepted count: 9
#  Basinhop count: 3
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 46: f -1478.72 trial_f inf accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.3151
#  Accepted count: 9
#  Basinhop count: 4
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 47: f -1478.72 trial_f -434.288 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0488
#  Accepted count: 9
#  Basinhop count: 5
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 48: f -1478.72 trial_f inf accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.2254
#  Accepted count: 9
#  Basinhop count: 6
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 49: f -1478.72 trial_f -95.8782 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.1772
#  Accepted count: 9
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.160000 target 0.500000 new stepsize 9 old stepsize 10
# basinhopping step 50: f -1478.72 trial_f -283.474 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.1582
#  Accepted count: 9
#  Basinhop count: 8
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 51: f -1478.72 trial_f inf accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.2399
#  Accepted count: 9
#  Basinhop count: 9
#
#
# basinhopping step 52: f -1478.72 trial_f -1058.84 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0669
#  Accepted count: 9
#  Basinhop count: 10
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 53: f -1478.72 trial_f inf accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0845
#  Accepted count: 9
#  Basinhop count: 11
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 54: f -1478.72 trial_f inf accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.3439
#  Accepted count: 9
#  Basinhop count: 12
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 55: f -1478.72 trial_f inf accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.4049
#  Accepted count: 9
#  Basinhop count: 13
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 56: f -1478.72 trial_f -448.721 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0991
#  Accepted count: 9
#  Basinhop count: 14
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 57: f -1478.72 trial_f inf accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.3026
#  Accepted count: 9
#  Basinhop count: 15
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 58: f -1478.72 trial_f -567.748 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0883
#  Accepted count: 9
#  Basinhop count: 16
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 59: f -1478.72 trial_f -362.982 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.1152
#  Accepted count: 9
#  Basinhop count: 17
#
#
# basinhopping step 60: f -1478.72 trial_f -761.238 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0520
#  Accepted count: 9
#  Basinhop count: 18
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 61: f -1478.72 trial_f -978.967 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0714
#  Accepted count: 9
#  Basinhop count: 19
#
#
# basinhopping step 62: f -1478.72 trial_f -1035.4 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0713
#  Accepted count: 9
#  Basinhop count: 20
#
#
# basinhopping step 63: f -1478.72 trial_f -1157.7 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0481
#  Accepted count: 9
#  Basinhop count: 21
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 64: f -1478.72 trial_f inf accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.1588
#  Accepted count: 9
#  Basinhop count: 22
#
#
# basinhopping step 65: f -1478.72 trial_f -797.429 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0471
#  Accepted count: 9
#  Basinhop count: 23
#
#
# basinhopping step 66: f -1478.72 trial_f -1057.25 accepted 0  lowest_f -1478.72
#  Fit Status: False
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0651
#  Accepted count: 9
#  Basinhop count: 24
#
#
# basinhopping step 67: f -1478.72 trial_f -1002.53 accepted 0  lowest_f -1478.72
#  Fit Status: True
#  Force threshold: 0.0485
#  Lowest RMSE: 0.0470
#  Current RMSE: 0.0710
#  Accepted count: 9
#  Basinhop count: 25
#
#
#
#
#  R-Squared = 0.9985
#
#
#  reduced Chi-Squared = 2.2546
#
#
#  Root Mean Squared Error = 0.0471
#
#
#  Mean Absolute Error = 0.0344
#
#
# -------------------------------------------------------
# {'TEST': [1, 2, 3, 4], 'RANGE': [(4400.0, 5355.0), (4400.0, 5355.0), (4400.0, 5355.0), (4400.0, 5355.0)], 'CONFIG_A': [1, 2, 3, 4], 'CONFIG_B': [2, 3, 4, 5], 'ANOVA': [0.9999999999999999, 0.9999999999999999, 0.9999999999999999, 0.99999999990374], 'BADASS': [1.0, 1.0, 0.5579317320524853, 0.7269099206772436], 'CHI2_RATIO': [0.8277513346250107, 0.24716754338132174, 0.030772386788646466, 0.06189025364580747], 'F_RATIO': [2.1847086929437824, 1.314511595654, 1.0584951851663948, 1.0303393202465332], 'SSR_RATIO': [4.772912920773692, 1.7279118399084612, 1.1203832143463266, 1.0616446317006052], 'TARGET_RMSE': [0.06755002675884335, 0.05137169721331428, 0.04853987875192004, 0.04710888478966816]}
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
