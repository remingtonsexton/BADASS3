# %% [markdown]
# ## Bayesian AGN Decomposition Analysis for SDSS Spectra (BADASS)
# ### Single Spectrum Configuration Test Example
#
# This notebook shows how to perform configuration testing.  Configuration testing is different from line testing.  Line testing performs tests on individual lines, whereas configurations can be multiple different lines simultaenously.  As a result, configuration testing requires the user to explicitly define which lines to test and the order to test them in.  BADASS will *not* discriminate between simple and complex models, but instead performs the fits in the order the user supplies them, and then will choose the best one.  It is up to the user to order the configurations in increasing complexity if the user wishes to test in such a way similar to the line test.
#
# In this example, we showcase how the configuration test is best utilized, and where the line test would fail.  Here we determine the best configuration to fit to the superposition of broad and narrow lines for the H$\alpha$/[NII] region.  The line test would fail in this regard because the line test cannot test broad and narrow lines simultaenously.
#
#
# ####  Remington O. Sexton$^{1}$, Sara M. Doan$^{2}$, William Matzko$^{2}$ Michael A. Reefe$^{2}$,
# $^{1}$United States Naval Observatory, $^{2}$George Mason University

# %%
import glob
import time
import natsort
from IPython.display import clear_output
import os
import sys
import psutil
import pathlib
import natsort
# Import BADASS here
BADASS_DIR = pathlib.Path(os.getcwd()).resolve().parent
sys.path.insert(1,str(BADASS_DIR))
import badass as badass
import badass_check_input
import badass_config_options

from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ### BADASS Options

# %%
options_file = "badass_config_options.py"

if os.path.exists(options_file):
    print("\n Options file %s found.\n" % (options_file))
# Out:
#  Options file badass_config_options.py found.

# %% [markdown]
# ### Run BADASS on a single spectrum
#
# The following is shows how to fit single SDSS spectra.

# %% [markdown]
# #### Directory Structure

# %%
nobj = 2 # Object in the spec_dir list
########################## Directory Structure #################################
spec_dir = '../example_spectra/' # folder with spectra in it
# Get full list of spectrum folders; these will be the working directories
spec_loc = natsort.natsorted( glob.glob(spec_dir+'*') )[nobj]

################################################################################
print(len(spec_loc))
print(spec_loc)
# Out:
# 25
# ../example_spectra/2-test

# %% [markdown]
# #### Choose Spectrum

# %%
file = glob.glob(spec_loc+'/*.fits')[0] # Get name of FITS spectra file
print(file)
# Out:
# ../example_spectra/2-test/spec-2756-54508-0579.fits

# %% [markdown]
# #### Run IRSA Dust Query
# To correct for Galactic extinction.  This only needs to be done once so that the data is stored locally.

# %%
badass_check_input.fetch_IRSA_dust(spec_loc)
# Out:
#  Fetching IRSA Dust for spectra...
#
#  Done fetching IRSA dust!

# %% [markdown]
# #### Run

# %%
import numpy as np
import importlib
importlib.reload(badass)
importlib.reload(badass_config_options)
if 1:
# for i in range(1):
#     np.random.seed()
#     print("\n---------------------------------------------------------")
#     print(" Begin Test %d of %d" % (i+1,10))
#     print("---------------------------------------------------------")
    
    # Call the main function in BADASS
    badass.run_BADASS(pathlib.Path(file), 
                      options_file = options_file,
                     )
        #
# Out:
# Start process memory: 0.26415514
#  Folder has not been created.  Creating MCMC_output folder...
#
#  > Starting fit for 2-test
#
#  Input fitting region exceeds available wavelength range.  BADASS will adjust your fitting range automatically...
# 		- Input fitting range: (4400, 5500)
# 		- Available wavelength range: (2218, 5354)
# 		- New fitting region is (4400, 5355).
#
#
#
# -----------------------------------------------------------
#  file:                        spec-2756-54508-0579.fits
#  SDSS redshift:               0.71967
#  fitting region:              (4400,5355) [A]
#  velocity scale:              69.15 [km/s/pixel]
#  Galactic E(B-V):             0.032
#  Flux Normalization:          1e-17
#  Fit Normalization:           406.35992
# -----------------------------------------------------------
# 	- Fitting a SSP host-galaxy template.
# 	- Fitting additive legendre polynomial component.
# 	- Fitting Simple AGN power-law continuum.
#
#  - ('BR_MGII_2799_DISP', 'NA_MGII_2799_DISP') soft constraint removed because one or more free parameters is not available.
#
#  - ('OUT_NII_6585_DISP', 'NA_NII_6585_DISP') soft constraint removed because one or more free parameters is not available.
#
#  Performing configuration testing for 5 configurations...
# ----------------------------------------------------------------------------------------------------
#
#  Performing test of configuration 1 versus configuration 2...
#
# 	 Fitting CONFIG 1
# -------------------------------------------------------
#
#
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_3
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 0.0716895557668437
# 	 plim = (0, 1.4999999931919876)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 0.31023949447323756
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 0.9726676161021446
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = NA_OIII_5007_DISP
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
#
#
#
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# basinhopping step 0: f 16429.9
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.9 old stepsize 1
# basinhopping step 1: f 16429.9 trial_f 1.95524e+06 accepted 0  lowest_f 16429.9
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.81 old stepsize 0.9
# basinhopping step 2: f 16429.9 trial_f 1.52374e+06 accepted 0  lowest_f 16429.9
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.729 old stepsize 0.81
# basinhopping step 3: f 16429.9 trial_f 7.83184e+06 accepted 0  lowest_f 16429.9
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.6561 old stepsize 0.729
# basinhopping step 4: f 16429.9 trial_f 3.424e+06 accepted 0  lowest_f 16429.9
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.59049 old stepsize 0.6561
# basinhopping step 5: f 16429.9 trial_f 1.15568e+07 accepted 0  lowest_f 16429.9
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.531441 old stepsize 0.59049
# basinhopping step 6: f 16429.9 trial_f 1.78304e+06 accepted 0  lowest_f 16429.9
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.478297 old stepsize 0.531441
# basinhopping step 7: f 16429.9 trial_f 1.04741e+06 accepted 0  lowest_f 16429.9
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.430467 old stepsize 0.478297
# basinhopping step 8: f 16429.9 trial_f 4.65574e+06 accepted 0  lowest_f 16429.9
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.38742 old stepsize 0.430467
# basinhopping step 9: f 16420.4 trial_f 16420.4 accepted 1  lowest_f 16420.4
# found new global minimum on step 9 with function value 16420.4
# adaptive stepsize: acceptance rate 0.100000 target 0.500000 new stepsize 0.348678 old stepsize 0.38742
# basinhopping step 10: f 16420.4 trial_f 1.10814e+06 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.090909 target 0.500000 new stepsize 0.313811 old stepsize 0.348678
# basinhopping step 11: f 16420.4 trial_f 204763 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.083333 target 0.500000 new stepsize 0.28243 old stepsize 0.313811
# basinhopping step 12: f 16420.4 trial_f 2.1985e+06 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.076923 target 0.500000 new stepsize 0.254187 old stepsize 0.28243
# basinhopping step 13: f 16420.4 trial_f 285194 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.071429 target 0.500000 new stepsize 0.228768 old stepsize 0.254187
# basinhopping step 14: f 16420.4 trial_f 1.36031e+06 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.066667 target 0.500000 new stepsize 0.205891 old stepsize 0.228768
# basinhopping step 15: f 16420.4 trial_f 176059 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.062500 target 0.500000 new stepsize 0.185302 old stepsize 0.205891
# basinhopping step 16: f 16420.4 trial_f 99805.7 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.058824 target 0.500000 new stepsize 0.166772 old stepsize 0.185302
# basinhopping step 17: f 16420.4 trial_f 359913 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.055556 target 0.500000 new stepsize 0.150095 old stepsize 0.166772
# basinhopping step 18: f 16420.4 trial_f 288721 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.052632 target 0.500000 new stepsize 0.135085 old stepsize 0.150095
# basinhopping step 19: f 16420.4 trial_f 137735 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.050000 target 0.500000 new stepsize 0.121577 old stepsize 0.135085
# basinhopping step 20: f 16420.4 trial_f 77139.1 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.047619 target 0.500000 new stepsize 0.109419 old stepsize 0.121577
# basinhopping step 21: f 16420.4 trial_f 141306 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.045455 target 0.500000 new stepsize 0.0984771 old stepsize 0.109419
# basinhopping step 22: f 16420.4 trial_f 81315.1 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.043478 target 0.500000 new stepsize 0.0886294 old stepsize 0.0984771
# basinhopping step 23: f 16420.4 trial_f 147971 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.041667 target 0.500000 new stepsize 0.0797664 old stepsize 0.0886294
# basinhopping step 24: f 16420.4 trial_f 67254.3 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.040000 target 0.500000 new stepsize 0.0717898 old stepsize 0.0797664
# basinhopping step 25: f 16420.4 trial_f 146876 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.038462 target 0.500000 new stepsize 0.0646108 old stepsize 0.0717898
# basinhopping step 26: f 16420.4 trial_f 63813 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.037037 target 0.500000 new stepsize 0.0581497 old stepsize 0.0646108
# basinhopping step 27: f 16420.4 trial_f 42468.4 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.035714 target 0.500000 new stepsize 0.0523348 old stepsize 0.0581497
# basinhopping step 28: f 16420.4 trial_f 21145.9 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.034483 target 0.500000 new stepsize 0.0471013 old stepsize 0.0523348
# basinhopping step 29: f 16420.4 trial_f 78233.4 accepted 0  lowest_f 16420.4
# adaptive stepsize: acceptance rate 0.033333 target 0.500000 new stepsize 0.0423912 old stepsize 0.0471013
# basinhopping step 30: f 16415.3 trial_f 16415.3 accepted 1  lowest_f 16415.3
# found new global minimum on step 30 with function value 16415.3
# adaptive stepsize: acceptance rate 0.064516 target 0.500000 new stepsize 0.038152 old stepsize 0.0423912
# basinhopping step 31: f 16415.3 trial_f 35398.1 accepted 0  lowest_f 16415.3
# adaptive stepsize: acceptance rate 0.062500 target 0.500000 new stepsize 0.0343368 old stepsize 0.038152
# basinhopping step 32: f 16415.3 trial_f 19020.3 accepted 0  lowest_f 16415.3
# adaptive stepsize: acceptance rate 0.060606 target 0.500000 new stepsize 0.0309032 old stepsize 0.0343368
# basinhopping step 33: f 16415.1 trial_f 16415.1 accepted 1  lowest_f 16415.1
# found new global minimum on step 33 with function value 16415.1
# adaptive stepsize: acceptance rate 0.088235 target 0.500000 new stepsize 0.0278128 old stepsize 0.0309032
# basinhopping step 34: f 16415.7 trial_f 16415.7 accepted 1  lowest_f 16415.1
# adaptive stepsize: acceptance rate 0.114286 target 0.500000 new stepsize 0.0250316 old stepsize 0.0278128
# basinhopping step 35: f 16415.7 trial_f 16462.6 accepted 0  lowest_f 16415.1
# adaptive stepsize: acceptance rate 0.111111 target 0.500000 new stepsize 0.0225284 old stepsize 0.0250316
# basinhopping step 36: f 16415.7 trial_f 16437.3 accepted 0  lowest_f 16415.1
# adaptive stepsize: acceptance rate 0.108108 target 0.500000 new stepsize 0.0202756 old stepsize 0.0225284
# basinhopping step 37: f 16415.7 trial_f 16422.8 accepted 0  lowest_f 16415.1
# adaptive stepsize: acceptance rate 0.105263 target 0.500000 new stepsize 0.018248 old stepsize 0.0202756
# basinhopping step 38: f 16394.4 trial_f 16394.4 accepted 1  lowest_f 16394.4
# found new global minimum on step 38 with function value 16394.4
# adaptive stepsize: acceptance rate 0.128205 target 0.500000 new stepsize 0.0164232 old stepsize 0.018248
# basinhopping step 39: f 16381.6 trial_f 16381.6 accepted 1  lowest_f 16381.6
# found new global minimum on step 39 with function value 16381.6
# adaptive stepsize: acceptance rate 0.150000 target 0.500000 new stepsize 0.0147809 old stepsize 0.0164232
# basinhopping step 40: f 16381.6 trial_f 16400.9 accepted 0  lowest_f 16381.6
# adaptive stepsize: acceptance rate 0.146341 target 0.500000 new stepsize 0.0133028 old stepsize 0.0147809
# basinhopping step 41: f 16381.6 trial_f 16384.4 accepted 0  lowest_f 16381.6
# adaptive stepsize: acceptance rate 0.142857 target 0.500000 new stepsize 0.0119725 old stepsize 0.0133028
# warning: basinhopping: local minimization failure
# basinhopping step 42: f 16365.3 trial_f 16365.3 accepted 1  lowest_f 16365.3
# found new global minimum on step 42 with function value 16365.3
# adaptive stepsize: acceptance rate 0.162791 target 0.500000 new stepsize 0.0107753 old stepsize 0.0119725
# basinhopping step 43: f 16340.2 trial_f 16340.2 accepted 1  lowest_f 16340.2
# found new global minimum on step 43 with function value 16340.2
# adaptive stepsize: acceptance rate 0.181818 target 0.500000 new stepsize 0.00969774 old stepsize 0.0107753
# basinhopping step 44: f 16334.8 trial_f 16334.8 accepted 1  lowest_f 16334.8
# found new global minimum on step 44 with function value 16334.8
# adaptive stepsize: acceptance rate 0.200000 target 0.500000 new stepsize 0.00872796 old stepsize 0.00969774
# basinhopping step 45: f 16325.8 trial_f 16325.8 accepted 1  lowest_f 16325.8
# found new global minimum on step 45 with function value 16325.8
# adaptive stepsize: acceptance rate 0.217391 target 0.500000 new stepsize 0.00785517 old stepsize 0.00872796
# basinhopping step 46: f 16323.2 trial_f 16323.2 accepted 1  lowest_f 16323.2
# found new global minimum on step 46 with function value 16323.2
# adaptive stepsize: acceptance rate 0.234043 target 0.500000 new stepsize 0.00706965 old stepsize 0.00785517
# basinhopping step 47: f 16323.8 trial_f 16323.8 accepted 1  lowest_f 16323.2
# adaptive stepsize: acceptance rate 0.250000 target 0.500000 new stepsize 0.00636269 old stepsize 0.00706965
# basinhopping step 48: f 16323.1 trial_f 16323.1 accepted 1  lowest_f 16323.1
# found new global minimum on step 48 with function value 16323.1
# adaptive stepsize: acceptance rate 0.265306 target 0.500000 new stepsize 0.00572642 old stepsize 0.00636269
# basinhopping step 49: f 16322.6 trial_f 16322.6 accepted 1  lowest_f 16322.6
# found new global minimum on step 49 with function value 16322.6
# adaptive stepsize: acceptance rate 0.280000 target 0.500000 new stepsize 0.00515378 old stepsize 0.00572642
# basinhopping step 50: f 16322.6 trial_f 16324 accepted 0  lowest_f 16322.6
# adaptive stepsize: acceptance rate 0.274510 target 0.500000 new stepsize 0.0046384 old stepsize 0.00515378
# basinhopping step 51: f 16323.6 trial_f 16323.6 accepted 1  lowest_f 16322.6
# adaptive stepsize: acceptance rate 0.288462 target 0.500000 new stepsize 0.00417456 old stepsize 0.0046384
# basinhopping step 52: f 16322.4 trial_f 16322.4 accepted 1  lowest_f 16322.4
# found new global minimum on step 52 with function value 16322.4
# adaptive stepsize: acceptance rate 0.301887 target 0.500000 new stepsize 0.0037571 old stepsize 0.00417456
# basinhopping step 53: f 16322.4 trial_f 16323.2 accepted 0  lowest_f 16322.4
# adaptive stepsize: acceptance rate 0.296296 target 0.500000 new stepsize 0.00338139 old stepsize 0.0037571
# basinhopping step 54: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.2
# found new global minimum on step 54 with function value 16322.2
# adaptive stepsize: acceptance rate 0.309091 target 0.500000 new stepsize 0.00304325 old stepsize 0.00338139
# basinhopping step 55: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# found new global minimum on step 55 with function value 16322.1
# adaptive stepsize: acceptance rate 0.321429 target 0.500000 new stepsize 0.00273893 old stepsize 0.00304325
# basinhopping step 56: f 16322.4 trial_f 16322.4 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.333333 target 0.500000 new stepsize 0.00246503 old stepsize 0.00273893
# basinhopping step 57: f 16322.4 trial_f 16322.4 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.344828 target 0.500000 new stepsize 0.00221853 old stepsize 0.00246503
# basinhopping step 58: f 16322.3 trial_f 16322.3 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.355932 target 0.500000 new stepsize 0.00199668 old stepsize 0.00221853
# basinhopping step 59: f 16322.4 trial_f 16322.4 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.366667 target 0.500000 new stepsize 0.00179701 old stepsize 0.00199668
# basinhopping step 60: f 16322.4 trial_f 16322.4 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.377049 target 0.500000 new stepsize 0.00161731 old stepsize 0.00179701
# basinhopping step 61: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.387097 target 0.500000 new stepsize 0.00145558 old stepsize 0.00161731
# basinhopping step 62: f 16322.2 trial_f 16324.6 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.380952 target 0.500000 new stepsize 0.00131002 old stepsize 0.00145558
# basinhopping step 63: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.390625 target 0.500000 new stepsize 0.00117902 old stepsize 0.00131002
# basinhopping step 64: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# found new global minimum on step 64 with function value 16322.1
# adaptive stepsize: acceptance rate 0.400000 target 0.500000 new stepsize 0.00106112 old stepsize 0.00117902
# basinhopping step 65: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.409091 target 0.500000 new stepsize 0.000955005 old stepsize 0.00106112
# basinhopping step 66: f 16322.3 trial_f 16322.3 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.417910 target 0.500000 new stepsize 0.000859504 old stepsize 0.000955005
# basinhopping step 67: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.426471 target 0.500000 new stepsize 0.000773554 old stepsize 0.000859504
# basinhopping step 68: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.434783 target 0.500000 new stepsize 0.000696199 old stepsize 0.000773554
# basinhopping step 69: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.442857 target 0.500000 new stepsize 0.000626579 old stepsize 0.000696199
# basinhopping step 70: f 16322.3 trial_f 16322.3 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.450704 target 0.500000 new stepsize 0.000563921 old stepsize 0.000626579
# basinhopping step 71: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.458333 target 0.500000 new stepsize 0.000507529 old stepsize 0.000563921
# basinhopping step 72: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.465753 target 0.500000 new stepsize 0.000456776 old stepsize 0.000507529
# basinhopping step 73: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.472973 target 0.500000 new stepsize 0.000411098 old stepsize 0.000456776
# basinhopping step 74: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.480000 target 0.500000 new stepsize 0.000369988 old stepsize 0.000411098
# basinhopping step 75: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.486842 target 0.500000 new stepsize 0.00033299 old stepsize 0.000369988
# basinhopping step 76: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.493506 target 0.500000 new stepsize 0.000299691 old stepsize 0.00033299
# basinhopping step 77: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.500000 target 0.500000 new stepsize 0.000269722 old stepsize 0.000299691
# basinhopping step 78: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.506329 target 0.500000 new stepsize 0.000299691 old stepsize 0.000269722
# basinhopping step 79: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.512500 target 0.500000 new stepsize 0.00033299 old stepsize 0.000299691
# basinhopping step 80: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.518519 target 0.500000 new stepsize 0.000369988 old stepsize 0.00033299
# basinhopping step 81: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.524390 target 0.500000 new stepsize 0.000411098 old stepsize 0.000369988
# basinhopping step 82: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.530120 target 0.500000 new stepsize 0.000456776 old stepsize 0.000411098
# basinhopping step 83: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.535714 target 0.500000 new stepsize 0.000507529 old stepsize 0.000456776
# basinhopping step 84: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.541176 target 0.500000 new stepsize 0.000563921 old stepsize 0.000507529
# basinhopping step 85: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.546512 target 0.500000 new stepsize 0.000626579 old stepsize 0.000563921
# basinhopping step 86: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.551724 target 0.500000 new stepsize 0.000696199 old stepsize 0.000626579
# basinhopping step 87: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.556818 target 0.500000 new stepsize 0.000773554 old stepsize 0.000696199
# basinhopping step 88: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.561798 target 0.500000 new stepsize 0.000859504 old stepsize 0.000773554
# basinhopping step 89: f 16322.3 trial_f 16322.3 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.566667 target 0.500000 new stepsize 0.000955005 old stepsize 0.000859504
# basinhopping step 90: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
#
#
#  R-Squared = 0.9850
#
#
#  reduced Chi-Squared = 20.0098
#
#
#  Root Mean Squared Error = 1.2059
#
#
#  Mean Absolute Error = 0.0951
#
#
# -------------------------------------------------------
# 	 Fitting CONFIG 2
# -------------------------------------------------------
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_3
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 0.0716895557668437
# 	 plim = (0, 1.4999999931919876)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 0.31023949447323756
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 0.9726676161021446
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# BR_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# BR_H_BETA_AMP
# 	 init = 0.31023949447323756
# 	 plim = (0.0, 1.9999999909226502)
# BR_H_BETA_DISP
# 	 init = 500.0
# 	 plim = (300, 3000)
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = NA_OIII_5007_DISP
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
# BR_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = br
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
#
#
#
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# basinhopping step 0: f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 0.2507
#  Accepted count: 1
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.9 old stepsize 1
# basinhopping step 1: f 23046.1 trial_f 2.34121e+07 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 5.6703
#  Accepted count: 1
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.81 old stepsize 0.9
# basinhopping step 2: f 23046.1 trial_f 5.5825e+06 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 2.7289
#  Accepted count: 1
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.729 old stepsize 0.81
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 23046.1 trial_f 1.35804e+07 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 4.2180
#  Accepted count: 1
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.6561 old stepsize 0.729
# basinhopping step 4: f 23046.1 trial_f 2.02682e+06 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 1.8877
#  Accepted count: 1
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.59049 old stepsize 0.6561
# basinhopping step 5: f 23046.1 trial_f 569376 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 1.0235
#  Accepted count: 1
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.531441 old stepsize 0.59049
# basinhopping step 6: f 23046.1 trial_f 2.61009e+06 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 2.1532
#  Accepted count: 1
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.478297 old stepsize 0.531441
# basinhopping step 7: f 23046.1 trial_f 679232 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 1.0639
#  Accepted count: 1
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.430467 old stepsize 0.478297
# basinhopping step 8: f 23046.1 trial_f 1.17287e+06 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 1.2704
#  Accepted count: 1
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.38742 old stepsize 0.430467
# basinhopping step 9: f 23046.1 trial_f 1.32307e+06 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 1.5632
#  Accepted count: 1
#  Basinhop count: 9
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.348678 old stepsize 0.38742
# basinhopping step 10: f 23046.1 trial_f 2.79968e+06 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 2.1597
#  Accepted count: 1
#  Basinhop count: 10
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.313811 old stepsize 0.348678
# basinhopping step 11: f 23046.1 trial_f 3.55089e+06 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 2.4770
#  Accepted count: 1
#  Basinhop count: 11
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.28243 old stepsize 0.313811
# basinhopping step 12: f 23046.1 trial_f 1.17546e+06 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 1.3795
#  Accepted count: 1
#  Basinhop count: 12
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.254187 old stepsize 0.28243
# basinhopping step 13: f 23046.1 trial_f 84014.2 accepted 0  lowest_f 23046.1
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.2507
#  Current RMSE: 0.3410
#  Accepted count: 1
#  Basinhop count: 13
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.228768 old stepsize 0.254187
# basinhopping step 14: f 9276.48 trial_f 9276.48 accepted 1  lowest_f 9276.48
# found new global minimum on step 14 with function value 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.0668
#  Accepted count: 2
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.066667 target 0.500000 new stepsize 0.205891 old stepsize 0.228768
# basinhopping step 15: f 9276.48 trial_f 441608 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.7849
#  Accepted count: 2
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.062500 target 0.500000 new stepsize 0.185302 old stepsize 0.205891
# basinhopping step 16: f 9276.48 trial_f 233791 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.5765
#  Accepted count: 2
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.058824 target 0.500000 new stepsize 0.166772 old stepsize 0.185302
# basinhopping step 17: f 9276.48 trial_f 281087 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.6769
#  Accepted count: 2
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.055556 target 0.500000 new stepsize 0.150095 old stepsize 0.166772
# basinhopping step 18: f 9276.48 trial_f 1.15136e+06 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 1.2128
#  Accepted count: 2
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.052632 target 0.500000 new stepsize 0.135085 old stepsize 0.150095
# basinhopping step 19: f 9276.48 trial_f 136085 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.4717
#  Accepted count: 2
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.050000 target 0.500000 new stepsize 0.121577 old stepsize 0.135085
# basinhopping step 20: f 9276.48 trial_f 684549 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 1.0007
#  Accepted count: 2
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.047619 target 0.500000 new stepsize 0.109419 old stepsize 0.121577
# basinhopping step 21: f 9276.48 trial_f 17821.8 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.1379
#  Accepted count: 2
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.045455 target 0.500000 new stepsize 0.0984771 old stepsize 0.109419
# warning: basinhopping: local minimization failure
# basinhopping step 22: f 9276.48 trial_f 9305.49 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.0674
#  Accepted count: 2
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.043478 target 0.500000 new stepsize 0.0886294 old stepsize 0.0984771
# basinhopping step 23: f 9276.48 trial_f 9282.2 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.0670
#  Accepted count: 2
#  Basinhop count: 9
#
#
# adaptive stepsize: acceptance rate 0.041667 target 0.500000 new stepsize 0.0797664 old stepsize 0.0886294
# basinhopping step 24: f 9276.48 trial_f 135478 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.4483
#  Accepted count: 2
#  Basinhop count: 10
#
#
# adaptive stepsize: acceptance rate 0.040000 target 0.500000 new stepsize 0.0717898 old stepsize 0.0797664
# basinhopping step 25: f 9276.48 trial_f 129796 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.4439
#  Accepted count: 2
#  Basinhop count: 11
#
#
# adaptive stepsize: acceptance rate 0.038462 target 0.500000 new stepsize 0.0646108 old stepsize 0.0717898
# basinhopping step 26: f 9276.48 trial_f 58618.3 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.2750
#  Accepted count: 2
#  Basinhop count: 12
#
#
# adaptive stepsize: acceptance rate 0.037037 target 0.500000 new stepsize 0.0581497 old stepsize 0.0646108
# basinhopping step 27: f 9276.48 trial_f 9300.04 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.0675
#  Accepted count: 2
#  Basinhop count: 13
#
#
# adaptive stepsize: acceptance rate 0.035714 target 0.500000 new stepsize 0.0523348 old stepsize 0.0581497
# basinhopping step 28: f 9276.48 trial_f 36446.9 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.2103
#  Accepted count: 2
#  Basinhop count: 14
#
#
# adaptive stepsize: acceptance rate 0.034483 target 0.500000 new stepsize 0.0471013 old stepsize 0.0523348
# warning: basinhopping: local minimization failure
# basinhopping step 29: f 9276.48 trial_f 9285.74 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.0671
#  Accepted count: 2
#  Basinhop count: 15
#
#
# adaptive stepsize: acceptance rate 0.033333 target 0.500000 new stepsize 0.0423912 old stepsize 0.0471013
# basinhopping step 30: f 9276.48 trial_f 9276.86 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.0668
#  Accepted count: 2
#  Basinhop count: 16
#
#
# adaptive stepsize: acceptance rate 0.032258 target 0.500000 new stepsize 0.038152 old stepsize 0.0423912
# basinhopping step 31: f 9276.48 trial_f 10550.9 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.0824
#  Accepted count: 2
#  Basinhop count: 17
#
#
# adaptive stepsize: acceptance rate 0.031250 target 0.500000 new stepsize 0.0343368 old stepsize 0.038152
# warning: basinhopping: local minimization failure
# basinhopping step 32: f 9276.48 trial_f 9284.72 accepted 0  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.0671
#  Accepted count: 2
#  Basinhop count: 18
#
#
# adaptive stepsize: acceptance rate 0.030303 target 0.500000 new stepsize 0.0309032 old stepsize 0.0343368
# basinhopping step 33: f 9276.49 trial_f 9276.49 accepted 1  lowest_f 9276.48
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0668
#  Current RMSE: 0.0668
#  Accepted count: 3
#  Basinhop count: 19
#
#
# adaptive stepsize: acceptance rate 0.058824 target 0.500000 new stepsize 0.0278128 old stepsize 0.0309032
# warning: basinhopping: local minimization failure
# basinhopping step 34: f 9274.79 trial_f 9274.79 accepted 1  lowest_f 9274.79
# found new global minimum on step 34 with function value 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0666
#  Current RMSE: 0.0666
#  Accepted count: 4
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.085714 target 0.500000 new stepsize 0.0250316 old stepsize 0.0278128
# basinhopping step 35: f 9274.79 trial_f 13705 accepted 0  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0666
#  Current RMSE: 0.1068
#  Accepted count: 4
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.083333 target 0.500000 new stepsize 0.0225284 old stepsize 0.0250316
# basinhopping step 36: f 9275.62 trial_f 9275.62 accepted 1  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0666
#  Current RMSE: 0.0668
#  Accepted count: 5
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.108108 target 0.500000 new stepsize 0.0202756 old stepsize 0.0225284
# basinhopping step 37: f 9275.62 trial_f 16137.4 accepted 0  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0666
#  Current RMSE: 0.1279
#  Accepted count: 5
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.105263 target 0.500000 new stepsize 0.018248 old stepsize 0.0202756
# basinhopping step 38: f 9275.6 trial_f 9275.6 accepted 1  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0666
#  Current RMSE: 0.0668
#  Accepted count: 6
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.128205 target 0.500000 new stepsize 0.0164232 old stepsize 0.018248
# basinhopping step 39: f 9275.6 trial_f 13561.3 accepted 0  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0666
#  Current RMSE: 0.1057
#  Accepted count: 6
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.125000 target 0.500000 new stepsize 0.0147809 old stepsize 0.0164232
# basinhopping step 40: f 9275.6 trial_f 10948.2 accepted 0  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0666
#  Current RMSE: 0.0828
#  Accepted count: 6
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.121951 target 0.500000 new stepsize 0.0133028 old stepsize 0.0147809
# basinhopping step 41: f 9274.88 trial_f 9274.88 accepted 1  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 7
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.142857 target 0.500000 new stepsize 0.0119725 old stepsize 0.0133028
# basinhopping step 42: f 9274.88 trial_f 9279.72 accepted 0  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 7
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.139535 target 0.500000 new stepsize 0.0107753 old stepsize 0.0119725
# basinhopping step 43: f 9274.88 trial_f 9280.15 accepted 0  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 7
#  Basinhop count: 9
#
#
# adaptive stepsize: acceptance rate 0.136364 target 0.500000 new stepsize 0.00969774 old stepsize 0.0107753
# basinhopping step 44: f 9274.88 trial_f 9276.12 accepted 0  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 7
#  Basinhop count: 10
#
#
# adaptive stepsize: acceptance rate 0.133333 target 0.500000 new stepsize 0.00872796 old stepsize 0.00969774
# basinhopping step 45: f 9274.88 trial_f 9281.45 accepted 0  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0668
#  Accepted count: 7
#  Basinhop count: 11
#
#
# adaptive stepsize: acceptance rate 0.130435 target 0.500000 new stepsize 0.00785517 old stepsize 0.00872796
# basinhopping step 46: f 9275.11 trial_f 9275.11 accepted 1  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 8
#  Basinhop count: 12
#
#
# adaptive stepsize: acceptance rate 0.148936 target 0.500000 new stepsize 0.00706965 old stepsize 0.00785517
# basinhopping step 47: f 9275.11 trial_f 9746.48 accepted 0  lowest_f 9274.79
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0715
#  Accepted count: 8
#  Basinhop count: 13
#
#
# adaptive stepsize: acceptance rate 0.145833 target 0.500000 new stepsize 0.00636269 old stepsize 0.00706965
# basinhopping step 48: f 9274.72 trial_f 9274.72 accepted 1  lowest_f 9274.72
# found new global minimum on step 48 with function value 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 9
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.163265 target 0.500000 new stepsize 0.00572642 old stepsize 0.00636269
# basinhopping step 49: f 9274.72 trial_f 9278.15 accepted 0  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 9
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.160000 target 0.500000 new stepsize 0.00515378 old stepsize 0.00572642
# basinhopping step 50: f 9274.72 trial_f 9277.56 accepted 0  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 9
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.156863 target 0.500000 new stepsize 0.0046384 old stepsize 0.00515378
# basinhopping step 51: f 9275.31 trial_f 9275.31 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 10
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.173077 target 0.500000 new stepsize 0.00417456 old stepsize 0.0046384
# basinhopping step 52: f 9275.31 trial_f 9277.12 accepted 0  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 10
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.169811 target 0.500000 new stepsize 0.0037571 old stepsize 0.00417456
# basinhopping step 53: f 9276.1 trial_f 9276.1 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 11
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.185185 target 0.500000 new stepsize 0.00338139 old stepsize 0.0037571
# basinhopping step 54: f 9274.88 trial_f 9274.88 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 12
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.200000 target 0.500000 new stepsize 0.00304325 old stepsize 0.00338139
# basinhopping step 55: f 9275.42 trial_f 9275.42 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 13
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.214286 target 0.500000 new stepsize 0.00273893 old stepsize 0.00304325
# basinhopping step 56: f 9275.09 trial_f 9275.09 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 14
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.228070 target 0.500000 new stepsize 0.00246503 old stepsize 0.00273893
# basinhopping step 57: f 9274.96 trial_f 9274.96 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 15
#  Basinhop count: 9
#
#
# adaptive stepsize: acceptance rate 0.241379 target 0.500000 new stepsize 0.00221853 old stepsize 0.00246503
# basinhopping step 58: f 9274.96 trial_f 9275.22 accepted 0  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 15
#  Basinhop count: 10
#
#
# adaptive stepsize: acceptance rate 0.237288 target 0.500000 new stepsize 0.00199668 old stepsize 0.00221853
# basinhopping step 59: f 9274.79 trial_f 9274.79 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 16
#  Basinhop count: 11
#
#
# adaptive stepsize: acceptance rate 0.250000 target 0.500000 new stepsize 0.00179701 old stepsize 0.00199668
# basinhopping step 60: f 9274.73 trial_f 9274.73 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 17
#  Basinhop count: 12
#
#
# adaptive stepsize: acceptance rate 0.262295 target 0.500000 new stepsize 0.00161731 old stepsize 0.00179701
# basinhopping step 61: f 9274.73 trial_f 9274.73 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 18
#  Basinhop count: 13
#
#
# adaptive stepsize: acceptance rate 0.274194 target 0.500000 new stepsize 0.00145558 old stepsize 0.00161731
# basinhopping step 62: f 9274.9 trial_f 9274.9 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 19
#  Basinhop count: 14
#
#
# adaptive stepsize: acceptance rate 0.285714 target 0.500000 new stepsize 0.00131002 old stepsize 0.00145558
# basinhopping step 63: f 9274.81 trial_f 9274.81 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 20
#  Basinhop count: 15
#
#
# adaptive stepsize: acceptance rate 0.296875 target 0.500000 new stepsize 0.00117902 old stepsize 0.00131002
# basinhopping step 64: f 9274.75 trial_f 9274.75 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 21
#  Basinhop count: 16
#
#
# adaptive stepsize: acceptance rate 0.307692 target 0.500000 new stepsize 0.00106112 old stepsize 0.00117902
# basinhopping step 65: f 9274.98 trial_f 9274.98 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 22
#  Basinhop count: 17
#
#
# adaptive stepsize: acceptance rate 0.318182 target 0.500000 new stepsize 0.000955005 old stepsize 0.00106112
# basinhopping step 66: f 9274.74 trial_f 9274.74 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 23
#  Basinhop count: 18
#
#
# adaptive stepsize: acceptance rate 0.328358 target 0.500000 new stepsize 0.000859504 old stepsize 0.000955005
# basinhopping step 67: f 9275.08 trial_f 9275.08 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 24
#  Basinhop count: 19
#
#
# adaptive stepsize: acceptance rate 0.338235 target 0.500000 new stepsize 0.000773554 old stepsize 0.000859504
# basinhopping step 68: f 9274.72 trial_f 9274.72 accepted 1  lowest_f 9274.72
# found new global minimum on step 68 with function value 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 25
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.347826 target 0.500000 new stepsize 0.000696199 old stepsize 0.000773554
# basinhopping step 69: f 9274.84 trial_f 9274.84 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 26
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.357143 target 0.500000 new stepsize 0.000626579 old stepsize 0.000696199
# basinhopping step 70: f 9274.82 trial_f 9274.82 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 27
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.366197 target 0.500000 new stepsize 0.000563921 old stepsize 0.000626579
# basinhopping step 71: f 9274.82 trial_f 9274.82 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 28
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.375000 target 0.500000 new stepsize 0.000507529 old stepsize 0.000563921
# basinhopping step 72: f 9275.01 trial_f 9275.01 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 29
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.383562 target 0.500000 new stepsize 0.000456776 old stepsize 0.000507529
# basinhopping step 73: f 9274.87 trial_f 9274.87 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 30
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.391892 target 0.500000 new stepsize 0.000411098 old stepsize 0.000456776
# basinhopping step 74: f 9275.02 trial_f 9275.02 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 31
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.400000 target 0.500000 new stepsize 0.000369988 old stepsize 0.000411098
# basinhopping step 75: f 9275.14 trial_f 9275.14 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 32
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.407895 target 0.500000 new stepsize 0.00033299 old stepsize 0.000369988
# basinhopping step 76: f 9275.09 trial_f 9275.09 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 33
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.415584 target 0.500000 new stepsize 0.000299691 old stepsize 0.00033299
# basinhopping step 77: f 9275.13 trial_f 9275.13 accepted 1  lowest_f 9274.72
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 34
#  Basinhop count: 9
#
#
# ...
# NA_H_BETA_2_W80               525.349685                    11.258858                     0.0
# NA_H_BETA_2_W80_CORR          512.606967                    11.258858                     0.0
# NA_H_BETA_AMP                 5.155685                      0.746856                      0.0
# NA_H_BETA_COMB_DISP           329.707087                    12.030173                     0.0
# NA_H_BETA_COMB_DISP_CORR      326.648999                    12.030173                     0.0
# NA_H_BETA_COMB_DISP_RES       44.801729                     nan                           nan
# NA_H_BETA_COMB_EW             10.647162                     0.365885                      0.0
# NA_H_BETA_COMB_FLUX           -14.229853                    0.015026                      0.0
# NA_H_BETA_COMB_FWHM           516.769305                    4.880985                      0.0
# NA_H_BETA_COMB_FWHM_CORR      505.885809                    4.880985                      0.0
# NA_H_BETA_COMB_LUM            43.136366                     0.015026                      0.0
# NA_H_BETA_COMB_NPIX           19.000000                     1.291758                      0.0
# NA_H_BETA_COMB_SNR            14.874213                     0.580156                      0.0
# NA_H_BETA_COMB_VOFF           22.108438                     27.858689                     0.0
# NA_H_BETA_COMB_W80            760.743399                    43.194460                     0.0
# NA_H_BETA_COMB_W80_CORR       752.000087                    43.194460                     0.0
# NA_H_BETA_DISP                497.553502                    30.504090                     0.0
# NA_H_BETA_DISP_CORR           495.532332                    30.504090                     0.0
# NA_H_BETA_DISP_RES            44.801729                     nan                           nan
# NA_H_BETA_EW                  3.239566                      0.292416                      0.0
# NA_H_BETA_FLUX                -14.746817                    0.040790                      0.0
# NA_H_BETA_FWHM                1172.633599                   71.759754                     0.0
# NA_H_BETA_FWHM_CORR           1167.878202                   71.759754                     0.0
# NA_H_BETA_LUM                 42.619402                     0.040790                      0.0
# NA_H_BETA_NPIX                18.000000                     1.141602                      0.0
# NA_H_BETA_SNR                 3.071007                      0.444594                      0.0
# NA_H_BETA_VOFF                137.298726                    90.286788                     0.0
# NA_H_BETA_W80                 1304.938688                   79.665223                     0.0
# NA_H_BETA_W80_CORR            1299.860989                   79.665223                     0.0
# NA_OIII_4960_2_AMP            97.282046                     5.647301                      0.0
# NA_OIII_4960_2_DISP           199.407787                    3.972427                      0.0
# NA_OIII_4960_2_DISP_CORR      194.397850                    3.972427                      0.0
# NA_OIII_4960_2_DISP_RES       44.417804                     nan                           nan
# NA_OIII_4960_2_EW             25.732736                     1.007991                      0.0
# NA_OIII_4960_2_FLUX           -13.859780                    0.016217                      0.0
# NA_OIII_4960_2_FWHM           471.793566                    9.270374                      0.0
# NA_OIII_4960_2_FWHM_CORR      460.053308                    9.270374                      0.0
# NA_OIII_4960_2_LUM            43.506438                     0.016217                      0.0
# NA_OIII_4960_2_NPIX           17.000000                     0.319486                      0.0
# NA_OIII_4960_2_SNR            57.924510                     1.131950                      0.0
# NA_OIII_4960_2_VOFF           -28.201754                    1.672904                      0.0
# NA_OIII_4960_2_W80            524.390703                    11.056141                     0.0
# NA_OIII_4960_2_W80_CORR       511.844639                    11.056141                     0.0
# NA_OIII_4960_AMP              17.028800                     6.722717                      0.0
# NA_OIII_4960_COMB_DISP        320.866338                    8.122661                      0.0
# NA_OIII_4960_COMB_DISP_CORR   317.777069                    8.122661                      0.0
# NA_OIII_4960_COMB_DISP_RES    44.417804                     nan                           nan
# NA_OIII_4960_COMB_EW          36.973657                     0.278013                      0.0
# NA_OIII_4960_COMB_FLUX        -13.702387                    0.002554                      0.0
# NA_OIII_4960_COMB_FWHM        516.972945                    4.915242                      0.0
# NA_OIII_4960_COMB_FWHM_CORR   506.281446                    4.915242                      0.0
# NA_OIII_4960_COMB_LUM         43.663831                     0.002554                      0.0
# NA_OIII_4960_COMB_NPIX        32.000000                     0.784465                      0.0
# NA_OIII_4960_COMB_SNR         58.901798                     0.416610                      0.0
# NA_OIII_4960_COMB_VOFF        -24.509157                    2.138491                      0.0
# NA_OIII_4960_COMB_W80         726.837923                    7.754767                      0.0
# NA_OIII_4960_COMB_W80_CORR    717.838904                    7.754767                      0.0
# NA_OIII_4960_DISP             497.553502                    30.504090                     0.0
# NA_OIII_4960_DISP_CORR        495.566894                    30.504090                     0.0
# NA_OIII_4960_DISP_RES         44.417804                     nan                           nan
# NA_OIII_4960_EW               11.240921                     0.852333                      0.0
# NA_OIII_4960_FLUX             -14.219509                    0.034732                      0.0
# NA_OIII_4960_FWHM             1172.850021                   72.096431                     0.0
# NA_OIII_4960_FWHM_CORR        1168.176805                   72.096431                     0.0
# NA_OIII_4960_LUM              43.146710                     0.034732                      0.0
# NA_OIII_4960_NPIX             32.000000                     0.784465                      0.0
# NA_OIII_4960_SNR              10.138971                     1.345684                      0.0
# NA_OIII_4960_VOFF             -16.055960                    9.120410                      0.0
# NA_OIII_4960_W80              1304.398904                   79.734107                     0.0
# NA_OIII_4960_W80_CORR         1299.405951                   79.734107                     0.0
# NA_OIII_5007_2_AMP            289.900497                    5.647301                      0.0
# NA_OIII_5007_2_DISP           199.407787                    3.972427                      0.0
# NA_OIII_5007_2_DISP_CORR      194.415284                    3.972427                      0.0
# NA_OIII_5007_2_DISP_RES       44.341437                     nan                           nan
# NA_OIII_5007_2_EW             78.834447                     3.095015                      0.0
# NA_OIII_5007_2_FLUX           -13.381378                    0.016216                      0.0
# NA_OIII_5007_2_FWHM           471.793528                    9.286102                      0.0
# NA_OIII_5007_2_FWHM_CORR      460.094116                    9.286102                      0.0
# NA_OIII_5007_2_LUM            43.984841                     0.016216                      0.0
# NA_OIII_5007_2_NPIX           19.000000                     0.746788                      0.0
# NA_OIII_5007_2_SNR            172.615080                    3.363045                      0.0
# NA_OIII_5007_2_VOFF           -28.201754                    1.672904                      0.0
# NA_OIII_5007_2_W80            525.775397                    11.248341                     0.0
# NA_OIII_5007_2_W80_CORR       513.306690                    11.248341                     0.0
# NA_OIII_5007_AMP              50.745825                     6.722717                      0.0
# NA_OIII_5007_COMB_DISP        320.873807                    8.123786                      0.0
# NA_OIII_5007_COMB_DISP_CORR   317.795275                    8.123786                      0.0
# NA_OIII_5007_COMB_DISP_RES    44.341437                     nan                           nan
# NA_OIII_5007_COMB_EW          113.271934                    0.856778                      0.0
# NA_OIII_5007_COMB_FLUX        -13.223986                    0.002553                      0.0
# NA_OIII_5007_COMB_FWHM        516.960209                    4.937071                      0.0
# NA_OIII_5007_COMB_FWHM_CORR   506.305561                    4.937071                      0.0
# NA_OIII_5007_COMB_LUM         44.142233                     0.002553                      0.0
# NA_OIII_5007_COMB_NPIX        39.000000                     1.434981                      0.0
# NA_OIII_5007_COMB_SNR         136.039673                    1.750518                      0.0
# NA_OIII_5007_COMB_VOFF        -24.509675                    2.138561                      0.0
# NA_OIII_5007_COMB_W80         727.295091                    6.464802                      0.0
# NA_OIII_5007_COMB_W80_CORR    718.332889                    6.464802                      0.0
# NA_OIII_5007_DISP             497.553502                    30.504090                     0.0
# NA_OIII_5007_DISP_CORR        495.573732                    30.504090                     0.0
# NA_OIII_5007_DISP_RES         44.341437                     nan                           nan
# NA_OIII_5007_EW               34.437487                     2.608371                      0.0
# NA_OIII_5007_FLUX             -13.741111                    0.034732                      0.0
# NA_OIII_5007_FWHM             1172.463770                   71.879020                     0.0
# NA_OIII_5007_FWHM_CORR        1167.805102                   71.879020                     0.0
# NA_OIII_5007_LUM              43.625108                     0.034732                      0.0
# NA_OIII_5007_NPIX             39.000000                     1.434981                      0.0
# NA_OIII_5007_SNR              30.237080                     4.008071                      0.0
# NA_OIII_5007_VOFF             -16.055960                    9.120410                      0.0
# NA_OIII_5007_W80              1303.908109                   79.850796                     0.0
# NA_OIII_5007_W80_CORR         1298.930463                   79.850796                     0.0
# NA_UNK_1_AMP                  0.000000                      0.000000                      1.0
# NA_UNK_1_DISP                 1000.000000                   0.000000                      0.0
# NA_UNK_1_DISP_CORR            998.995135                    0.000000                      0.0
# NA_UNK_1_DISP_RES             44.818749                     nan                           nan
# NA_UNK_1_EW                   0.000000                      0.000000                      1.0
# NA_UNK_1_FLUX                 0.000000                      0.000000                      0.0
# NA_UNK_1_FWHM                 0.000000                      0.000000                      0.0
# NA_UNK_1_FWHM_CORR            0.000000                      0.000000                      0.0
# NA_UNK_1_LUM                  0.000000                      0.000000                      1.0
# NA_UNK_1_NPIX                 0.000000                      0.000000                      0.0
# NA_UNK_1_SNR                  0.000000                      0.000000                      0.0
# NA_UNK_1_VOFF                 29.568189                     3.876289                      0.0
# NA_UNK_1_W80                  0.000000                      0.000000                      0.0
# NA_UNK_1_W80_CORR             0.000000                      0.000000                      0.0
# POWER_AMP                     53.881451                     0.040047                      0.0
# POWER_SLOPE                   -1.117880                     0.000000                      0.0
# RCHI_SQUARED                  2.383998                      0.010979                      0.0
# R_SQUARED                     0.998259                      0.000042                      0.0
# NOISE_STD                     1.499550
# RESID_STD                     2.931338
# --------------------------------------------------------------------------------------
#  - Done fitting 2-test!
#
# End process memory: 0.37111398
