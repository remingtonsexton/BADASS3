# %% [markdown]
# ## Bayesian AGN Decomposition Analysis for SDSS Spectra (BADASS)
# ### Single Spectrum Line Test Example
#
# ####  Remington O. Sexton$^{1}$, Sara M. Doan$^{2}$, William Matzko$^{2}$ Michael A. Reefe$^{2}$,
# $^{1}$United States Naval Observatory, $^{2}$George Mason University

# %%
import glob
import time
import natsort
from IPython.display import clear_output
import os
import sys
import psutil
import pathlib
import natsort
# Import BADASS here
BADASS_DIR = pathlib.Path(os.getcwd()).resolve().parent
sys.path.insert(1,str(BADASS_DIR))
import badass as badass
import badass_check_input
import badass_ncomp_options

from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ### BADASS Options

# %%
options_file = "badass_ncomp_options.py"

if os.path.exists(options_file):
    print("\n Options file %s found.\n" % (options_file))
# Out:
#  Options file badass_ncomp_options.py found.

# %% [markdown]
# ### Run BADASS on a single spectrum
#
# The following is shows how to fit single SDSS spectra.

# %% [markdown]
# #### Directory Structure

# %%
nobj = 2 # Object in the spec_dir list
########################## Directory Structure #################################
spec_dir = '../example_spectra/' # folder with spectra in it
# Get full list of spectrum folders; these will be the working directories
spec_loc = natsort.natsorted( glob.glob(spec_dir+'*') )[nobj]

################################################################################
print(len(spec_loc))
print(spec_loc)
# Out:
# 25
# ../example_spectra/2-test

# %% [markdown]
# #### Choose Spectrum

# %%
file = glob.glob(spec_loc+'/*.fits')[0] # Get name of FITS spectra file
print(file)
# Out:
# ../example_spectra/2-test/spec-2756-54508-0579.fits

# %% [markdown]
# #### Run IRSA Dust Query
# To correct for Galactic extinction.  This only needs to be done once so that the data is stored locally.

# %%
badass_check_input.fetch_IRSA_dust(spec_loc)
# Out:
#  Fetching IRSA Dust for spectra...
#
#  Done fetching IRSA dust!

# %% [markdown]
# #### Run

# %%
import numpy as np
import importlib
importlib.reload(badass)
importlib.reload(badass_ncomp_options)
if 1:
# for i in range(1):
#     np.random.seed()
#     print("\n---------------------------------------------------------")
#     print(" Begin Test %d of %d" % (i+1,10))
#     print("---------------------------------------------------------")
    
    # Call the main function in BADASS
    badass.run_BADASS(pathlib.Path(file),
                      options_file = options_file,
                     )
        #
# Out:
# Start process memory: 0.26943898
#  Storing MCMC_output in ../example_spectra/2-test/MCMC_output_3/
#
#  > Starting fit for 2-test
#
#  Input fitting region exceeds available wavelength range.  BADASS will adjust your fitting range automatically...
# 		- Input fitting range: (4400, 5500)
# 		- Available wavelength range: (2218, 5354)
# 		- New fitting region is (4400, 5355).
#
#
#
# -----------------------------------------------------------
#  file:                        spec-2756-54508-0579.fits
#  SDSS redshift:               0.71967
#  fitting region:              (4400,5355) [A]
#  velocity scale:              69.15 [km/s/pixel]
#  Galactic E(B-V):             0.032
#  Flux Normalization:          1.0e-17
# -----------------------------------------------------------
# 	- Adding parameter for unexplained variance for reduced Chi-squared.
# 	- Fitting a SSP host-galaxy template.
# 	- Fitting additive legendre polynomial component.
# 	- Fitting Simple AGN power-law continuum.
#
#  Performing line testing for [['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA']]
# ----------------------------------------------------------------------------------------------------
#
#  Performing test of NCOMP 0 versus NCOMP 1 for ['NA_OIII_5007', 'NA_OIII_4960', 'NA_H_BETA']...
#
# 	 Fitting NCOMP 0
# -------------------------------------------------------
#
#
# NOISE_SCALE
# 	 init = 1.0
# 	 plim = (0.0001, 100.0)
# 	 prior = {'type': 'jeffreys'}
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 29.131762146250143
# 	 plim = (0, 609.5398772334967)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_UNK_1_VOFF
# 	 init = 0.0
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_UNK_1_AMP
# 	 init = 44.629010232217816
# 	 plim = (0.0, 812.7198363113289)
# NA_UNK_1_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
#
#
# NA_UNK_1
# 	 center = 5200
# 	 line_type = na
# 	 line_profile = gaussian
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 ncomp = 1
# 	 center_pix = 726.478971008575
# 	 disp_res_ang = 0.7773961211552205
# 	 disp_res_kms = 44.81874884630564
#
#
#
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# basinhopping step 0: f 106.069
# basinhopping step 1: f 38.5188 trial_f 38.5188 accepted 1  lowest_f 38.5188
# found new global minimum on step 1 with function value 38.5188
# basinhopping step 2: f 38.2798 trial_f 38.2798 accepted 1  lowest_f 38.2798
# found new global minimum on step 2 with function value 38.2798
# basinhopping step 3: f 34.2108 trial_f 34.2108 accepted 1  lowest_f 34.2108
# found new global minimum on step 3 with function value 34.2108
# warning: basinhopping: local minimization failure
# basinhopping step 4: f 34.2108 trial_f 38.2391 accepted 0  lowest_f 34.2108
# basinhopping step 5: f 34.2108 trial_f 42.6455 accepted 0  lowest_f 34.2108
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 34.2108 trial_f inf accepted 0  lowest_f 34.2108
# basinhopping step 7: f 34.3848 trial_f 34.3848 accepted 1  lowest_f 34.2108
# basinhopping step 8: f 34.2985 trial_f 34.2985 accepted 1  lowest_f 34.2108
# warning: basinhopping: local minimization failure
# basinhopping step 9: f 29.0874 trial_f 29.0874 accepted 1  lowest_f 29.0874
# found new global minimum on step 9 with function value 29.0874
# warning: basinhopping: local minimization failure
# basinhopping step 10: f 29.0874 trial_f 36.475 accepted 0  lowest_f 29.0874
# basinhopping step 11: f 28.9251 trial_f 28.9251 accepted 1  lowest_f 28.9251
# found new global minimum on step 11 with function value 28.9251
# basinhopping step 12: f 28.8087 trial_f 28.8087 accepted 1  lowest_f 28.8087
# found new global minimum on step 12 with function value 28.8087
# basinhopping step 13: f 28.8087 trial_f 34.3431 accepted 0  lowest_f 28.8087
# basinhopping step 14: f 28.8108 trial_f 28.8108 accepted 1  lowest_f 28.8087
# warning: basinhopping: local minimization failure
# basinhopping step 15: f 28.8108 trial_f 29.0413 accepted 0  lowest_f 28.8087
# basinhopping step 16: f 28.9717 trial_f 28.9717 accepted 1  lowest_f 28.8087
# warning: basinhopping: local minimization failure
# basinhopping step 17: f 29.129 trial_f 29.129 accepted 1  lowest_f 28.8087
# basinhopping step 18: f 29.129 trial_f 33.4349 accepted 0  lowest_f 28.8087
# basinhopping step 19: f 28.9919 trial_f 28.9919 accepted 1  lowest_f 28.8087
# warning: basinhopping: local minimization failure
# basinhopping step 20: f 28.8596 trial_f 28.8596 accepted 1  lowest_f 28.8087
# basinhopping step 21: f 28.8596 trial_f 33.2955 accepted 0  lowest_f 28.8087
# warning: basinhopping: local minimization failure
# basinhopping step 22: f 28.8596 trial_f 34.2773 accepted 0  lowest_f 28.8087
# warning: basinhopping: local minimization failure
# basinhopping step 23: f 28.797 trial_f 28.797 accepted 1  lowest_f 28.797
# found new global minimum on step 23 with function value 28.797
# basinhopping step 24: f 33.3655 trial_f 33.3655 accepted 1  lowest_f 28.797
# basinhopping step 25: f 33.3484 trial_f 33.3484 accepted 1  lowest_f 28.797
# basinhopping step 26: f 33.3484 trial_f 37.4225 accepted 0  lowest_f 28.797
# warning: basinhopping: local minimization failure
# basinhopping step 27: f 33.3484 trial_f 38.4451 accepted 0  lowest_f 28.797
# warning: basinhopping: local minimization failure
# basinhopping step 28: f 30.865 trial_f 30.865 accepted 1  lowest_f 28.797
# basinhopping step 29: f 29.7514 trial_f 29.7514 accepted 1  lowest_f 28.797
# basinhopping step 30: f 29.7018 trial_f 29.7018 accepted 1  lowest_f 28.797
# basinhopping step 31: f 29.6304 trial_f 29.6304 accepted 1  lowest_f 28.797
# basinhopping step 32: f 29.7252 trial_f 29.7252 accepted 1  lowest_f 28.797
# basinhopping step 33: f 29.6158 trial_f 29.6158 accepted 1  lowest_f 28.797
# warning: basinhopping: local minimization failure
# basinhopping step 34: f 29.6173 trial_f 29.6173 accepted 1  lowest_f 28.797
# basinhopping step 35: f 29.6173 trial_f 34.4474 accepted 0  lowest_f 28.797
# basinhopping step 36: f 29.6558 trial_f 29.6558 accepted 1  lowest_f 28.797
# basinhopping step 37: f 29.6558 trial_f 34.1886 accepted 0  lowest_f 28.797
# warning: basinhopping: local minimization failure
# basinhopping step 38: f 29.6165 trial_f 29.6165 accepted 1  lowest_f 28.797
# warning: basinhopping: local minimization failure
# basinhopping step 39: f 29.6159 trial_f 29.6159 accepted 1  lowest_f 28.797
# basinhopping step 40: f 29.6643 trial_f 29.6643 accepted 1  lowest_f 28.797
# basinhopping step 41: f 29.6204 trial_f 29.6204 accepted 1  lowest_f 28.797
# basinhopping step 42: f 29.6204 trial_f 34.5031 accepted 0  lowest_f 28.797
# basinhopping step 43: f 29.6202 trial_f 29.6202 accepted 1  lowest_f 28.797
# warning: basinhopping: local minimization failure
# basinhopping step 44: f 29.952 trial_f 29.952 accepted 1  lowest_f 28.797
# basinhopping step 45: f 29.952 trial_f 34.418 accepted 0  lowest_f 28.797
# basinhopping step 46: f 29.6283 trial_f 29.6283 accepted 1  lowest_f 28.797
# warning: basinhopping: local minimization failure
# basinhopping step 47: f 29.8136 trial_f 29.8136 accepted 1  lowest_f 28.797
# basinhopping step 48: f 29.8136 trial_f 34.1621 accepted 0  lowest_f 28.797
# basinhopping step 49: f 30.3685 trial_f 30.3685 accepted 1  lowest_f 28.797
#
#  Performing Monte Carlo bootstrapping...
# 	   Completed 1 of 10 iterations.
# 	   Completed 2 of 10 iterations.
# 	   Completed 3 of 10 iterations.
# 	   Completed 4 of 10 iterations.
# 	   Completed 5 of 10 iterations.
# 	   Completed 6 of 10 iterations.
# 	   Completed 7 of 10 iterations.
# 	   Completed 8 of 10 iterations.
# 	   Completed 9 of 10 iterations.
# 	   Completed 10 of 10 iterations.
#
#
#  R-Squared = 0.8238
#
#
#  reduced Chi-Squared = 81.3825
#
#
#  Root Mean Squared Error = 0.5063
#
#
#  Mean Absolute Error = 0.2098
#
#
# -------------------------------------------------------
# 	 Fitting NCOMP 1
# -------------------------------------------------------
# NOISE_SCALE
# 	 init = 1.0
# 	 plim = (0.0001, 100.0)
# 	 prior = {'type': 'jeffreys'}
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 29.131762146250143
# 	 plim = (0, 609.5398772334967)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 126.06889615498525
# 	 plim = (0.0, 812.7198363113289)
# NA_H_BETA_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 395.25313466585817
# 	 plim = (0.0, 812.7198363113289)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# NA_UNK_1_VOFF
# 	 init = 0.0
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_UNK_1_AMP
# 	 init = 44.629010232217816
# 	 plim = (0.0, 812.7198363113289)
# NA_UNK_1_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# 16
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
# NA_UNK_1
# 	 center = 5200
# 	 line_type = na
# 	 line_profile = gaussian
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 ncomp = 1
# 	 center_pix = 726.478971008575
# 	 disp_res_ang = 0.7773961211552205
# 	 disp_res_kms = 44.81874884630564
#
#
#
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# warning: basinhopping: local minimization failure
# basinhopping step 0: f -306.073
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1944
#  Current RMSE: 0.1944
#  RMSE MAD: nan
#  RMSE STD: nan
#  RMSE Threshold: nan
#  Accepted count: 1
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -335.645 trial_f -335.645 accepted 1  lowest_f -335.645
# found new global minimum on step 1 with function value -335.645
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1893
#  Current RMSE: 0.1893
#  RMSE MAD: 0.0000
#  RMSE STD: 0.0000
#  RMSE Threshold: 0.1919
#  Accepted count: 2
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -337.208 trial_f -337.208 accepted 1  lowest_f -337.208
# found new global minimum on step 2 with function value -337.208
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1893
#  Current RMSE: 0.1893
#  RMSE MAD: 0.0025
#  RMSE STD: 0.0025
#  RMSE Threshold: 0.1919
#  Accepted count: 3
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -339 trial_f -339 accepted 1  lowest_f -339
# found new global minimum on step 3 with function value -339
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1884
#  Current RMSE: 0.1884
#  RMSE MAD: 0.0000
#  RMSE STD: 0.0024
#  RMSE Threshold: 0.1893
#  Accepted count: 4
#  Basinhop count: 0
#
#
# basinhopping step 4: f -339.018 trial_f -339.018 accepted 1  lowest_f -339.018
# found new global minimum on step 4 with function value -339.018
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1884
#  Current RMSE: 0.1885
#  RMSE MAD: 0.0005
#  RMSE STD: 0.0024
#  RMSE Threshold: 0.1898
#  Accepted count: 5
#  Basinhop count: 0
#
#
# basinhopping step 5: f -339.276 trial_f -339.276 accepted 1  lowest_f -339.276
# found new global minimum on step 5 with function value -339.276
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1884
#  Current RMSE: 0.1885
#  RMSE MAD: 0.0008
#  RMSE STD: 0.0022
#  RMSE Threshold: 0.1897
#  Accepted count: 6
#  Basinhop count: 0
#
#
# basinhopping step 6: f -339.276 trial_f -329.899 accepted 0  lowest_f -339.276
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1884
#  Current RMSE: 0.1916
#  RMSE MAD: 0.0004
#  RMSE STD: 0.0021
#  RMSE Threshold: 0.1897
#  Accepted count: 6
#  Basinhop count: 1
#
#
# basinhopping step 7: f -402.326 trial_f -402.326 accepted 1  lowest_f -402.326
# found new global minimum on step 7 with function value -402.326
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1770
#  Current RMSE: 0.1770
#  RMSE MAD: 0.0008
#  RMSE STD: 0.0021
#  RMSE Threshold: 0.1897
#  Accepted count: 7
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -402.326 trial_f -400.703 accepted 0  lowest_f -402.326
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1770
#  Current RMSE: 0.1774
#  RMSE MAD: 0.0005
#  RMSE STD: 0.0047
#  RMSE Threshold: 0.1890
#  Accepted count: 7
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -402.326 trial_f inf accepted 0  lowest_f -402.326
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1770
#  Current RMSE: 0.1854
#  RMSE MAD: 0.0008
#  RMSE STD: 0.0056
#  RMSE Threshold: 0.1893
#  Accepted count: 7
#  Basinhop count: 2
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -408.754 trial_f -408.754 accepted 1  lowest_f -408.754
# found new global minimum on step 10 with function value -408.754
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1755
#  Current RMSE: 0.1755
#  RMSE MAD: 0.0019
#  RMSE STD: 0.0054
#  RMSE Threshold: 0.1904
#  Accepted count: 8
#  Basinhop count: 0
#
#
# basinhopping step 11: f -407.488 trial_f -407.488 accepted 1  lowest_f -408.754
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1755
#  Current RMSE: 0.1757
#  RMSE MAD: 0.0030
#  RMSE STD: 0.0061
#  RMSE Threshold: 0.1915
#  Accepted count: 9
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -413.809 trial_f -413.809 accepted 1  lowest_f -413.809
# found new global minimum on step 12 with function value -413.809
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1749
#  Current RMSE: 0.1749
#  RMSE MAD: 0.0031
#  RMSE STD: 0.0065
#  RMSE Threshold: 0.1915
#  Accepted count: 10
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -562.973 trial_f -562.973 accepted 1  lowest_f -562.973
# found new global minimum on step 13 with function value -562.973
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.1394
#  Current RMSE: 0.1394
#  RMSE MAD: 0.0032
#  RMSE STD: 0.0068
#  RMSE Threshold: 0.1901
#  Accepted count: 11
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -931.992 trial_f -931.992 accepted 1  lowest_f -931.992
# found new global minimum on step 14 with function value -931.992
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0932
#  Current RMSE: 0.0932
#  RMSE MAD: 0.0061
#  RMSE STD: 0.0133
#  RMSE Threshold: 0.1915
#  Accepted count: 12
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -931.992 trial_f inf accepted 0  lowest_f -931.992
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0932
#  Current RMSE: 0.3111
#  RMSE MAD: 0.0081
#  RMSE STD: 0.0254
#  RMSE Threshold: 0.1950
#  Accepted count: 12
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -938.769 trial_f -938.769 accepted 1  lowest_f -938.769
# found new global minimum on step 16 with function value -938.769
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0924
#  Current RMSE: 0.0924
#  RMSE MAD: 0.0085
#  RMSE STD: 0.0411
#  RMSE Threshold: 0.1940
#  Accepted count: 13
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -942.704 trial_f -942.704 accepted 1  lowest_f -942.704
# found new global minimum on step 17 with function value -942.704
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0924
#  Current RMSE: 0.0925
#  RMSE MAD: 0.0084
#  RMSE STD: 0.0453
#  RMSE Threshold: 0.1898
#  Accepted count: 14
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 18: f -942.704 trial_f inf accepted 0  lowest_f -942.704
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0924
#  Current RMSE: 0.5241
#  RMSE MAD: 0.0075
#  RMSE STD: 0.0482
#  RMSE Threshold: 0.1930
#  Accepted count: 14
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -942.704 trial_f inf accepted 0  lowest_f -942.704
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0924
#  Current RMSE: 0.1732
#  RMSE MAD: 0.0090
#  RMSE STD: 0.0913
#  RMSE Threshold: 0.1903
#  Accepted count: 14
#  Basinhop count: 2
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -942.704 trial_f -928.427 accepted 0  lowest_f -942.704
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0924
#  Current RMSE: 0.0934
#  RMSE MAD: 0.0079
#  RMSE STD: 0.0890
#  RMSE Threshold: 0.1853
#  Accepted count: 14
#  Basinhop count: 3
#
#
# basinhopping step 21: f -942.704 trial_f -925.136 accepted 0  lowest_f -942.704
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0924
#  Current RMSE: 0.0936
#  RMSE MAD: 0.0120
#  RMSE STD: 0.0893
#  RMSE Threshold: 0.1891
#  Accepted count: 14
#  Basinhop count: 4
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -942.704 trial_f -940.148 accepted 0  lowest_f -942.704
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0924
#  Current RMSE: 0.0925
#  RMSE MAD: 0.0121
#  RMSE STD: 0.0894
#  RMSE Threshold: 0.1892
#  Accepted count: 14
#  Basinhop count: 5
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -943.979 trial_f -943.979 accepted 1  lowest_f -943.979
# found new global minimum on step 23 with function value -943.979
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0924
#  Current RMSE: 0.0924
#  RMSE MAD: 0.0123
#  RMSE STD: 0.0893
#  RMSE Threshold: 0.1887
#  Accepted count: 15
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -943.979 trial_f -942.19 accepted 0  lowest_f -943.979
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0924
#  Current RMSE: 0.0924
#  RMSE MAD: 0.0141
#  RMSE STD: 0.0891
#  RMSE Threshold: 0.1898
#  Accepted count: 15
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -944.279 trial_f -944.279 accepted 1  lowest_f -944.279
# found new global minimum on step 25 with function value -944.279
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0923
#  RMSE MAD: 0.0159
#  RMSE STD: 0.0888
#  RMSE Threshold: 0.1915
#  Accepted count: 16
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -944.279 trial_f inf accepted 0  lowest_f -944.279
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.1436
#  RMSE MAD: 0.0174
#  RMSE STD: 0.0884
#  RMSE Threshold: 0.1929
#  Accepted count: 16
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -944.545 trial_f -944.545 accepted 1  lowest_f -944.545
# found new global minimum on step 27 with function value -944.545
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0924
#  RMSE MAD: 0.0189
#  RMSE STD: 0.0869
#  RMSE Threshold: 0.1941
#  Accepted count: 17
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 28: f -944.545 trial_f inf accepted 0  lowest_f -944.545
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.2099
#  RMSE MAD: 0.0254
#  RMSE STD: 0.0864
#  RMSE Threshold: 0.2009
#  Accepted count: 17
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 29: f -944.545 trial_f inf accepted 0  lowest_f -944.545
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.1125
#  RMSE MAD: 0.0319
#  RMSE STD: 0.0853
#  RMSE Threshold: 0.2071
#  Accepted count: 17
#  Basinhop count: 2
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 30: f -944.545 trial_f -941.399 accepted 0  lowest_f -944.545
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0927
#  RMSE MAD: 0.0332
#  RMSE STD: 0.0845
#  RMSE Threshold: 0.2081
#  Accepted count: 17
#  Basinhop count: 3
#
#
# basinhopping step 31: f -944.642 trial_f -944.642 accepted 1  lowest_f -944.642
# found new global minimum on step 31 with function value -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0925
#  RMSE MAD: 0.0350
#  RMSE STD: 0.0840
#  RMSE Threshold: 0.2091
#  Accepted count: 18
#  Basinhop count: 0
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 32: f -944.642 trial_f -937.619 accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0951
#  RMSE MAD: 0.0353
#  RMSE STD: 0.0836
#  RMSE Threshold: 0.2085
#  Accepted count: 18
#  Basinhop count: 1
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 33: f -944.642 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.3962
#  RMSE MAD: 0.0367
#  RMSE STD: 0.0831
#  RMSE Threshold: 0.2107
#  Accepted count: 18
#  Basinhop count: 2
#
#
# basinhopping step 34: f -944.595 trial_f -944.595 accepted 1  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0924
#  RMSE MAD: 0.0487
#  RMSE STD: 0.0912
#  RMSE Threshold: 0.2219
#  Accepted count: 19
#  Basinhop count: 3
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 35: f -944.595 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.3661
#  RMSE MAD: 0.0607
#  RMSE STD: 0.0907
#  RMSE Threshold: 0.2348
#  Accepted count: 19
#  Basinhop count: 4
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 36: f -944.595 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.1090
#  RMSE MAD: 0.0703
#  RMSE STD: 0.0955
#  RMSE Threshold: 0.2435
#  Accepted count: 19
#  Basinhop count: 5
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 37: f -944.627 trial_f -944.627 accepted 1  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0925
#  RMSE MAD: 0.0642
#  RMSE STD: 0.0947
#  RMSE Threshold: 0.2227
#  Accepted count: 20
#  Basinhop count: 6
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 38: f -944.627 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.2439
#  RMSE MAD: 0.0574
#  RMSE STD: 0.0942
#  RMSE Threshold: 0.2307
#  Accepted count: 20
#  Basinhop count: 7
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 39: f -944.627 trial_f -928.861 accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0935
#  RMSE MAD: 0.0707
#  RMSE STD: 0.0938
#  RMSE Threshold: 0.2291
#  Accepted count: 20
#  Basinhop count: 8
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 40: f -944.627 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.2052
#  RMSE MAD: 0.0641
#  RMSE STD: 0.0933
#  RMSE Threshold: 0.2373
#  Accepted count: 20
#  Basinhop count: 9
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 41: f -944.627 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.1601
#  RMSE MAD: 0.0707
#  RMSE STD: 0.0924
#  RMSE Threshold: 0.2374
#  Accepted count: 20
#  Basinhop count: 10
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 42: f -944.627 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.2002
#  RMSE MAD: 0.0646
#  RMSE STD: 0.0913
#  RMSE Threshold: 0.2379
#  Accepted count: 20
#  Basinhop count: 11
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 43: f -944.627 trial_f -929.39 accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0936
#  RMSE MAD: 0.0642
#  RMSE STD: 0.0903
#  RMSE Threshold: 0.2309
#  Accepted count: 20
#  Basinhop count: 12
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 44: f -944.627 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.1832
#  RMSE MAD: 0.0646
#  RMSE STD: 0.0900
#  RMSE Threshold: 0.2379
#  Accepted count: 20
#  Basinhop count: 13
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 45: f -944.627 trial_f -929.324 accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0937
#  RMSE MAD: 0.0642
#  RMSE STD: 0.0890
#  RMSE Threshold: 0.2309
#  Accepted count: 20
#  Basinhop count: 14
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 46: f -944.627 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.1817
#  RMSE MAD: 0.0646
#  RMSE STD: 0.0887
#  RMSE Threshold: 0.2379
#  Accepted count: 20
#  Basinhop count: 15
#
#
# basinhopping step 47: f -944.627 trial_f -928.867 accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0934
#  RMSE MAD: 0.0642
#  RMSE STD: 0.0877
#  RMSE Threshold: 0.2309
#  Accepted count: 20
#  Basinhop count: 16
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 48: f -944.627 trial_f -929.2 accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0929
#  RMSE MAD: 0.0646
#  RMSE STD: 0.0874
#  RMSE Threshold: 0.2248
#  Accepted count: 20
#  Basinhop count: 17
#
#
# basinhopping step 49: f -944.627 trial_f -929.479 accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0936
#  RMSE MAD: 0.0650
#  RMSE STD: 0.0871
#  RMSE Threshold: 0.2169
#  Accepted count: 20
#  Basinhop count: 18
#
#
# adaptive stepsize: acceptance rate 0.380000 target 0.500000 new stepsize 9 old stepsize 10
# warning: basinhopping: local minimization failure
# basinhopping step 50: f -944.145 trial_f -944.145 accepted 1  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0925
#  RMSE MAD: 0.0581
#  RMSE STD: 0.0867
#  RMSE Threshold: 0.2016
#  Accepted count: 21
#  Basinhop count: 19
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 51: f -944.145 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0984
#  RMSE MAD: 0.0500
#  RMSE STD: 0.0864
#  RMSE Threshold: 0.1915
#  Accepted count: 21
#  Basinhop count: 20
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 52: f -944.377 trial_f -944.377 accepted 1  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0923
#  Current RMSE: 0.0925
#  RMSE MAD: 0.0480
#  RMSE STD: 0.0860
#  RMSE Threshold: 0.1874
#  Accepted count: 22
#  Basinhop count: 21
#
#
# basinhopping step 53: f -944.288 trial_f -944.288 accepted 1  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0922
#  Current RMSE: 0.0922
#  RMSE MAD: 0.0469
#  RMSE STD: 0.0856
#  RMSE Threshold: 0.1728
#  Accepted count: 23
#  Basinhop count: 22
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 54: f -944.288 trial_f -926.65 accepted 0  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0922
#  Current RMSE: 0.0933
#  RMSE MAD: 0.0336
#  RMSE STD: 0.0852
#  RMSE Threshold: 0.1461
#  Accepted count: 23
#  Basinhop count: 23
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 55: f -940.999 trial_f -940.999 accepted 1  lowest_f -944.642
#  Fit Status: False
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0922
#  Current RMSE: 0.0928
#  RMSE MAD: 0.0203
#  RMSE STD: 0.0849
#  RMSE Threshold: 0.1311
#  Accepted count: 24
#  Basinhop count: 24
#
#
# warning: basinhopping: local minimization failure
# basinhopping step 56: f -940.999 trial_f inf accepted 0  lowest_f -944.642
#  Fit Status: True
#  Force threshold: 0.5063
#  Lowest RMSE: 0.0922
#  Current RMSE: 0.1134
#  RMSE MAD: 0.0185
#  RMSE STD: 0.0845
#  RMSE Threshold: 0.1310
#  Accepted count: 24
#  Basinhop count: 25
#
#
#
#
#  R-Squared = 0.9941
#
#
#  reduced Chi-Squared = 8.1503
#
#
#  Root Mean Squared Error = 0.0925
#
#
#  Mean Absolute Error = 0.0655
#
#
# -------------------------------------------------------
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
