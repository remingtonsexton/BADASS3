# %% [markdown]
# ## Bayesian AGN Decomposition Analysis for SDSS Spectra (BADASS)
# ### Single Spectrum Configuration Test Example
#
# This notebook shows how to perform configuration testing.  Configuration testing is different from line testing.  Line testing performs tests on individual lines, whereas configurations can be multiple different lines simultaenously.  As a result, configuration testing requires the user to explicitly define which lines to test and the order to test them in.  BADASS will *not* discriminate between simple and complex models, but instead performs the fits in the order the user supplies them, and then will choose the best one.  It is up to the user to order the configurations in increasing complexity if the user wishes to test in such a way similar to the line test.
#
# In this example, we showcase how the configuration test is best utilized, and where the line test would fail.  Here we determine the best configuration to fit to the superposition of broad and narrow lines for the H$\alpha$/[NII] region.  The line test would fail in this regard because the line test cannot test broad and narrow lines simultaenously.
#
#
# ####  Remington O. Sexton$^{1}$, Sara M. Doan$^{2}$, William Matzko$^{2}$ Michael A. Reefe$^{2}$,
# $^{1}$United States Naval Observatory, $^{2}$George Mason University

# %%
import glob
import time
import natsort
from IPython.display import clear_output
import os
import sys
import psutil
import pathlib
import natsort
# Import BADASS here
BADASS_DIR = pathlib.Path(os.getcwd()).resolve().parent
sys.path.insert(1,str(BADASS_DIR))
import badass as badass
import badass_check_input
import badass_config_options

from IPython.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ### BADASS Options

# %%
options_file = "badass_config_options.py"

if os.path.exists(options_file):
    print("\n Options file %s found.\n" % (options_file))
# Out:
#  Options file badass_config_options.py found.

# %% [markdown]
# ### Run BADASS on a single spectrum
#
# The following is shows how to fit single SDSS spectra.

# %% [markdown]
# #### Directory Structure

# %%
nobj = 2 # Object in the spec_dir list
########################## Directory Structure #################################
spec_dir = '../example_spectra/' # folder with spectra in it
# Get full list of spectrum folders; these will be the working directories
spec_loc = natsort.natsorted( glob.glob(spec_dir+'*') )[nobj]

################################################################################
print(len(spec_loc))
print(spec_loc)
# Out:
# 25
# ../example_spectra/2-test

# %% [markdown]
# #### Choose Spectrum

# %%
file = glob.glob(spec_loc+'/*.fits')[0] # Get name of FITS spectra file
print(file)
# Out:
# ../example_spectra/2-test/spec-2756-54508-0579.fits

# %% [markdown]
# #### Run IRSA Dust Query
# To correct for Galactic extinction.  This only needs to be done once so that the data is stored locally.

# %%
badass_check_input.fetch_IRSA_dust(spec_loc)
# Out:
#  Fetching IRSA Dust for spectra...
#
#  Done fetching IRSA dust!

# %% [markdown]
# #### Run

# %%
import numpy as np
import importlib
importlib.reload(badass)
importlib.reload(badass_config_options)
if 1:
# for i in range(1):
#     np.random.seed()
#     print("\n---------------------------------------------------------")
#     print(" Begin Test %d of %d" % (i+1,10))
#     print("---------------------------------------------------------")
    
    # Call the main function in BADASS
    badass.run_BADASS(pathlib.Path(file), 
                      options_file = options_file,
                     )
        #
# Out:
# Start process memory: 0.27611546
#  Storing MCMC_output in ../example_spectra/2-test/MCMC_output_2/
#
#  > Starting fit for 2-test
#
#  Input fitting region exceeds available wavelength range.  BADASS will adjust your fitting range automatically...
# 		- Input fitting range: (4400, 5500)
# 		- Available wavelength range: (2218, 5354)
# 		- New fitting region is (4400, 5355).
#
#
#
# -----------------------------------------------------------
#  file:                        spec-2756-54508-0579.fits
#  SDSS redshift:               0.71967
#  fitting region:              (4400,5355) [A]
#  velocity scale:              69.15 [km/s/pixel]
#  Galactic E(B-V):             0.032
#  Flux Normalization:          1e-17
#  Fit Normalization:           406.35992
# -----------------------------------------------------------
# 	- Fitting a SSP host-galaxy template.
# 	- Fitting additive legendre polynomial component.
# 	- Fitting Simple AGN power-law continuum.
#
#  - ('BR_MGII_2799_DISP', 'NA_MGII_2799_DISP') soft constraint removed because one or more free parameters is not available.
#
#  - ('OUT_NII_6585_DISP', 'NA_NII_6585_DISP') soft constraint removed because one or more free parameters is not available.
#
#  Performing configuration testing for 5 configurations...
# ----------------------------------------------------------------------------------------------------
#
#  Performing test of configuration 1 versus configuration 2...
#
# 	 Fitting CONFIG 1
# -------------------------------------------------------
#
#
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_3
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 0.0716895557668437
# 	 plim = (0, 1.4999999931919876)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 0.31023949447323756
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 0.9726676161021446
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = NA_OIII_5007_DISP
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
#
#
#
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# basinhopping step 0: f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.9 old stepsize 1
# basinhopping step 1: f 16363.6 trial_f 1.27422e+07 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.81 old stepsize 0.9
# basinhopping step 2: f 16363.6 trial_f 6.96162e+06 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.729 old stepsize 0.81
# basinhopping step 3: f 16363.6 trial_f 4.82115e+06 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.6561 old stepsize 0.729
# basinhopping step 4: f 16363.6 trial_f 5.3217e+06 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.59049 old stepsize 0.6561
# basinhopping step 5: f 16363.6 trial_f 8.33961e+06 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.531441 old stepsize 0.59049
# basinhopping step 6: f 16363.6 trial_f 2.77141e+06 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.478297 old stepsize 0.531441
# basinhopping step 7: f 16363.6 trial_f 866611 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.430467 old stepsize 0.478297
# basinhopping step 8: f 16363.6 trial_f 897520 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.38742 old stepsize 0.430467
# basinhopping step 9: f 16363.6 trial_f 814878 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.348678 old stepsize 0.38742
# basinhopping step 10: f 16363.6 trial_f 223910 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.313811 old stepsize 0.348678
# basinhopping step 11: f 16363.6 trial_f 946640 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.28243 old stepsize 0.313811
# basinhopping step 12: f 16363.6 trial_f 1.16553e+06 accepted 0  lowest_f 16363.6
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.254187 old stepsize 0.28243
# warning: basinhopping: local minimization failure
# basinhopping step 13: f 16347.2 trial_f 16347.2 accepted 1  lowest_f 16347.2
# found new global minimum on step 13 with function value 16347.2
# adaptive stepsize: acceptance rate 0.071429 target 0.500000 new stepsize 0.228768 old stepsize 0.254187
# basinhopping step 14: f 16347.2 trial_f 513844 accepted 0  lowest_f 16347.2
# adaptive stepsize: acceptance rate 0.066667 target 0.500000 new stepsize 0.205891 old stepsize 0.228768
# basinhopping step 15: f 16347.2 trial_f 666207 accepted 0  lowest_f 16347.2
# adaptive stepsize: acceptance rate 0.062500 target 0.500000 new stepsize 0.185302 old stepsize 0.205891
# basinhopping step 16: f 16347.2 trial_f 147749 accepted 0  lowest_f 16347.2
# adaptive stepsize: acceptance rate 0.058824 target 0.500000 new stepsize 0.166772 old stepsize 0.185302
# basinhopping step 17: f 16347.2 trial_f 299050 accepted 0  lowest_f 16347.2
# adaptive stepsize: acceptance rate 0.055556 target 0.500000 new stepsize 0.150095 old stepsize 0.166772
# basinhopping step 18: f 16347.2 trial_f 81603.2 accepted 0  lowest_f 16347.2
# adaptive stepsize: acceptance rate 0.052632 target 0.500000 new stepsize 0.135085 old stepsize 0.150095
# basinhopping step 19: f 16347.2 trial_f 165014 accepted 0  lowest_f 16347.2
# adaptive stepsize: acceptance rate 0.050000 target 0.500000 new stepsize 0.121577 old stepsize 0.135085
# basinhopping step 20: f 16347.2 trial_f 157891 accepted 0  lowest_f 16347.2
# adaptive stepsize: acceptance rate 0.047619 target 0.500000 new stepsize 0.109419 old stepsize 0.121577
# basinhopping step 21: f 16347.2 trial_f 119244 accepted 0  lowest_f 16347.2
# adaptive stepsize: acceptance rate 0.045455 target 0.500000 new stepsize 0.0984771 old stepsize 0.109419
# basinhopping step 22: f 16324.6 trial_f 16324.6 accepted 1  lowest_f 16324.6
# found new global minimum on step 22 with function value 16324.6
# adaptive stepsize: acceptance rate 0.086957 target 0.500000 new stepsize 0.0886294 old stepsize 0.0984771
# basinhopping step 23: f 16324.6 trial_f 16405.3 accepted 0  lowest_f 16324.6
# adaptive stepsize: acceptance rate 0.083333 target 0.500000 new stepsize 0.0797664 old stepsize 0.0886294
# basinhopping step 24: f 16324.6 trial_f 16398.3 accepted 0  lowest_f 16324.6
# adaptive stepsize: acceptance rate 0.080000 target 0.500000 new stepsize 0.0717898 old stepsize 0.0797664
# warning: basinhopping: local minimization failure
# basinhopping step 25: f 16324.6 trial_f 16361.1 accepted 0  lowest_f 16324.6
# adaptive stepsize: acceptance rate 0.076923 target 0.500000 new stepsize 0.0646108 old stepsize 0.0717898
# basinhopping step 26: f 16323.8 trial_f 16323.8 accepted 1  lowest_f 16323.8
# found new global minimum on step 26 with function value 16323.8
# adaptive stepsize: acceptance rate 0.111111 target 0.500000 new stepsize 0.0581497 old stepsize 0.0646108
# basinhopping step 27: f 16323.8 trial_f 67463 accepted 0  lowest_f 16323.8
# adaptive stepsize: acceptance rate 0.107143 target 0.500000 new stepsize 0.0523348 old stepsize 0.0581497
# basinhopping step 28: f 16323.8 trial_f 16360.8 accepted 0  lowest_f 16323.8
# adaptive stepsize: acceptance rate 0.103448 target 0.500000 new stepsize 0.0471013 old stepsize 0.0523348
# basinhopping step 29: f 16323.8 trial_f 16328.7 accepted 0  lowest_f 16323.8
# adaptive stepsize: acceptance rate 0.100000 target 0.500000 new stepsize 0.0423912 old stepsize 0.0471013
# basinhopping step 30: f 16322.9 trial_f 16322.9 accepted 1  lowest_f 16322.9
# found new global minimum on step 30 with function value 16322.9
# adaptive stepsize: acceptance rate 0.129032 target 0.500000 new stepsize 0.038152 old stepsize 0.0423912
# basinhopping step 31: f 16322.9 trial_f 16323.4 accepted 0  lowest_f 16322.9
# adaptive stepsize: acceptance rate 0.125000 target 0.500000 new stepsize 0.0343368 old stepsize 0.038152
# basinhopping step 32: f 16322.9 trial_f 16338.5 accepted 0  lowest_f 16322.9
# adaptive stepsize: acceptance rate 0.121212 target 0.500000 new stepsize 0.0309032 old stepsize 0.0343368
# basinhopping step 33: f 16322.8 trial_f 16322.8 accepted 1  lowest_f 16322.8
# found new global minimum on step 33 with function value 16322.8
# adaptive stepsize: acceptance rate 0.147059 target 0.500000 new stepsize 0.0278128 old stepsize 0.0309032
# basinhopping step 34: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# found new global minimum on step 34 with function value 16322.1
# adaptive stepsize: acceptance rate 0.171429 target 0.500000 new stepsize 0.0250316 old stepsize 0.0278128
# basinhopping step 35: f 16322.1 trial_f 16333.3 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.166667 target 0.500000 new stepsize 0.0225284 old stepsize 0.0250316
# basinhopping step 36: f 16322.1 trial_f 16331 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.162162 target 0.500000 new stepsize 0.0202756 old stepsize 0.0225284
# basinhopping step 37: f 16322.1 trial_f 16324.5 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.157895 target 0.500000 new stepsize 0.018248 old stepsize 0.0202756
# basinhopping step 38: f 16322.8 trial_f 16322.8 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.179487 target 0.500000 new stepsize 0.0164232 old stepsize 0.018248
# basinhopping step 39: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.200000 target 0.500000 new stepsize 0.0147809 old stepsize 0.0164232
# basinhopping step 40: f 16322.2 trial_f 16326.2 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.195122 target 0.500000 new stepsize 0.0133028 old stepsize 0.0147809
# basinhopping step 41: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
# found new global minimum on step 41 with function value 16322.1
# adaptive stepsize: acceptance rate 0.214286 target 0.500000 new stepsize 0.0119725 old stepsize 0.0133028
# basinhopping step 42: f 16322.1 trial_f 16325.8 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.209302 target 0.500000 new stepsize 0.0107753 old stepsize 0.0119725
# basinhopping step 43: f 16325.2 trial_f 16325.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.227273 target 0.500000 new stepsize 0.00969774 old stepsize 0.0107753
# basinhopping step 44: f 16322.3 trial_f 16322.3 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.244444 target 0.500000 new stepsize 0.00872796 old stepsize 0.00969774
# basinhopping step 45: f 16322.3 trial_f 16326.2 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.239130 target 0.500000 new stepsize 0.00785517 old stepsize 0.00872796
# basinhopping step 46: f 16323.2 trial_f 16323.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.255319 target 0.500000 new stepsize 0.00706965 old stepsize 0.00785517
# basinhopping step 47: f 16322.4 trial_f 16322.4 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.270833 target 0.500000 new stepsize 0.00636269 old stepsize 0.00706965
# basinhopping step 48: f 16322.4 trial_f 16324.6 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.265306 target 0.500000 new stepsize 0.00572642 old stepsize 0.00636269
# basinhopping step 49: f 16322.4 trial_f 16322.5 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.260000 target 0.500000 new stepsize 0.00515378 old stepsize 0.00572642
# basinhopping step 50: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.274510 target 0.500000 new stepsize 0.0046384 old stepsize 0.00515378
# basinhopping step 51: f 16322.2 trial_f 16324.3 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.269231 target 0.500000 new stepsize 0.00417456 old stepsize 0.0046384
# basinhopping step 52: f 16322.7 trial_f 16322.7 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.283019 target 0.500000 new stepsize 0.0037571 old stepsize 0.00417456
# basinhopping step 53: f 16322.7 trial_f 16324.6 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.277778 target 0.500000 new stepsize 0.00338139 old stepsize 0.0037571
# basinhopping step 54: f 16322.7 trial_f 16324.1 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.272727 target 0.500000 new stepsize 0.00304325 old stepsize 0.00338139
# basinhopping step 55: f 16322.6 trial_f 16322.6 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.285714 target 0.500000 new stepsize 0.00273893 old stepsize 0.00304325
# basinhopping step 56: f 16323.2 trial_f 16323.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.298246 target 0.500000 new stepsize 0.00246503 old stepsize 0.00273893
# basinhopping step 57: f 16322.7 trial_f 16322.7 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.310345 target 0.500000 new stepsize 0.00221853 old stepsize 0.00246503
# basinhopping step 58: f 16323.1 trial_f 16323.1 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.322034 target 0.500000 new stepsize 0.00199668 old stepsize 0.00221853
# basinhopping step 59: f 16322.4 trial_f 16322.4 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.333333 target 0.500000 new stepsize 0.00179701 old stepsize 0.00199668
# basinhopping step 60: f 16322.7 trial_f 16322.7 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.344262 target 0.500000 new stepsize 0.00161731 old stepsize 0.00179701
# basinhopping step 61: f 16322.4 trial_f 16322.4 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.354839 target 0.500000 new stepsize 0.00145558 old stepsize 0.00161731
# basinhopping step 62: f 16322.4 trial_f 16324.2 accepted 0  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.349206 target 0.500000 new stepsize 0.00131002 old stepsize 0.00145558
# basinhopping step 63: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.359375 target 0.500000 new stepsize 0.00117902 old stepsize 0.00131002
# basinhopping step 64: f 16322.3 trial_f 16322.3 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.369231 target 0.500000 new stepsize 0.00106112 old stepsize 0.00117902
# basinhopping step 65: f 16322.3 trial_f 16322.3 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.378788 target 0.500000 new stepsize 0.000955005 old stepsize 0.00106112
# basinhopping step 66: f 16322.2 trial_f 16322.2 accepted 1  lowest_f 16322.1
# adaptive stepsize: acceptance rate 0.388060 target 0.500000 new stepsize 0.000859504 old stepsize 0.000955005
# basinhopping step 67: f 16322.1 trial_f 16322.1 accepted 1  lowest_f 16322.1
#
#
#  R-Squared = 0.9850
#
#
#  reduced Chi-Squared = 20.0098
#
#
#  Root Mean Squared Error = 1.2059
#
#
#  Mean Absolute Error = 0.0951
#
#
# -------------------------------------------------------
# 	 Fitting CONFIG 2
# -------------------------------------------------------
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_3
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 0.0716895557668437
# 	 plim = (0, 1.4999999931919876)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 0.31023949447323756
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 0.9726676161021446
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# BR_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# BR_H_BETA_AMP
# 	 init = 0.31023949447323756
# 	 plim = (0.0, 1.9999999909226502)
# BR_H_BETA_DISP
# 	 init = 500.0
# 	 plim = (300, 3000)
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = NA_OIII_5007_DISP
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
# BR_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = br
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
#
#
#
#
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 25
# warning: basinhopping: local minimization failure
# basinhopping step 0: f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.0669
#  Accepted count: 1
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.9 old stepsize 1
# basinhopping step 1: f 9275.61 trial_f 3.35649e+06 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 2.2855
#  Accepted count: 1
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.81 old stepsize 0.9
# basinhopping step 2: f 9275.61 trial_f 2.81134e+07 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 6.2504
#  Accepted count: 1
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.729 old stepsize 0.81
# warning: basinhopping: local minimization failure
# basinhopping step 3: f 9275.61 trial_f 1.42332e+07 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 5.0414
#  Accepted count: 1
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.6561 old stepsize 0.729
# basinhopping step 4: f 9275.61 trial_f 1.35997e+07 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 4.5602
#  Accepted count: 1
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.59049 old stepsize 0.6561
# basinhopping step 5: f 9275.61 trial_f 865252 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 1.1165
#  Accepted count: 1
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.531441 old stepsize 0.59049
# warning: basinhopping: local minimization failure
# basinhopping step 6: f 9275.61 trial_f 1.14999e+07 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 4.2085
#  Accepted count: 1
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.478297 old stepsize 0.531441
# basinhopping step 7: f 9275.61 trial_f 645175 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.9777
#  Accepted count: 1
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.430467 old stepsize 0.478297
# basinhopping step 8: f 9275.61 trial_f 3.12328e+06 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 2.0454
#  Accepted count: 1
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.38742 old stepsize 0.430467
# basinhopping step 9: f 9275.61 trial_f 119283 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.5417
#  Accepted count: 1
#  Basinhop count: 9
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.348678 old stepsize 0.38742
# basinhopping step 10: f 9275.61 trial_f 295935 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.7542
#  Accepted count: 1
#  Basinhop count: 10
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.313811 old stepsize 0.348678
# basinhopping step 11: f 9275.61 trial_f 487668 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.8051
#  Accepted count: 1
#  Basinhop count: 11
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.28243 old stepsize 0.313811
# basinhopping step 12: f 9275.61 trial_f 36472 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.2922
#  Accepted count: 1
#  Basinhop count: 12
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.254187 old stepsize 0.28243
# basinhopping step 13: f 9275.61 trial_f 925653 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 1.2028
#  Accepted count: 1
#  Basinhop count: 13
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.228768 old stepsize 0.254187
# basinhopping step 14: f 9275.61 trial_f 847100 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 1.0770
#  Accepted count: 1
#  Basinhop count: 14
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.205891 old stepsize 0.228768
# basinhopping step 15: f 9275.61 trial_f 125430 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.4552
#  Accepted count: 1
#  Basinhop count: 15
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.185302 old stepsize 0.205891
# basinhopping step 16: f 9275.61 trial_f 147934 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.5287
#  Accepted count: 1
#  Basinhop count: 16
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.166772 old stepsize 0.185302
# basinhopping step 17: f 9275.61 trial_f 67978.3 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.3196
#  Accepted count: 1
#  Basinhop count: 17
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.150095 old stepsize 0.166772
# basinhopping step 18: f 9275.61 trial_f 374913 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.7840
#  Accepted count: 1
#  Basinhop count: 18
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.135085 old stepsize 0.150095
# basinhopping step 19: f 9275.61 trial_f 169247 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.4815
#  Accepted count: 1
#  Basinhop count: 19
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.121577 old stepsize 0.135085
# basinhopping step 20: f 9275.61 trial_f 147651 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.4848
#  Accepted count: 1
#  Basinhop count: 20
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.109419 old stepsize 0.121577
# basinhopping step 21: f 9275.61 trial_f 386172 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.7034
#  Accepted count: 1
#  Basinhop count: 21
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.0984771 old stepsize 0.109419
# basinhopping step 22: f 9275.61 trial_f 13967.7 accepted 0  lowest_f 9275.61
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0669
#  Current RMSE: 0.1280
#  Accepted count: 1
#  Basinhop count: 22
#
#
# adaptive stepsize: acceptance rate 0.000000 target 0.500000 new stepsize 0.0886294 old stepsize 0.0984771
# basinhopping step 23: f 9275.22 trial_f 9275.22 accepted 1  lowest_f 9275.22
# found new global minimum on step 23 with function value 9275.22
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 2
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.041667 target 0.500000 new stepsize 0.0797664 old stepsize 0.0886294
# basinhopping step 24: f 9275.22 trial_f 65518.3 accepted 0  lowest_f 9275.22
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.2864
#  Accepted count: 2
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.040000 target 0.500000 new stepsize 0.0717898 old stepsize 0.0797664
# basinhopping step 25: f 9275.22 trial_f 139662 accepted 0  lowest_f 9275.22
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.4842
#  Accepted count: 2
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.038462 target 0.500000 new stepsize 0.0646108 old stepsize 0.0717898
# basinhopping step 26: f 9275.22 trial_f 9278.92 accepted 0  lowest_f 9275.22
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 2
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.037037 target 0.500000 new stepsize 0.0581497 old stepsize 0.0646108
# basinhopping step 27: f 9275.22 trial_f 9276.05 accepted 0  lowest_f 9275.22
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 2
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.035714 target 0.500000 new stepsize 0.0523348 old stepsize 0.0581497
# basinhopping step 28: f 9275.22 trial_f 95853.8 accepted 0  lowest_f 9275.22
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.3680
#  Accepted count: 2
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.034483 target 0.500000 new stepsize 0.0471013 old stepsize 0.0523348
# warning: basinhopping: local minimization failure
# basinhopping step 29: f 9275.22 trial_f 9281.26 accepted 0  lowest_f 9275.22
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0670
#  Accepted count: 2
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.033333 target 0.500000 new stepsize 0.0423912 old stepsize 0.0471013
# basinhopping step 30: f 9275.22 trial_f 75288.2 accepted 0  lowest_f 9275.22
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.3055
#  Accepted count: 2
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.032258 target 0.500000 new stepsize 0.038152 old stepsize 0.0423912
# basinhopping step 31: f 9275.22 trial_f 9276.08 accepted 0  lowest_f 9275.22
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 2
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.031250 target 0.500000 new stepsize 0.0343368 old stepsize 0.038152
# basinhopping step 32: f 9274.74 trial_f 9274.74 accepted 1  lowest_f 9274.74
# found new global minimum on step 32 with function value 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 3
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.060606 target 0.500000 new stepsize 0.0309032 old stepsize 0.0343368
# basinhopping step 33: f 9274.74 trial_f 17445.6 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.1327
#  Accepted count: 3
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.058824 target 0.500000 new stepsize 0.0278128 old stepsize 0.0309032
# warning: basinhopping: local minimization failure
# basinhopping step 34: f 9274.74 trial_f 9278.51 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0668
#  Accepted count: 3
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.057143 target 0.500000 new stepsize 0.0250316 old stepsize 0.0278128
# basinhopping step 35: f 9274.74 trial_f 9277.8 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 3
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.055556 target 0.500000 new stepsize 0.0225284 old stepsize 0.0250316
# basinhopping step 36: f 9274.74 trial_f 9278.24 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 3
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.054054 target 0.500000 new stepsize 0.0202756 old stepsize 0.0225284
# basinhopping step 37: f 9274.74 trial_f 9279.44 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 3
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.052632 target 0.500000 new stepsize 0.018248 old stepsize 0.0202756
# basinhopping step 38: f 9274.74 trial_f 9889.1 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0738
#  Accepted count: 3
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.051282 target 0.500000 new stepsize 0.0164232 old stepsize 0.018248
# basinhopping step 39: f 9274.74 trial_f 9275.42 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 3
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.050000 target 0.500000 new stepsize 0.0147809 old stepsize 0.0164232
# basinhopping step 40: f 9274.74 trial_f 9759.19 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0723
#  Accepted count: 3
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.048780 target 0.500000 new stepsize 0.0133028 old stepsize 0.0147809
# basinhopping step 41: f 9274.74 trial_f 10190.4 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0755
#  Accepted count: 3
#  Basinhop count: 9
#
#
# adaptive stepsize: acceptance rate 0.047619 target 0.500000 new stepsize 0.0119725 old stepsize 0.0133028
# basinhopping step 42: f 9274.74 trial_f 9923.09 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0740
#  Accepted count: 3
#  Basinhop count: 10
#
#
# adaptive stepsize: acceptance rate 0.046512 target 0.500000 new stepsize 0.0107753 old stepsize 0.0119725
# basinhopping step 43: f 9274.74 trial_f 9278.11 accepted 0  lowest_f 9274.74
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 3
#  Basinhop count: 11
#
#
# adaptive stepsize: acceptance rate 0.045455 target 0.500000 new stepsize 0.00969774 old stepsize 0.0107753
# basinhopping step 44: f 9274.73 trial_f 9274.73 accepted 1  lowest_f 9274.73
# found new global minimum on step 44 with function value 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 4
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.066667 target 0.500000 new stepsize 0.00872796 old stepsize 0.00969774
# basinhopping step 45: f 9274.73 trial_f 9278.67 accepted 0  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 4
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.065217 target 0.500000 new stepsize 0.00785517 old stepsize 0.00872796
# basinhopping step 46: f 9274.73 trial_f 9275.57 accepted 0  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0668
#  Accepted count: 4
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.063830 target 0.500000 new stepsize 0.00706965 old stepsize 0.00785517
# basinhopping step 47: f 9274.83 trial_f 9274.83 accepted 1  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 5
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.083333 target 0.500000 new stepsize 0.00636269 old stepsize 0.00706965
# basinhopping step 48: f 9274.83 trial_f 9278.42 accepted 0  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 5
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.081633 target 0.500000 new stepsize 0.00572642 old stepsize 0.00636269
# basinhopping step 49: f 9278.38 trial_f 9278.38 accepted 1  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 6
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.100000 target 0.500000 new stepsize 0.00515378 old stepsize 0.00572642
# basinhopping step 50: f 9275.89 trial_f 9275.89 accepted 1  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 7
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.117647 target 0.500000 new stepsize 0.0046384 old stepsize 0.00515378
# warning: basinhopping: local minimization failure
# basinhopping step 51: f 9275.89 trial_f 9278.51 accepted 0  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 7
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.115385 target 0.500000 new stepsize 0.00417456 old stepsize 0.0046384
# basinhopping step 52: f 9274.88 trial_f 9274.88 accepted 1  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 8
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.132075 target 0.500000 new stepsize 0.0037571 old stepsize 0.00417456
# basinhopping step 53: f 9274.76 trial_f 9274.76 accepted 1  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 9
#  Basinhop count: 9
#
#
# adaptive stepsize: acceptance rate 0.148148 target 0.500000 new stepsize 0.00338139 old stepsize 0.0037571
# basinhopping step 54: f 9274.76 trial_f 9275.64 accepted 0  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0668
#  Accepted count: 9
#  Basinhop count: 10
#
#
# adaptive stepsize: acceptance rate 0.145455 target 0.500000 new stepsize 0.00304325 old stepsize 0.00338139
# basinhopping step 55: f 9274.76 trial_f 9278.27 accepted 0  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 9
#  Basinhop count: 11
#
#
# adaptive stepsize: acceptance rate 0.142857 target 0.500000 new stepsize 0.00273893 old stepsize 0.00304325
# basinhopping step 56: f 9275.06 trial_f 9275.06 accepted 1  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 10
#  Basinhop count: 12
#
#
# adaptive stepsize: acceptance rate 0.157895 target 0.500000 new stepsize 0.00246503 old stepsize 0.00273893
# basinhopping step 57: f 9274.91 trial_f 9274.91 accepted 1  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 11
#  Basinhop count: 13
#
#
# adaptive stepsize: acceptance rate 0.172414 target 0.500000 new stepsize 0.00221853 old stepsize 0.00246503
# basinhopping step 58: f 9274.91 trial_f 9275.89 accepted 0  lowest_f 9274.73
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 11
#  Basinhop count: 14
#
#
# adaptive stepsize: acceptance rate 0.169492 target 0.500000 new stepsize 0.00199668 old stepsize 0.00221853
# basinhopping step 59: f 9274.71 trial_f 9274.71 accepted 1  lowest_f 9274.71
# found new global minimum on step 59 with function value 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 12
#  Basinhop count: 0
#
#
# adaptive stepsize: acceptance rate 0.183333 target 0.500000 new stepsize 0.00179701 old stepsize 0.00199668
# basinhopping step 60: f 9274.71 trial_f 9275.24 accepted 0  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 12
#  Basinhop count: 1
#
#
# adaptive stepsize: acceptance rate 0.180328 target 0.500000 new stepsize 0.00161731 old stepsize 0.00179701
# basinhopping step 61: f 9274.72 trial_f 9274.72 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 13
#  Basinhop count: 2
#
#
# adaptive stepsize: acceptance rate 0.193548 target 0.500000 new stepsize 0.00145558 old stepsize 0.00161731
# basinhopping step 62: f 9274.97 trial_f 9274.97 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0665
#  Accepted count: 14
#  Basinhop count: 3
#
#
# adaptive stepsize: acceptance rate 0.206349 target 0.500000 new stepsize 0.00131002 old stepsize 0.00145558
# basinhopping step 63: f 9274.72 trial_f 9274.72 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 15
#  Basinhop count: 4
#
#
# adaptive stepsize: acceptance rate 0.218750 target 0.500000 new stepsize 0.00117902 old stepsize 0.00131002
# basinhopping step 64: f 9274.88 trial_f 9274.88 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 16
#  Basinhop count: 5
#
#
# adaptive stepsize: acceptance rate 0.230769 target 0.500000 new stepsize 0.00106112 old stepsize 0.00117902
# basinhopping step 65: f 9275.15 trial_f 9275.15 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 17
#  Basinhop count: 6
#
#
# adaptive stepsize: acceptance rate 0.242424 target 0.500000 new stepsize 0.000955005 old stepsize 0.00106112
# basinhopping step 66: f 9275.52 trial_f 9275.52 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 18
#  Basinhop count: 7
#
#
# adaptive stepsize: acceptance rate 0.253731 target 0.500000 new stepsize 0.000859504 old stepsize 0.000955005
# basinhopping step 67: f 9275.54 trial_f 9275.54 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 19
#  Basinhop count: 8
#
#
# adaptive stepsize: acceptance rate 0.264706 target 0.500000 new stepsize 0.000773554 old stepsize 0.000859504
# basinhopping step 68: f 9275.54 trial_f 9276.07 accepted 0  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0668
#  Accepted count: 19
#  Basinhop count: 9
#
#
# adaptive stepsize: acceptance rate 0.260870 target 0.500000 new stepsize 0.000696199 old stepsize 0.000773554
# basinhopping step 69: f 9275.54 trial_f 9276.08 accepted 0  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 19
#  Basinhop count: 10
#
#
# adaptive stepsize: acceptance rate 0.257143 target 0.500000 new stepsize 0.000626579 old stepsize 0.000696199
# basinhopping step 70: f 9275.45 trial_f 9275.45 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 20
#  Basinhop count: 11
#
#
# adaptive stepsize: acceptance rate 0.267606 target 0.500000 new stepsize 0.000563921 old stepsize 0.000626579
# basinhopping step 71: f 9275.64 trial_f 9275.64 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 21
#  Basinhop count: 12
#
#
# adaptive stepsize: acceptance rate 0.277778 target 0.500000 new stepsize 0.000507529 old stepsize 0.000563921
# basinhopping step 72: f 9275.54 trial_f 9275.54 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 22
#  Basinhop count: 13
#
#
# adaptive stepsize: acceptance rate 0.287671 target 0.500000 new stepsize 0.000456776 old stepsize 0.000507529
# basinhopping step 73: f 9275.55 trial_f 9275.55 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 23
#  Basinhop count: 14
#
#
# adaptive stepsize: acceptance rate 0.297297 target 0.500000 new stepsize 0.000411098 old stepsize 0.000456776
# basinhopping step 74: f 9275.52 trial_f 9275.52 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 24
#  Basinhop count: 15
#
#
# adaptive stepsize: acceptance rate 0.306667 target 0.500000 new stepsize 0.000369988 old stepsize 0.000411098
# basinhopping step 75: f 9275.28 trial_f 9275.28 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 25
#  Basinhop count: 16
#
#
# adaptive stepsize: acceptance rate 0.315789 target 0.500000 new stepsize 0.00033299 old stepsize 0.000369988
# basinhopping step 76: f 9275.18 trial_f 9275.18 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0667
#  Accepted count: 26
#  Basinhop count: 17
#
#
# adaptive stepsize: acceptance rate 0.324675 target 0.500000 new stepsize 0.000299691 old stepsize 0.00033299
# basinhopping step 77: f 9275.07 trial_f 9275.07 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 27
#  Basinhop count: 18
#
#
# adaptive stepsize: acceptance rate 0.333333 target 0.500000 new stepsize 0.000269722 old stepsize 0.000299691
# basinhopping step 78: f 9274.91 trial_f 9274.91 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 28
#  Basinhop count: 19
#
#
# adaptive stepsize: acceptance rate 0.341772 target 0.500000 new stepsize 0.000242749 old stepsize 0.000269722
# basinhopping step 79: f 9274.91 trial_f 9274.91 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 29
#  Basinhop count: 20
#
#
# adaptive stepsize: acceptance rate 0.350000 target 0.500000 new stepsize 0.000218475 old stepsize 0.000242749
# basinhopping step 80: f 9274.87 trial_f 9274.87 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 30
#  Basinhop count: 21
#
#
# adaptive stepsize: acceptance rate 0.358025 target 0.500000 new stepsize 0.000196627 old stepsize 0.000218475
# basinhopping step 81: f 9274.87 trial_f 9274.87 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 31
#  Basinhop count: 22
#
#
# adaptive stepsize: acceptance rate 0.365854 target 0.500000 new stepsize 0.000176964 old stepsize 0.000196627
# basinhopping step 82: f 9274.92 trial_f 9274.92 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 32
#  Basinhop count: 23
#
#
# adaptive stepsize: acceptance rate 0.373494 target 0.500000 new stepsize 0.000159268 old stepsize 0.000176964
# basinhopping step 83: f 9274.89 trial_f 9274.89 accepted 1  lowest_f 9274.71
#  Fit Status: False
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 33
#  Basinhop count: 24
#
#
# adaptive stepsize: acceptance rate 0.380952 target 0.500000 new stepsize 0.000143341 old stepsize 0.000159268
# basinhopping step 84: f 9274.91 trial_f 9274.91 accepted 1  lowest_f 9274.71
#  Fit Status: True
#  Force threshold: 1.2059
#  Lowest RMSE: 0.0665
#  Current RMSE: 0.0666
#  Accepted count: 34
#  Basinhop count: 25
#
#
#
#
#  R-Squared = 0.9970
#
#
#  reduced Chi-Squared = 3.2692
#
#
#  Root Mean Squared Error = 0.0665
#
#
#  Mean Absolute Error = 0.0422
#
#
# -------------------------------------------------------
#
#  Performing test of configuration 2 versus configuration 3...
#
# 	 Fitting CONFIG 3
# -------------------------------------------------------
# HOST_TEMP_VEL
# 	 init = 0.0
# 	 plim = (-500.0, 500)
# HOST_TEMP_DISP
# 	 init = 100.0
# 	 plim = (0.001, 500.0)
# APOLY_COEFF_1
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_2
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# APOLY_COEFF_3
# 	 init = 0.0
# 	 plim = (-100.0, 100.0)
# POWER_AMP
# 	 init = 0.0716895557668437
# 	 plim = (0, 1.4999999931919876)
# POWER_SLOPE
# 	 init = -1.0
# 	 plim = (-6.0, 6.0)
# NA_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_H_BETA_AMP
# 	 init = 0.15511974723661878
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_AMP
# 	 init = 0.4863338080510723
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# NA_OIII_5007_2_VOFF
# 	 init = -89.51267826969064
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# NA_OIII_5007_2_AMP
# 	 init = 0.4863338080510723
# 	 plim = (0.0, 1.9999999909226502)
# NA_OIII_5007_2_DISP
# 	 init = 50.0
# 	 plim = (0, 1000)
# BR_H_BETA_VOFF
# 	 init = 54.39160208657732
# 	 plim = (-1000, 1000)
# 	 prior = {'type': 'gaussian'}
# BR_H_BETA_AMP
# 	 init = 0.31023949447323756
# 	 plim = (0.0, 1.9999999909226502)
# BR_H_BETA_DISP
# 	 init = 500.0
# 	 plim = (300, 3000)
#
#
# NA_H_BETA
# 	 center = 4862.691
# 	 amp = free
# 	 disp = NA_OIII_5007_DISP
# 	 voff = free
# 	 line_type = na
# 	 label = H$\beta$
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 435.21099039301293
# 	 disp_res_ang = 0.7266926172967304
# 	 disp_res_kms = 44.80172932021387
# NA_OIII_4960
# 	 center = 4960.295
# 	 amp = (NA_OIII_5007_AMP/2.98)
# 	 disp = NA_OIII_5007_DISP
# 	 voff = NA_OIII_5007_VOFF
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 521.5197602739727
# 	 disp_res_ang = 0.7349264587941482
# 	 disp_res_kms = 44.41780368529158
# NA_OIII_5007
# 	 center = 5008.24
# 	 amp = free
# 	 disp = free
# 	 voff = free
# 	 line_type = na
# 	 label = [O III]
# 	 ncomp = 1
# 	 line_profile = gaussian
# 	 center_pix = 563.2959830508472
# 	 disp_res_ang = 0.7407543175269816
# 	 disp_res_kms = 44.341436837197556
# NA_H_BETA_2
# 	 center = 4862.691
# 	 amp = NA_H_BETA_AMP*(NA_OIII_5007_2_AMP/NA_OIII_5007_AMP)
# 	 disp = NA_OIII_5007_2_DISP
# 	 voff = NA_OIII_5007_2_VOFF
# 	 line_type = na
# 	 ncomp = 2
# 	 parent = NA_H_BETA
# 	 line_profile = gaussian
# ...
# NA_H_BETA_2_W80               1321.306839                   106.847115                    0.0
# NA_H_BETA_2_W80_CORR          1316.292283                   106.847115                    0.0
# NA_H_BETA_AMP                 29.260737                     1.287223                      0.0
# NA_H_BETA_COMB_DISP           322.642944                    11.660242                     0.0
# NA_H_BETA_COMB_DISP_CORR      319.517252                    11.660242                     0.0
# NA_H_BETA_COMB_DISP_RES       44.801729                     nan                           nan
# NA_H_BETA_COMB_EW             10.535641                     0.329635                      0.0
# NA_H_BETA_COMB_FLUX           -14.234286                    0.013255                      0.0
# NA_H_BETA_COMB_FWHM           518.210627                    5.409761                      0.0
# NA_H_BETA_COMB_FWHM_CORR      507.358050                    5.409761                      0.0
# NA_H_BETA_COMB_LUM            43.131933                     0.013255                      0.0
# NA_H_BETA_COMB_NPIX           20.000000                     0.891279                      0.0
# NA_H_BETA_COMB_SNR            14.826560                     0.466585                      0.0
# NA_H_BETA_COMB_VOFF           -23.891543                    7.360107                      0.0
# NA_H_BETA_COMB_W80            728.679319                    8.762566                      0.0
# NA_H_BETA_COMB_W80_CORR       719.546497                    8.762566                      0.0
# NA_H_BETA_DISP                200.266328                    5.140961                      0.0
# NA_H_BETA_DISP_CORR           195.190695                    5.140961                      0.0
# NA_H_BETA_DISP_RES            44.801729                     nan                           nan
# NA_H_BETA_EW                  7.389898                      0.476483                      0.0
# NA_H_BETA_FLUX                -14.388297                    0.028456                      0.0
# NA_H_BETA_FWHM                474.054536                    12.017757                     0.0
# NA_H_BETA_FWHM_CORR           462.166248                    12.017757                     0.0
# NA_H_BETA_LUM                 42.977921                     0.028456                      0.0
# NA_H_BETA_NPIX                13.000000                     0.277350                      0.0
# NA_H_BETA_SNR                 17.397369                     0.776423                      0.0
# NA_H_BETA_VOFF                -27.892751                    11.345511                     0.0
# NA_H_BETA_W80                 527.849670                    14.105126                     0.0
# NA_H_BETA_W80_CORR            515.168793                    14.105126                     0.0
# NA_OIII_4960_2_AMP            16.511819                     9.733643                      0.0
# NA_OIII_4960_2_DISP           504.388905                    40.846451                     0.0
# NA_OIII_4960_2_DISP_CORR      502.429324                    40.846451                     0.0
# NA_OIII_4960_2_DISP_RES       44.417804                     nan                           nan
# NA_OIII_4960_2_EW             11.052715                     1.150553                      0.0
# NA_OIII_4960_2_FLUX           -14.226970                    0.043174                      0.0
# NA_OIII_4960_2_FWHM           1188.977492                   96.373453                     0.0
# NA_OIII_4960_2_FWHM_CORR      1184.367913                   96.373453                     0.0
# NA_OIII_4960_2_LUM            43.139249                     0.043174                      0.0
# NA_OIII_4960_2_NPIX           32.000000                     1.240944                      0.0
# NA_OIII_4960_2_SNR            9.830122                      1.946853                      0.0
# NA_OIII_4960_2_VOFF           -14.492468                    10.816773                     0.0
# NA_OIII_4960_2_W80            1322.256882                   106.961506                    0.0
# NA_OIII_4960_2_W80_CORR       1317.331616                   106.961506                    0.0
# NA_OIII_4960_AMP              97.708266                     8.401159                      0.0
# NA_OIII_4960_COMB_DISP        322.672127                    11.732412                     0.0
# NA_OIII_4960_COMB_DISP_CORR   319.600314                    11.732412                     0.0
# NA_OIII_4960_COMB_DISP_RES    44.417804                     nan                           nan
# NA_OIII_4960_COMB_EW          37.016831                     0.371698                      0.0
# NA_OIII_4960_COMB_FLUX        -13.702005                    0.003408                      0.0
# NA_OIII_4960_COMB_FWHM        517.853009                    5.357010                      0.0
# NA_OIII_4960_COMB_FWHM_CORR   507.180062                    5.357010                      0.0
# NA_OIII_4960_COMB_LUM         43.664214                     0.003408                      0.0
# NA_OIII_4960_COMB_NPIX        32.000000                     1.240944                      0.0
# NA_OIII_4960_COMB_SNR         58.853478                     0.527759                      0.0
# NA_OIII_4960_COMB_VOFF        -24.038388                    3.034847                      0.0
# NA_OIII_4960_COMB_W80         728.231973                    10.209346                     0.0
# NA_OIII_4960_COMB_W80_CORR    719.250396                    10.209346                     0.0
# NA_OIII_4960_DISP             200.266328                    5.140961                      0.0
# NA_OIII_4960_DISP_CORR        195.278419                    5.140961                      0.0
# NA_OIII_4960_DISP_RES         44.417804                     nan                           nan
# NA_OIII_4960_EW               25.964116                     1.408872                      0.0
# NA_OIII_4960_FLUX             -13.856016                    0.023819                      0.0
# NA_OIII_4960_FWHM             473.803731                    12.121835                     0.0
# NA_OIII_4960_FWHM_CORR        462.114545                    12.121835                     0.0
# NA_OIII_4960_LUM              43.510203                     0.023819                      0.0
# NA_OIII_4960_NPIX             17.000000                     0.481922                      0.0
# NA_OIII_4960_SNR              58.177523                     1.684096                      0.0
# NA_OIII_4960_VOFF             -28.100322                    1.199653                      0.0
# NA_OIII_4960_W80              526.833439                    13.904571                     0.0
# NA_OIII_4960_W80_CORR         514.346962                    13.904571                     0.0
# NA_OIII_5007_2_AMP            49.205219                     9.733643                      0.0
# NA_OIII_5007_2_DISP           504.388905                    40.846451                     0.0
# NA_OIII_5007_2_DISP_CORR      502.436070                    40.846451                     0.0
# NA_OIII_5007_2_DISP_RES       44.341437                     nan                           nan
# NA_OIII_5007_2_EW             33.860400                     3.521699                      0.0
# NA_OIII_5007_2_FLUX           -13.748572                    0.043174                      0.0
# NA_OIII_5007_2_FWHM           1188.503164                   96.323614                     0.0
# NA_OIII_5007_2_FWHM_CORR      1183.907612                   96.323614                     0.0
# NA_OIII_5007_2_LUM            43.617647                     0.043174                      0.0
# NA_OIII_5007_2_NPIX           39.000000                     2.278339                      0.0
# NA_OIII_5007_2_SNR            29.318200                     5.800534                      0.0
# NA_OIII_5007_2_VOFF           -14.492468                    10.816773                     0.0
# NA_OIII_5007_2_W80            1321.941536                   106.823841                    0.0
# NA_OIII_5007_2_W80_CORR       1317.032047                   106.823841                    0.0
# NA_OIII_5007_AMP              291.170633                    8.401159                      0.0
# NA_OIII_5007_COMB_DISP        322.680769                    11.733713                     0.0
# NA_OIII_5007_COMB_DISP_CORR   319.619642                    11.733713                     0.0
# NA_OIII_5007_COMB_DISP_RES    44.341437                     nan                           nan
# NA_OIII_5007_COMB_EW          113.401856                    1.147670                      0.0
# NA_OIII_5007_COMB_FLUX        -13.223604                    0.003408                      0.0
# NA_OIII_5007_COMB_FWHM        517.828773                    5.367845                      0.0
# NA_OIII_5007_COMB_FWHM_CORR   507.192370                    5.367845                      0.0
# NA_OIII_5007_COMB_LUM         44.142615                     0.003408                      0.0
# NA_OIII_5007_COMB_NPIX        39.000000                     2.278339                      0.0
# NA_OIII_5007_COMB_SNR         135.933633                    2.933115                      0.0
# NA_OIII_5007_COMB_VOFF        -24.037855                    3.034872                      0.0
# NA_OIII_5007_COMB_W80         728.307517                    8.872735                      0.0
# NA_OIII_5007_COMB_W80_CORR    719.357928                    8.872735                      0.0
# NA_OIII_5007_DISP             200.266328                    5.140961                      0.0
# NA_OIII_5007_DISP_CORR        195.295774                    5.140961                      0.0
# NA_OIII_5007_DISP_RES         44.341437                     nan                           nan
# NA_OIII_5007_EW               79.541457                     4.324670                      0.0
# NA_OIII_5007_FLUX             -13.377613                    0.023818                      0.0
# NA_OIII_5007_FWHM             473.796904                    12.129412                     0.0
# NA_OIII_5007_FWHM_CORR        462.148211                    12.129412                     0.0
# NA_OIII_5007_LUM              43.988606                     0.023818                      0.0
# NA_OIII_5007_NPIX             19.000000                     0.746788                      0.0
# NA_OIII_5007_SNR              173.375841                    5.001106                      0.0
# NA_OIII_5007_VOFF             -28.100322                    1.199653                      0.0
# NA_OIII_5007_W80              528.223277                    14.849428                     0.0
# NA_OIII_5007_W80_CORR         515.813747                    14.849428                     0.0
# NA_UNK_1_AMP                  0.000375                      0.000000                      0.0
# NA_UNK_1_DISP                 482.084451                    0.000000                      1.0
# NA_UNK_1_DISP_CORR            479.996560                    0.000000                      1.0
# NA_UNK_1_DISP_RES             44.818749                     nan                           nan
# NA_UNK_1_EW                   0.000000                      0.000000                      1.0
# NA_UNK_1_FLUX                 0.000000                      0.000000                      0.0
# NA_UNK_1_FWHM                 0.000000                      0.000000                      0.0
# NA_UNK_1_FWHM_CORR            0.000000                      0.000000                      0.0
# NA_UNK_1_LUM                  0.000000                      0.000000                      1.0
# NA_UNK_1_NPIX                 0.000000                      0.000000                      0.0
# NA_UNK_1_SNR                  0.000000                      0.000000                      0.0
# NA_UNK_1_VOFF                 -22.736575                    1.529831                      0.0
# NA_UNK_1_W80                  0.000000                      0.000000                      0.0
# NA_UNK_1_W80_CORR             0.000000                      0.000000                      0.0
# POWER_AMP                     53.972980                     0.077888                      0.0
# POWER_SLOPE                   -1.036534                     0.000000                      1.0
# RCHI_SQUARED                  2.387436                      0.009976                      0.0
# R_SQUARED                     0.998253                      0.000043                      0.0
# NOISE_STD                     1.499550
# RESID_STD                     2.936937
# --------------------------------------------------------------------------------------
#  - Done fitting 2-test!
#
# End process memory: 0.32885555
