# %% [markdown]
# ## Bayesian AGN Decomposition Analysis for SDSS Spectra (BADASS)
# ### Single Spectrum with Options File
# ####  Remington O. Sexton$^{1,2}$, Sara M. Doan$^{1}$, Michael A. Reefe$^{1}$, William Matzko$^{1}$
# $^{1}$George Mason University, $^{2}$United States Naval Observatory

# %%
import glob
import time
import natsort
from IPython.display import clear_output
# import multiprocess as mp
import os
import psutil
import pathlib
import natsort
# Import BADASS here
import badass as badass
import badass_utils as badass_utils

from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ### BADASS Options

# %%
# A .py file containing options
options_file = "BADASS_options.py"

# %% [markdown]
# ### Run BADASS on a single spectrum
#
# The following is shows how to fit single SDSS spectra.

# %% [markdown]
# #### Directory Structure

# %%
########################## Directory Structure #################################
spec_dir = 'examples/' # folder with spectra in it

# Get full list of spectrum folders; these will be the working directories
spec_loc = natsort.natsorted( glob.glob(spec_dir+'*') )
################################################################################
print(len(spec_loc))
# Out:
# 10

# %% [markdown]
# #### Choose Spectrum

# %%
nobj = 1 # Object in the spec_loc list
file = glob.glob(spec_loc[nobj]+'/*.fits')[0] # Get name of FITS spectra file
#
print(file)
# Out:
# examples/1-test/spec-7748-58396-0782.fits

# %% [markdown]
# #### Run IRSA Dust Query
# To correct for Galactic extinction.  This only needs to be done once so that the data is stored locally.

# %%
badass_utils.fetch_IRSA_dust(spec_loc[nobj])
# Out:
#  Fetching IRSA Dust for spectra...
#
#  Done fetching IRSA dust!

# %% [markdown]
# #### Run

# %%
# Call the main function in BADASS
badass.run_BADASS(pathlib.Path(file),
                  options_file = options_file,
                 )
    #
# Out:
# Start process memory: 0.50565530
#  Storing MCMC_output in examples/1-test/MCMC_output_3/
#
#  > Starting fit for 1-test
#
#
# -----------------------------------------------------------
#  file:                        spec-7748-58396-0782.fits
#  SDSS redshift:               0.58427
#  fitting region:              (4750,5100) [A]
#  velocity scale:              69.15 [km/s/pixel]
#  Galactic E(B-V):             0.041
# -----------------------------------------------------------
#
#  Initializing parameters for Maximum Likelihood Fitting.
# ----------------------------------------------------------------------------------------------------
# 	 - Adding parameter for unexplained noise to fit reduced Chi-squared.
# 	 - Fitting the stellar LOSVD.
# 	 - Fitting Simple AGN power-law continuum.
# 	 - Fitting broad and narrow optical FeII using Veron-Cetty et al. (2004) optical FeII templates
# 	 		* varying optical FeII amplitudes
# 	 		* varying optical FeII dispersion.
# 	 		* varying optical FeII voff
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Line List:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
# BR_H_BETA
#                               amp                           free
#                               center                        4862.691
#                               center_pix                    102.06668175881568
#                               disp                          free
#                               disp_init                     1000.0
#                               disp_plim                     (500, 5000)
#                               disp_res_ang                  0.9552230400999352
#                               disp_res_kms                  58.890985080029175
#                               h3                            free
#                               h3_prior                      {'type': 'gaussian', 'loc': 0.0, 'scale': 0.01}
#                               h4                            free
#                               h4_prior                      {'type': 'gaussian', 'loc': 0.0, 'scale': 0.01}
#                               line_profile                  gauss-hermite
#                               line_type                     br
#                               voff                          free
# NA_H_BETA
#                               amp                           free
#                               center                        4862.691
#                               center_pix                    102.06668175881568
#                               disp                          NA_OIII_5007_DISP
#                               disp_res_ang                  0.9552230400999352
#                               disp_res_kms                  58.890985080029175
#                               label                         H$\beta$
#                               line_profile                  gaussian
#                               line_type                     na
#                               voff                          NA_OIII_5007_VOFF
# NA_OIII_4960
#                               amp                           (NA_OIII_5007_AMP/2.98)
#                               center                        4960.295
#                               center_pix                    188.37453458582414
#                               disp                          NA_OIII_5007_DISP
#                               disp_res_ang                  0.9560830818568381
#                               disp_res_kms                  57.78416347456687
#                               label                         [O III]
#                               line_profile                  gaussian
#                               line_type                     na
#                               voff                          NA_OIII_5007_VOFF
# NA_OIII_5007
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    230.1511712473571
#                               disp                          free
#                               disp_res_ang                  0.9558470574040805
#                               disp_res_kms                  57.21685438621879
#                               label                         [O III]
#                               line_profile                  gaussian
#                               line_type                     na
#                               voff                          free
# OUT_H_BETA
#                               amp                           OUT_OIII_5007_AMP/NA_OIII_5007_AMP*NA_H_BETA_AMP
#                               center                        4862.691
#                               center_pix                    102.06668175881568
#                               disp                          OUT_OIII_5007_DISP
#                               disp_res_ang                  0.9552230400999352
#                               disp_res_kms                  58.890985080029175
#                               line_profile                  gaussian
#                               line_type                     out
#                               voff                          OUT_OIII_5007_VOFF
# OUT_OIII_4960
#                               amp                           OUT_OIII_5007_AMP/2.98
#                               center                        4960.295
#                               center_pix                    188.37453458582414
#                               disp                          OUT_OIII_5007_DISP
#                               disp_res_ang                  0.9560830818568381
#                               disp_res_kms                  57.78416347456687
#                               line_profile                  gaussian
#                               line_type                     out
#                               voff                          OUT_OIII_5007_VOFF
# OUT_OIII_5007
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    230.1511712473571
#                               disp                          free
#                               disp_res_ang                  0.9558470574040805
#                               disp_res_kms                  57.21685438621879
#                               line_profile                  gaussian
#                               line_type                     out
#                               voff                          free
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Number of Free Line Parameters: 12
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  All Free Parameters:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
# BR_H_BETA_AMP
#                               init                          11.262788855388406
#                               plim                          (0.0, 22.525577710776812)
# BR_H_BETA_DISP
#                               init                          1000.0
#                               plim                          (500, 5000)
# BR_H_BETA_H3
#                               init                          0.0
#                               plim                          (-0.5, 0.5)
#                               prior                         {'type': 'gaussian', 'loc': 0.0, 'scale': 0.01}
# BR_H_BETA_H4
#                               init                          0.0
#                               plim                          (-0.5, 0.5)
#                               prior                         {'type': 'gaussian', 'loc': 0.0, 'scale': 0.01}
# BR_H_BETA_VOFF
#                               init                          0.001
#                               plim                          (-500, 500)
#                               prior                         {'type': 'gaussian'}
# BR_OPT_FEII_AMP
#                               init                          0.7892417185644329
#                               plim                          (0, 22.525577710776812)
# BR_OPT_FEII_DISP
#                               init                          500.0
#                               plim                          (100.0, 5000.0)
# BR_OPT_FEII_VOFF
#                               init                          0.0
#                               plim                          (-2000.0, 2000.0)
# NA_H_BETA_AMP
#                               init                          22.525577710776812
#                               plim                          (0.0, 22.525577710776812)
# NA_OIII_5007_AMP
#                               init                          11.827593145121329
#                               plim                          (0.0, 22.525577710776812)
# NA_OIII_5007_DISP
#                               init                          50.0
#                               plim                          (0.1, 500.0)
# NA_OIII_5007_VOFF
#                               init                          0.001
#                               plim                          (-500, 500)
#                               prior                         {'type': 'gaussian'}
# NA_OPT_FEII_AMP
#                               init                          0.7892417185644329
#                               plim                          (0, 22.525577710776812)
# NA_OPT_FEII_DISP
#                               init                          10.0
#                               plim                          (0.1, 250.0)
# NA_OPT_FEII_VOFF
#                               init                          0.0
#                               plim                          (-1000.0, 1000.0)
# NOISE_SCALE
#                               init                          1.0
#                               plim                          (0.0001, 100.0)
#                               prior                         {'type': 'jeffreys'}
# OUT_OIII_5007_AMP
#                               init                          5.913796572560664
#                               plim                          (0.0, 22.525577710776812)
# OUT_OIII_5007_DISP
#                               init                          100.0
#                               plim                          (0.1, 1000.0)
# OUT_OIII_5007_VOFF
#                               init                          0.001
#                               plim                          (-500, 500)
#                               prior                         {'type': 'gaussian'}
# POWER_AMP
#                               init                          3.9462085928221646
#                               plim                          (0, 22.525577710776812)
# POWER_SLOPE
#                               init                          -1.0
#                               plim                          (-6.0, 6.0)
# STEL_DISP
#                               init                          150.0
#                               plim                          (0.001, 500.0)
# STEL_VEL
#                               init                          100.0
#                               plim                          (-500.0, 500.0)
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Total number of free parameters: 23
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Soft Constraints:
#
#               NA_OIII_5007_AMP > NA_H_BETA_AMP
#             OUT_OIII_5007_DISP > NA_OIII_5007_DISP
#               NA_OIII_5007_AMP > OUT_OIII_5007_AMP
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 10
# warning: basinhopping: local minimization failure
# basinhopping step 0: f -192.398
# basinhopping step 1: f -343.041 trial_f -343.041 accepted 1  lowest_f -343.041
# found new global minimum on step 1 with function value -343.041
# basinhopping step 2: f -343.041 trial_f -311.273 accepted 0  lowest_f -343.041
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -354.745 trial_f -354.745 accepted 1  lowest_f -354.745
# found new global minimum on step 3 with function value -354.745
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -354.745 trial_f -333.72 accepted 0  lowest_f -354.745
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -354.745 trial_f 1385.44 accepted 0  lowest_f -354.745
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -354.745 trial_f -45.1419 accepted 0  lowest_f -354.745
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -354.745 trial_f -41.4334 accepted 0  lowest_f -354.745
# basinhopping step 8: f -354.745 trial_f -45.4415 accepted 0  lowest_f -354.745
# basinhopping step 9: f -354.745 trial_f -331.062 accepted 0  lowest_f -354.745
# basinhopping step 10: f -354.745 trial_f -208.445 accepted 0  lowest_f -354.745
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -354.745 trial_f 187.781 accepted 0  lowest_f -354.745
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -362.529 trial_f -362.529 accepted 1  lowest_f -362.529
# found new global minimum on step 12 with function value -362.529
# basinhopping step 13: f -365.255 trial_f -365.255 accepted 1  lowest_f -365.255
# found new global minimum on step 13 with function value -365.255
# basinhopping step 14: f -365.042 trial_f -365.042 accepted 1  lowest_f -365.255
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -373.855 trial_f -373.855 accepted 1  lowest_f -373.855
# found new global minimum on step 15 with function value -373.855
# basinhopping step 16: f -373.855 trial_f -329.164 accepted 0  lowest_f -373.855
# basinhopping step 17: f -373.855 trial_f -356.877 accepted 0  lowest_f -373.855
# basinhopping step 18: f -376.333 trial_f -376.333 accepted 1  lowest_f -376.333
# found new global minimum on step 18 with function value -376.333
# basinhopping step 19: f -377.054 trial_f -377.054 accepted 1  lowest_f -377.054
# found new global minimum on step 19 with function value -377.054
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -377.054 trial_f -258.091 accepted 0  lowest_f -377.054
# basinhopping step 21: f -377.801 trial_f -377.801 accepted 1  lowest_f -377.801
# found new global minimum on step 21 with function value -377.801
# basinhopping step 22: f -377.801 trial_f -267.054 accepted 0  lowest_f -377.801
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -377.801 trial_f 86.1024 accepted 0  lowest_f -377.801
# basinhopping step 24: f -377.801 trial_f -321.663 accepted 0  lowest_f -377.801
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -377.801 trial_f -31.9408 accepted 0  lowest_f -377.801
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -377.801 trial_f -318.757 accepted 0  lowest_f -377.801
# basinhopping step 27: f -377.801 trial_f -314.785 accepted 0  lowest_f -377.801
# basinhopping step 28: f -377.832 trial_f -377.832 accepted 1  lowest_f -377.832
# found new global minimum on step 28 with function value -377.832
# warning: basinhopping: local minimization failure
# basinhopping step 29: f -377.832 trial_f -258.135 accepted 0  lowest_f -377.832
# warning: basinhopping: local minimization failure
# basinhopping step 30: f -377.832 trial_f 98.2751 accepted 0  lowest_f -377.832
# basinhopping step 31: f -377.832 trial_f 125.824 accepted 0  lowest_f -377.832
# basinhopping step 32: f -377.832 trial_f -373.324 accepted 0  lowest_f -377.832
# basinhopping step 33: f -377.832 trial_f -359.195 accepted 0  lowest_f -377.832
# basinhopping step 34: f -377.832 trial_f -343.574 accepted 0  lowest_f -377.832
# basinhopping step 35: f -377.832 trial_f -375.42 accepted 0  lowest_f -377.832
# basinhopping step 36: f -377.832 trial_f -262.477 accepted 0  lowest_f -377.832
# basinhopping step 37: f -377.832 trial_f -341.119 accepted 0  lowest_f -377.832
# basinhopping step 38: f -377.832 trial_f -357.256 accepted 0  lowest_f -377.832
# basinhopping step 39: f -377.832 trial_f -370.816 accepted 0  lowest_f -377.832
#
#  Performing Monte Carlo bootstrapping...
# 	   Completed 1 of 10 iterations.
# 	   Completed 2 of 10 iterations.
# 	   Completed 3 of 10 iterations.
# 	   Completed 4 of 10 iterations.
# 	   Completed 5 of 10 iterations.
# 	   Completed 6 of 10 iterations.
# 	   Completed 7 of 10 iterations.
# 	   Completed 8 of 10 iterations.
# 	   Completed 9 of 10 iterations.
# 	   Completed 10 of 10 iterations.
#
#  Maximum Likelihood Best-fit Parameters:
# --------------------------------------------------------------------------------------
#
# Parameter                     Best-fit Value                +/- 1-sigma                   Flag
# --------------------------------------------------------------------------------------
# BR_H_BETA_AMP                 14.302047                     0.110628                      0
# BR_H_BETA_DISP                581.533226                    4.529768                      0
# BR_H_BETA_EW                  51.404154                     0.502313                      0
# BR_H_BETA_FLUX                -14.469482                    0.002839                      1
# BR_H_BETA_FWHM                1275.915582                   10.888119                     0
# BR_H_BETA_H3                  -0.023365                     0.002092                      0
# BR_H_BETA_H4                  0.051383                      0.001707                      0
# BR_H_BETA_LUM                 42.676138                     0.002839                      0
# BR_H_BETA_NPIX                50.000000                     0.000000                      0
# BR_H_BETA_VOFF                107.245017                    0.985346                      0
# BR_OPT_FEII_AMP               22.148511                     0.168125                      0
# BR_OPT_FEII_DISP              243.991632                    27.324950                     0
# BR_OPT_FEII_TEMPLATE_EW       6.843262                      0.047036                      0
# BR_OPT_FEII_TEMPLATE_FLUX     -15.308878                    0.003320                      1
# BR_OPT_FEII_TEMPLATE_LUM      41.836742                     0.003320                      0
# BR_OPT_FEII_VOFF              429.565939                    16.987015                     0
# LOG_LIKE                      -291.964488                   29.602979                     0
# NA_H_BETA_AMP                 0.000000                      0.000000                      1
# NA_H_BETA_DISP                205.883613                    14.835167                     0
# NA_H_BETA_EW                  0.000000                      0.000000                      1
# NA_H_BETA_FLUX                0.000000                      0.000000                      1
# NA_H_BETA_FWHM                0.000000                      0.000000                      0
# NA_H_BETA_LUM                 0.000000                      0.000000                      1
# NA_H_BETA_NPIX                0.000000                      0.000000                      0
# NA_H_BETA_VOFF                22.849313                     11.467763                     0
# NA_OIII_4960_AMP              0.837675                      0.175978                      0
# NA_OIII_4960_DISP             205.883613                    14.835167                     0
# NA_OIII_4960_EW               1.072928                      0.065906                      0
# NA_OIII_4960_FLUX             -16.129752                    0.025480                      1
# NA_OIII_4960_FWHM             487.648494                    34.627036                     0
# NA_OIII_4960_LUM              41.015869                     0.025480                      0
# NA_OIII_4960_NPIX             5.000000                      0.000000                      0
# NA_OIII_4960_VOFF             22.849313                     11.467763                     0
# NA_OIII_5007_AMP              2.496271                      0.175978                      0
# NA_OIII_5007_DISP             205.883613                    14.835167                     0
# NA_OIII_5007_EW               3.304827                      0.206518                      0
# NA_OIII_5007_FLUX             -15.651668                    0.025491                      1
# NA_OIII_5007_FWHM             490.899744                    33.798316                     0
# NA_OIII_5007_LUM              41.493953                     0.025491                      0
# NA_OIII_5007_NPIX             11.000000                     0.000000                      0
# NA_OIII_5007_VOFF             22.849313                     11.467763                     0
# NA_OPT_FEII_AMP               0.355140                      0.183363                      0
# NA_OPT_FEII_DISP              89.003167                     26.290129                     0
# NA_OPT_FEII_TEMPLATE_EW       0.254700                      0.133375                      0
# NA_OPT_FEII_TEMPLATE_FLUX     -16.730061                    4.245110                      1
# NA_OPT_FEII_TEMPLATE_LUM      40.415560                     4.245110                      0
# NA_OPT_FEII_VOFF              1.377979                      29.629038                     0
# NOISE_SCALE                   1.300516                      0.001911                      0
# OUT_H_BETA_AMP                0.000000                      0.246465                      1
# OUT_H_BETA_DISP               606.127880                    19.935018                     0
# OUT_H_BETA_EW                 0.000000                      0.000000                      1
# OUT_H_BETA_FLUX               0.000000                      0.000000                      1
# OUT_H_BETA_FWHM               0.000000                      0.000000                      0
# OUT_H_BETA_LUM                0.000000                      0.000000                      1
# OUT_H_BETA_NPIX               0.000000                      0.000000                      0
# OUT_H_BETA_VOFF               -35.599138                    8.436678                      0
# OUT_OIII_4960_AMP             0.837659                      0.172559                      0
# OUT_OIII_4960_DISP            606.127880                    19.935018                     0
# OUT_OIII_4960_EW              3.000679                      0.154524                      0
# OUT_OIII_4960_FLUX            -15.675401                    0.023848                      1
# OUT_OIII_4960_FWHM            1428.029247                   46.957435                     0
# OUT_OIII_4960_LUM             41.470220                     0.023848                      0
# OUT_OIII_4960_NPIX            17.000000                     0.000000                      0
# OUT_OIII_4960_VOFF            -35.599138                    8.436678                      0
# OUT_OIII_5007_AMP             2.496224                      0.172559                      0
# OUT_OIII_5007_DISP            606.127880                    19.935018                     0
# OUT_OIII_5007_EW              9.346071                      0.480551                      0
# OUT_OIII_5007_FLUX            -15.197050                    0.023846                      1
# OUT_OIII_5007_FWHM            1428.449959                   46.877339                     0
# OUT_OIII_5007_LUM             41.948571                     0.023846                      0
# OUT_OIII_5007_NPIX            33.000000                     0.000000                      0
# OUT_OIII_5007_VOFF            -35.599138                    8.436678                      0
# POWER_AMP                     1.185090                      0.000000                      0
# POWER_SLOPE                   -3.009425                     0.000000                      1
# RCHI_SQUARED                  1.191585                      0.000000                      0
# R_SQUARED                     0.996555                      0.000000                      0
# STEL_DISP                     140.367167                    24.683414                     0
# STEL_VEL                      -283.776627                   34.110389                     0
# NOISE_STD                     0.360598
# RESID_STD                     0.532103
# --------------------------------------------------------------------------------------
#  - Done fitting 1-test!
# End process memory: 0.46817690

# %% [markdown]
# ######
