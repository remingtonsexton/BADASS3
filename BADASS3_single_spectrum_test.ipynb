# %% [markdown]
# ## Bayesian AGN Decomposition Analysis for SDSS Spectra (BADASS)
# ### Single Spectrum
#
# ####  Remington O. Sexton$^{1,2}$, Sara M. Doan$^{1}$, Michael A. Reefe$^{1}$, William Matzko$^{1}$
# $^{1}$George Mason University, $^{2}$United States Naval Observatory

# %%
import glob
import time
import natsort
from IPython.display import clear_output
# import multiprocess as mp
import os
import psutil
import pathlib
import natsort
# Import BADASS here
import badass as badass
import badass_utils as badass_utils
import badass_ncomp_options

from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ### BADASS Options

# %%
options_file = "badass_ncomp_options.py"
if os.path.exists(options_file):
    print("\n Options file %s found.\n" % (options_file))
# Out:
#  Options file badass_ncomp_options.py found.

# %% [markdown]
# ### Run BADASS on a single spectrum
#
# The following is shows how to fit single SDSS spectra.

# %% [markdown]
# #### Directory Structure

# %%
nobj = 2 # Object in the spec_dir list
########################## Directory Structure #################################
spec_dir = 'examples/' # folder with spectra in it
# Get full list of spectrum folders; these will be the working directories
spec_loc = natsort.natsorted( glob.glob(spec_dir+'*') )[nobj]

################################################################################
print(len(spec_loc))
print(spec_loc)
# Out:
# 15
# examples/2-test

# %% [markdown]
# #### Choose Spectrum

# %%
file = glob.glob(spec_loc+'/*.fits')[0] # Get name of FITS spectra file
print(file)
# Out:
# examples/2-test/spec-2756-54508-0579.fits

# %% [markdown]
# #### Run IRSA Dust Query
# To correct for Galactic extinction.  This only needs to be done once so that the data is stored locally.

# %%
# badass_utils.fetch_IRSA_dust(spec_loc)

# %% [markdown]
# #### Run

# %%
import importlib
import numpy as np
importlib.reload(badass)
importlib.reload(badass_utils)
importlib.reload(badass_ncomp_options)


for i in range(1):
    np.random.seed()
    print("\n---------------------------------------------------------")
    print(" Begin Test %d of %d" % (i+1,10))
    print("---------------------------------------------------------")
    
    # Call the main function in BADASS
    badass.run_BADASS(pathlib.Path(file),
                      options_file = options_file,
                     )
        #
# Out:
# ---------------------------------------------------------
#  Begin Test 1 of 10
# ---------------------------------------------------------
# Start process memory: 0.52195328
#  Storing MCMC_output in examples/2-test/MCMC_output_2/
#
#  > Starting fit for 2-test
#
#  Input fitting region exceeds available wavelength range.  BADASS will adjust your fitting range automatically...
# 		- Input fitting range: (4400, 5500)
# 		- Available wavelength range: (2218, 5354)
# 		- New fitting region is (4400, 5355).
#
#
#
# -----------------------------------------------------------
#  file:                        spec-2756-54508-0579.fits
#  SDSS redshift:               0.71967
#  fitting region:              (4400,5355) [A]
#  velocity scale:              69.15 [km/s/pixel]
#  Galactic E(B-V):             0.032
#  Flux Normalization:          1.0e-17
# -----------------------------------------------------------
#
#  Initializing parameters...
# ----------------------------------------------------------------------------------------------------
# 	- Adding parameter for unexplained variance for reduced Chi-squared.
# 	- Fitting a SSP host-galaxy template.
# 	- Fitting additive legendre polynomial component.
# 	- Fitting Simple AGN power-law continuum.
# 	- Fitting broad and narrow optical FeII using Veron-Cetty et al. (2004) optical FeII templates
# 	 		* varying optical FeII amplitudes
# 	 		* varying optical FeII dispersion.
# 	 		* varying optical FeII voff
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Line List:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
# BR_H_BETA
#                               amp                           free
#                               center                        4862.691
#                               center_pix                    435.21099039301293
#                               disp                          free
#                               disp_res_ang                  0.7266926172967304
#                               disp_res_kms                  44.80172932021387
#                               line_profile                  gaussian
#                               line_type                     br
#                               ncomp                         1
#                               voff                          free
# NA_H_BETA
#                               amp                           free
#                               center                        4862.691
#                               center_pix                    435.21099039301293
#                               disp                          NA_OIII_5007_DISP
#                               disp_res_ang                  0.7266926172967304
#                               disp_res_kms                  44.80172932021387
#                               label                         H$\beta$
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          free
# NA_H_BETA_2
#                               amp                           NA_H_BETA_AMP*NA_OIII_5007_2_AMP/NA_OIII_5007_AMP
#                               center                        4862.691
#                               center_pix                    435.21099039301293
#                               disp                          NA_OIII_5007_2_DISP
#                               disp_res_ang                  0.7266926172967304
#                               disp_res_kms                  44.80172932021387
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         2
#                               parent                        NA_H_BETA
#                               voff                          NA_OIII_5007_2_VOFF
# NA_H_BETA_3
#                               amp                           NA_H_BETA_AMP*NA_OIII_5007_3_AMP/NA_OIII_5007_AMP
#                               center                        4862.691
#                               center_pix                    435.21099039301293
#                               disp                          NA_OIII_5007_3_DISP
#                               disp_res_ang                  0.7266926172967304
#                               disp_res_kms                  44.80172932021387
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         3
#                               parent                        NA_H_BETA
#                               voff                          NA_OIII_5007_3_VOFF
# NA_OIII_4960
#                               amp                           (NA_OIII_5007_AMP/2.98)
#                               center                        4960.295
#                               center_pix                    521.5197602739727
#                               disp                          NA_OIII_5007_DISP
#                               disp_res_ang                  0.7349264587941482
#                               disp_res_kms                  44.41780368529158
#                               label                         [O III]
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          NA_OIII_5007_VOFF
# NA_OIII_4960_2
#                               amp                           (NA_OIII_5007_2_AMP/2.98)
#                               center                        4960.295
#                               center_pix                    521.5197602739727
#                               disp                          NA_OIII_5007_2_DISP
#                               disp_res_ang                  0.7349264587941482
#                               disp_res_kms                  44.41780368529158
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         2
#                               parent                        NA_OIII_4960
#                               voff                          NA_OIII_5007_2_VOFF
# NA_OIII_4960_3
#                               amp                           (NA_OIII_5007_3_AMP/2.98)
#                               center                        4960.295
#                               center_pix                    521.5197602739727
#                               disp                          NA_OIII_5007_3_DISP
#                               disp_res_ang                  0.7349264587941482
#                               disp_res_kms                  44.41780368529158
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         3
#                               parent                        NA_OIII_4960
#                               voff                          NA_OIII_5007_3_VOFF
# NA_OIII_5007
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    563.2959830508472
#                               disp                          free
#                               disp_res_ang                  0.7407543175269816
#                               disp_res_kms                  44.341436837197556
#                               label                         [O III]
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          free
# NA_OIII_5007_2
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    563.2959830508472
#                               disp                          free
#                               disp_res_ang                  0.7407543175269816
#                               disp_res_kms                  44.341436837197556
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         2
#                               parent                        NA_OIII_5007
#                               voff                          free
# NA_OIII_5007_3
#                               amp                           free
#                               center                        5008.24
#                               center_pix                    563.2959830508472
#                               disp                          free
#                               disp_res_ang                  0.7407543175269816
#                               disp_res_kms                  44.341436837197556
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         3
#                               parent                        NA_OIII_5007
#                               voff                          free
# NA_UNK_1
#                               amp                           free
#                               center                        5200
#                               center_pix                    726.478971008575
#                               disp                          free
#                               disp_res_ang                  0.7773961211552205
#                               disp_res_kms                  44.81874884630564
#                               line_profile                  gaussian
#                               line_type                     na
#                               ncomp                         1
#                               voff                          free
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Number of Free Line Parameters: 17
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  All Free Parameters:
#
# ----------------------------------------------------------------------------------------------------------------------------------------
# APOLY_COEFF_1
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_2
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_3
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# BR_H_BETA_AMP
#                               init                          123.71961977961685
#                               plim                          (0.0, 812.7198363113289)
# BR_H_BETA_DISP
#                               init                          500.0
#                               plim                          (300.0, 3000.0)
# BR_H_BETA_VOFF
#                               init                          -14.54495027591921
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# BR_OPT_FEII_AMP
#                               init                          5.826352429250029
#                               plim                          (0, 609.5398772334967)
# BR_OPT_FEII_DISP
#                               init                          500.0
#                               plim                          (500.0, 5000.0)
# BR_OPT_FEII_VOFF
#                               init                          0.0
#                               plim                          (-500.0, 500.0)
# HOST_TEMP_DISP
#                               init                          100.0
#                               plim                          (0.001, 500.0)
# HOST_TEMP_VEL
#                               init                          0.0
#                               plim                          (-500.0, 500)
# NA_H_BETA_AMP
#                               init                          41.23987325987228
#                               plim                          (0.0, 812.7198363113289)
# NA_H_BETA_VOFF
#                               init                          -14.54495027591921
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_2_AMP
#                               init                          135.45330605188815
#                               plim                          (0.0, 812.7198363113289)
# NA_OIII_5007_2_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_OIII_5007_2_VOFF
#                               init                          -20.4166490422637
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_3_AMP
#                               init                          135.45330605188815
#                               plim                          (0.0, 812.7198363113289)
# NA_OIII_5007_3_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_OIII_5007_3_VOFF
#                               init                          -20.4166490422637
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_AMP
#                               init                          135.45330605188815
#                               plim                          (0.0, 812.7198363113289)
# NA_OIII_5007_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_OIII_5007_VOFF
#                               init                          -20.4166490422637
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OPT_FEII_AMP
#                               init                          5.826352429250029
#                               plim                          (0, 609.5398772334967)
# NA_OPT_FEII_DISP
#                               init                          10.0
#                               plim                          (0.1, 500.0)
# NA_OPT_FEII_VOFF
#                               init                          0.0
#                               plim                          (-500.0, 500.0)
# NA_UNK_1_AMP
#                               init                          43.36974189851907
#                               plim                          (0.0, 812.7198363113289)
# NA_UNK_1_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_UNK_1_VOFF
#                               init                          174.0550600786884
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NOISE_SCALE
#                               init                          1.0
#                               plim                          (0.0001, 100.0)
#                               prior                         {'type': 'jeffreys'}
# POWER_AMP
#                               init                          29.131762146250143
#                               plim                          (0, 609.5398772334967)
# POWER_SLOPE
#                               init                          -1.0
#                               plim                          (-6.0, 6.0)
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Total number of free parameters: 31
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Soft Constraints:
#
#            NA_OIII_5007_2_DISP > NA_OIII_5007_DISP
#            NA_OIII_5007_3_DISP > NA_OIII_5007_2_DISP
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Performing max. likelihood fitting.
#
#  Using Basin-hopping algorithm to estimate parameters. niter_success = 10
# basinhopping step 0: f 24660.1
# warning: basinhopping: local minimization failure
# basinhopping step 1: f 24660.1 trial_f inf accepted 0  lowest_f 24660.1
# warning: basinhopping: local minimization failure
# basinhopping step 2: f 24660.1 trial_f inf accepted 0  lowest_f 24660.1
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -1055.44 trial_f -1055.44 accepted 1  lowest_f -1055.44
# found new global minimum on step 3 with function value -1055.44
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -1447.93 trial_f -1447.93 accepted 1  lowest_f -1447.93
# found new global minimum on step 4 with function value -1447.93
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -1468.16 trial_f -1468.16 accepted 1  lowest_f -1468.16
# found new global minimum on step 5 with function value -1468.16
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -1478.94 trial_f -1478.94 accepted 1  lowest_f -1478.94
# found new global minimum on step 6 with function value -1478.94
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -1479.91 trial_f -1479.91 accepted 1  lowest_f -1479.91
# found new global minimum on step 7 with function value -1479.91
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -1480.13 trial_f -1480.13 accepted 1  lowest_f -1480.13
# found new global minimum on step 8 with function value -1480.13
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -1480.13 trial_f -1479.41 accepted 0  lowest_f -1480.13
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -1480.13 trial_f -1474.89 accepted 0  lowest_f -1480.13
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -1479.77 trial_f -1479.77 accepted 1  lowest_f -1480.13
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -1480.82 trial_f -1480.82 accepted 1  lowest_f -1480.82
# found new global minimum on step 12 with function value -1480.82
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -1480.82 trial_f -1479.08 accepted 0  lowest_f -1480.82
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -1480.98 trial_f -1480.98 accepted 1  lowest_f -1480.98
# found new global minimum on step 14 with function value -1480.98
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -1480.47 trial_f -1480.47 accepted 1  lowest_f -1480.98
# basinhopping step 16: f -1481.43 trial_f -1481.43 accepted 1  lowest_f -1481.43
# found new global minimum on step 16 with function value -1481.43
# basinhopping step 17: f -1481.14 trial_f -1481.14 accepted 1  lowest_f -1481.43
# basinhopping step 18: f -1481.29 trial_f -1481.29 accepted 1  lowest_f -1481.43
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -1481.22 trial_f -1481.22 accepted 1  lowest_f -1481.43
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -1481.12 trial_f -1481.12 accepted 1  lowest_f -1481.43
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -1481.06 trial_f -1481.06 accepted 1  lowest_f -1481.43
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -1481.1 trial_f -1481.1 accepted 1  lowest_f -1481.43
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -1481.1 trial_f -1480.87 accepted 0  lowest_f -1481.43
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -1480.03 trial_f -1480.03 accepted 1  lowest_f -1481.43
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -1480.03 trial_f -1479.66 accepted 0  lowest_f -1481.43
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -1480.27 trial_f -1480.27 accepted 1  lowest_f -1481.43
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -1481.38 trial_f -1481.38 accepted 1  lowest_f -1481.43
#
#  Performing Monte Carlo bootstrapping...
# 	   Completed 1 of 10 iterations.
# 	   Completed 2 of 10 iterations.
# 	   Completed 3 of 10 iterations.
# 	   Completed 4 of 10 iterations.
# 	   Completed 5 of 10 iterations.
# 	   Completed 6 of 10 iterations.
# 	   Completed 7 of 10 iterations.
# 	   Completed 8 of 10 iterations.
# 	   Completed 9 of 10 iterations.
# 	   Completed 10 of 10 iterations.
#
#  Maximum Likelihood Best-fit Parameters:
# --------------------------------------------------------------------------------------
#
# Parameter                     Best-fit Value                +/- 1-sigma                   Flag
# --------------------------------------------------------------------------------------
# APOLY_COEFF_1                 0.087702                      0.006897                      0
# APOLY_COEFF_2                 -2.472083                     0.165539                      0
# APOLY_COEFF_3                 -0.663508                     0.107403                      0
# BR_H_BETA_AMP                 39.529003                     0.515483                      0
# BR_H_BETA_DISP                2266.057632                   16.982512                     0
# BR_H_BETA_EW                  65.754490                     0.933396                      0
# BR_H_BETA_FLUX                -13.441592                    0.005202                      0
# BR_H_BETA_FWHM                5336.505643                   39.994159                     0
# BR_H_BETA_LUM                 43.924627                     0.005202                      0
# BR_H_BETA_NPIX                156.000000                    1.285649                      0
# BR_H_BETA_SNR                 15.928170                     0.207599                      0
# BR_H_BETA_VOFF                261.607692                    19.280056                     0
# BR_H_BETA_W80                 5937.584783                   44.412809                     0
# BR_OPT_FEII_AMP               0.000674                      0.000033                      0
# BR_OPT_FEII_DISP              826.766594                    84.593976                     0
# BR_OPT_FEII_TEMPLATE_EW       0.000229                      0.000012                      0
# BR_OPT_FEII_TEMPLATE_FLUX     -18.914874                    0.021030                      1
# BR_OPT_FEII_TEMPLATE_LUM      38.451345                     0.021030                      0
# BR_OPT_FEII_VOFF              3.473016                      0.279676                      0
# HOST_TEMP_DISP                98.745508                     9.228591                      0
# HOST_TEMP_VEL                 -0.282155                     0.018726                      0
# H_BETA_COMP_DISP              2175.633052                   16.104422                     0
# H_BETA_COMP_EW                71.414190                     0.857294                      0
# H_BETA_COMP_FLUX              -13.406023                    0.004185                      0
# H_BETA_COMP_FWHM              1800.843105                   200.250170                    0
# H_BETA_COMP_LUM               43.960196                     0.004185                      0
# H_BETA_COMP_NPIX              156.000000                    1.285649                      0
# H_BETA_COMP_SNR               27.077443                     0.445278                      0
# H_BETA_COMP_VOFF              239.797442                    18.462744                     0
# H_BETA_COMP_W80               5723.233850                   42.456240                     0
# LOG_LIKE                      -1318.341515                  48.002611                     0
# L_CONT_AGN_5100               45.774268                     0.002485                      0
# L_CONT_HOST_5100              43.914481                     0.058373                      0
# L_CONT_TOT_5100               45.774552                     0.001487                      0
# NA_H_BETA_2_AMP               17.556113                     6.319374                      0
# NA_H_BETA_2_DISP              286.100851                    1.902143                      0
# NA_H_BETA_2_EW                3.780686                      0.187882                      0
# NA_H_BETA_2_FLUX              -14.681025                    0.022205                      0
# NA_H_BETA_2_FWHM              675.830363                    4.495009                      0
# NA_H_BETA_2_LUM               42.685194                     0.022205                      0
# NA_H_BETA_2_NPIX              14.000000                     0.000000                      0
# NA_H_BETA_2_SNR               7.095050                      0.347868                      0
# NA_H_BETA_2_VOFF              -32.885669                    2.033556                      0
# NA_H_BETA_2_W80               750.083028                    5.053605                      0
# NA_H_BETA_3_AMP               0.971543                      4.373153                      0
# NA_H_BETA_3_DISP              1000.000000                   0.000000                      2
# NA_H_BETA_3_EW                0.711292                      0.045527                      0
# NA_H_BETA_3_FLUX              -15.407358                    0.024886                      0
# NA_H_BETA_3_FWHM              2355.289034                   0.295671                      0
# NA_H_BETA_3_LUM               41.958861                     0.024886                      0
# NA_H_BETA_3_NPIX              0.000000                      0.000000                      0
# NA_H_BETA_3_SNR               0.388000                      0.023835                      0
# NA_H_BETA_3_VOFF              108.308295                    7.206084                      0
# NA_H_BETA_3_W80               2619.771200                   0.163225                      0
# NA_H_BETA_AMP                 17.076863                     0.805210                      0
# NA_H_BETA_COMB_DISP           411.839411                    7.055597                      0
# NA_H_BETA_COMB_EW             6.316019                      0.247339                      0
# NA_H_BETA_COMB_FLUX           -14.458211                    0.017042                      0
# NA_H_BETA_COMB_FWHM           481.592664                    3.224197                      0
# NA_H_BETA_COMB_LUM            42.908008                     0.017042                      0
# NA_H_BETA_COMB_NPIX           16.000000                     0.497930                      0
# NA_H_BETA_COMB_SNR            10.401637                     0.298100                      0
# NA_H_BETA_COMB_VOFF           -6.924274                     1.986516                      0
# NA_H_BETA_COMB_W80            765.548725                    7.818226                      0
# NA_H_BETA_DISP                141.612851                    2.923850                      0
# NA_H_BETA_EW                  1.867664                      0.097052                      0
# NA_H_BETA_FLUX                -14.987390                    0.022902                      0
# NA_H_BETA_FWHM                337.057987                    6.677522                      0
# NA_H_BETA_LUM                 42.378829                     0.022902                      0
# NA_H_BETA_NPIX                8.000000                      0.287480                      0
# NA_H_BETA_SNR                 6.842509                      0.322771                      0
# NA_H_BETA_VOFF                1.167402                      0.054073                      0
# NA_H_BETA_W80                 373.025550                    7.887249                      0
# NA_OIII_4960_2_AMP            58.332820                     4.602447                      0
# NA_OIII_4960_2_DISP           286.100851                    1.902143                      0
# NA_OIII_4960_2_EW             13.109036                     0.321764                      0
# NA_OIII_4960_2_FLUX           -14.155855                    0.010236                      0
# NA_OIII_4960_2_FWHM           673.959586                    4.386238                      0
# NA_OIII_4960_2_LUM            43.210364                     0.010236                      0
# NA_OIII_4960_2_NPIX           20.000000                     0.000000                      0
# NA_OIII_4960_2_SNR            23.504105                     0.622174                      0
# NA_OIII_4960_2_VOFF           -32.885669                    2.033556                      0
# NA_OIII_4960_2_W80            750.351951                    5.089835                      0
# NA_OIII_4960_3_AMP            3.228096                      0.610323                      0
# NA_OIII_4960_3_DISP           1000.000000                   0.000000                      2
# NA_OIII_4960_3_EW             2.513102                      0.166146                      0
# NA_OIII_4960_3_FLUX           -14.873434                    0.026773                      0
# NA_OIII_4960_3_FWHM           2355.002720                   0.121988                      0
# NA_OIII_4960_3_LUM            42.492785                     0.026773                      0
# NA_OIII_4960_3_NPIX           16.000000                     3.816017                      0
# NA_OIII_4960_3_SNR            1.300733                      0.082524                      0
# NA_OIII_4960_3_VOFF           108.308295                    7.206084                      0
# NA_OIII_4960_3_W80            2618.840790                   0.264593                      0
# NA_OIII_4960_AMP              56.740441                     4.254834                      0
# NA_OIII_4960_COMB_DISP        411.904384                    7.090203                      0
# NA_OIII_4960_COMB_EW          22.185363                     0.202130                      0
# NA_OIII_4960_COMB_FLUX        -13.927413                    0.002703                      0
# NA_OIII_4960_COMB_FWHM        479.720756                    3.279279                      0
# NA_OIII_4960_COMB_LUM         43.438806                     0.002703                      0
# NA_OIII_4960_COMB_NPIX        30.000000                     1.052349                      0
# NA_OIII_4960_COMB_SNR         40.574123                     0.462503                      0
# NA_OIII_4960_COMB_VOFF        -15.232379                    1.800127                      0
# NA_OIII_4960_COMB_W80         768.140862                    7.406420                      0
# NA_OIII_4960_DISP             141.612851                    2.923850                      0
# NA_OIII_4960_EW               6.527501                      0.258560                      0
# NA_OIII_4960_FLUX             -14.458159                    0.017486                      0
# NA_OIII_4960_FWHM             337.179101                    6.649671                      0
# NA_OIII_4960_LUM              42.908060                     0.017486                      0
# NA_OIII_4960_NPIX             11.000000                     0.287480                      0
# NA_OIII_4960_SNR              22.742967                     0.572372                      0
# NA_OIII_4960_VOFF             -25.374575                    2.462964                      0
# NA_OIII_4960_W80              374.549721                    8.317817                      0
# NA_OIII_5007_2_AMP            173.831805                    4.602447                      0
# NA_OIII_5007_2_DISP           286.100851                    1.902143                      0
# NA_OIII_5007_2_EW             40.175894                     0.987013                      0
# NA_OIII_5007_2_FLUX           -13.677477                    0.010236                      0
# NA_OIII_5007_2_FWHM           674.978857                    4.521167                      0
# NA_OIII_5007_2_LUM            43.688742                     0.010236                      0
# NA_OIII_5007_2_NPIX           24.000000                     0.287480                      0
# NA_OIII_5007_2_SNR            69.977497                     1.856150                      0
# NA_OIII_5007_2_VOFF           -32.885669                    2.033556                      0
# NA_OIII_5007_2_W80            748.611470                    4.859063                      0
# NA_OIII_5007_3_AMP            9.619727                      0.610323                      0
# NA_OIII_5007_3_DISP           1000.000000                   0.000000                      2
# NA_OIII_5007_3_EW             7.701112                      0.510775                      0
# NA_OIII_5007_3_FLUX           -14.395040                    0.026773                      0
# NA_OIII_5007_3_FWHM           2355.082438                   0.237457                      0
# NA_OIII_5007_3_LUM            42.971179                     0.026773                      0
# NA_OIII_5007_3_NPIX           49.000000                     1.553455                      0
# NA_OIII_5007_3_SNR            3.875355                      0.246034                      0
# NA_OIII_5007_3_VOFF           108.308295                    7.206084                      0
# NA_OIII_5007_3_W80            2619.527466                   0.266422                      0
# NA_OIII_5007_AMP              169.086515                    4.254834                      0
# NA_OIII_5007_COMB_DISP        411.914723                    7.090351                      0
# NA_OIII_5007_COMB_EW          67.992969                     0.638902                      0
# NA_OIII_5007_COMB_FLUX        -13.449038                    0.002703                      0
# NA_OIII_5007_COMB_FWHM        479.363998                    3.294360                      0
# NA_OIII_5007_COMB_LUM         43.917180                     0.002703                      0
# NA_OIII_5007_COMB_NPIX        49.000000                     0.899954                      0
# NA_OIII_5007_COMB_SNR         102.723977                    0.638222                      0
# NA_OIII_5007_COMB_VOFF        -15.231457                    1.800226                      0
# NA_OIII_5007_COMB_W80         766.530905                    7.799259                      0
# NA_OIII_5007_DISP             141.612851                    2.923850                      0
# NA_OIII_5007_EW               20.004348                     0.793463                      0
# NA_OIII_5007_FLUX             -13.979800                    0.017486                      0
# NA_OIII_5007_FWHM             336.044990                    6.581593                      0
# NA_OIII_5007_LUM              43.386419                     0.017486                      0
# NA_OIII_5007_NPIX             11.000000                     0.962091                      0
# NA_OIII_5007_SNR              68.133210                     1.717436                      0
# NA_OIII_5007_VOFF             -25.374575                    2.462964                      0
# NA_OIII_5007_W80              377.327126                    8.167442                      0
# NA_OPT_FEII_AMP               0.433983                      0.029399                      0
# NA_OPT_FEII_DISP              53.790775                     2.964101                      0
# NA_OPT_FEII_TEMPLATE_EW       0.190893                      0.012743                      0
# NA_OPT_FEII_TEMPLATE_FLUX     -15.989910                    0.030885                      0
# NA_OPT_FEII_TEMPLATE_LUM      41.376309                     0.030885                      0
# NA_OPT_FEII_VOFF              31.105974                     7.409907                      0
# ...
# APOLY_COEFF_1
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_2
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# APOLY_COEFF_3
#                               init                          0.0
#                               plim                          (-100.0, 100.0)
# BR_H_BETA_AMP
#                               init                          123.71961977961685
#                               plim                          (0.0, 812.7198363113289)
# BR_H_BETA_DISP
#                               init                          500.0
#                               plim                          (300.0, 3000.0)
# BR_H_BETA_VOFF
#                               init                          -14.54495027591921
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# BR_OPT_FEII_AMP
#                               init                          5.826352429250029
#                               plim                          (0, 609.5398772334967)
# BR_OPT_FEII_DISP
#                               init                          500.0
#                               plim                          (500.0, 5000.0)
# BR_OPT_FEII_VOFF
#                               init                          0.0
#                               plim                          (-500.0, 500.0)
# HOST_TEMP_DISP
#                               init                          100.0
#                               plim                          (0.001, 500.0)
# HOST_TEMP_VEL
#                               init                          0.0
#                               plim                          (-500.0, 500)
# NA_H_BETA_AMP
#                               init                          41.23987325987228
#                               plim                          (0.0, 812.7198363113289)
# NA_H_BETA_VOFF
#                               init                          -14.54495027591921
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_2_AMP
#                               init                          135.45330605188815
#                               plim                          (0.0, 812.7198363113289)
# NA_OIII_5007_2_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_OIII_5007_2_VOFF
#                               init                          -20.4166490422637
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_3_AMP
#                               init                          135.45330605188815
#                               plim                          (0.0, 812.7198363113289)
# NA_OIII_5007_3_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_OIII_5007_3_VOFF
#                               init                          -20.4166490422637
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OIII_5007_AMP
#                               init                          135.45330605188815
#                               plim                          (0.0, 812.7198363113289)
# NA_OIII_5007_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_OIII_5007_VOFF
#                               init                          -20.4166490422637
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NA_OPT_FEII_AMP
#                               init                          5.826352429250029
#                               plim                          (0, 609.5398772334967)
# NA_OPT_FEII_DISP
#                               init                          10.0
#                               plim                          (0.1, 500.0)
# NA_OPT_FEII_VOFF
#                               init                          0.0
#                               plim                          (-500.0, 500.0)
# NA_UNK_1_AMP
#                               init                          43.36974189851907
#                               plim                          (0.0, 812.7198363113289)
# NA_UNK_1_DISP
#                               init                          50.0
#                               plim                          (0, 1000)
# NA_UNK_1_VOFF
#                               init                          174.0550600786884
#                               plim                          (-1000, 1000)
#                               prior                         {'type': 'gaussian'}
# NOISE_SCALE
#                               init                          1.0
#                               plim                          (0.0001, 100.0)
#                               prior                         {'type': 'jeffreys'}
# POWER_AMP
#                               init                          29.131762146250143
#                               plim                          (0, 609.5398772334967)
# POWER_SLOPE
#                               init                          -1.0
#                               plim                          (-6.0, 6.0)
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Total number of free parameters: 31
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Soft Constraints:
#
#            NA_OIII_5007_2_DISP > NA_OIII_5007_DISP
#            NA_OIII_5007_3_DISP > NA_OIII_5007_2_DISP
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#  Performing MCMC iterations...
# ----------------------------------------------------------------------------------------------------
# MCMC iteration: 100
# MCMC iteration: 200
# MCMC iteration: 300
# MCMC iteration: 400
# MCMC iteration: 500
# MCMC iteration: 600
# MCMC iteration: 700
# MCMC iteration: 800
# MCMC iteration: 900
# MCMC iteration: 1000
#
# Iteration = 1000
# ------------------------------------------------
# Parameter                     Current Value
# ------------------------------------------------
# APOLY_COEFF_1                 0.5728
# APOLY_COEFF_2                 -2.4483
# APOLY_COEFF_3                 -0.6825
# BR_H_BETA_AMP                 39.4813
# BR_H_BETA_DISP                2265.5962
# BR_H_BETA_VOFF                266.1053
# BR_OPT_FEII_AMP               0.9613
# BR_OPT_FEII_DISP              825.8220
# BR_OPT_FEII_VOFF              5.0550
# HOST_TEMP_DISP                95.5990
# HOST_TEMP_VEL                 -3.7849
# NA_H_BETA_AMP                 17.3822
# NA_H_BETA_VOFF                1.1175
# NA_OIII_5007_2_AMP            172.7555
# NA_OIII_5007_2_DISP           286.3331
# NA_OIII_5007_2_VOFF           -31.8755
# NA_OIII_5007_3_AMP            9.4486
# NA_OIII_5007_3_DISP           997.2895
# NA_OIII_5007_3_VOFF           111.5853
# NA_OIII_5007_AMP              170.9219
# NA_OIII_5007_DISP             141.4631
# NA_OIII_5007_VOFF             -25.7279
# NA_OPT_FEII_AMP               1.1874
# NA_OPT_FEII_DISP              55.8657
# NA_OPT_FEII_VOFF              33.1074
# NA_UNK_1_AMP                  4.4371
# NA_UNK_1_DISP                 1.8472
# NA_UNK_1_VOFF                 115.4475
# NOISE_SCALE                   1.5132
# POWER_AMP                     51.6565
# POWER_SLOPE                   -1.8192
# ------------------------------------------------
#
#  emcee Runtime = 0:12:16.
#
#
#  > Fitting MCMC chains...
#
#  Generating model parameter distributions...
#
# 		  NOISE_SCALE
# 		  HOST_TEMP_VEL
# 		  HOST_TEMP_DISP
# 		  APOLY_COEFF_1
# 		  APOLY_COEFF_2
# 		  APOLY_COEFF_3
# 		  POWER_AMP
# 		  POWER_SLOPE
# 		  NA_OPT_FEII_AMP
# 		  BR_OPT_FEII_AMP
# 		  NA_OPT_FEII_DISP
# 		  BR_OPT_FEII_DISP
# 		  NA_OPT_FEII_VOFF
# 		  BR_OPT_FEII_VOFF
# 		  NA_H_BETA_VOFF
# 		  NA_H_BETA_AMP
# 		  NA_OIII_5007_VOFF
# 		  NA_OIII_5007_AMP
# 		  NA_OIII_5007_DISP
# 		  NA_OIII_5007_2_VOFF
# 		  NA_OIII_5007_2_AMP
# 		  NA_OIII_5007_2_DISP
# 		  NA_OIII_5007_3_VOFF
# 		  NA_OIII_5007_3_AMP
# 		  NA_OIII_5007_3_DISP
# 		  BR_H_BETA_VOFF
# 		  BR_H_BETA_AMP
# 		  BR_H_BETA_DISP
# 		  NA_UNK_1_VOFF
# 		  NA_UNK_1_AMP
# 		  NA_UNK_1_DISP
#
#  Generating model flux distributions...
#
# 		  NA_OPT_FEII_TEMPLATE_FLUX
# 		  BR_OPT_FEII_TEMPLATE_FLUX
# 		  NA_H_BETA_FLUX
# 		  NA_H_BETA_2_FLUX
# 		  NA_H_BETA_3_FLUX
# 		  NA_OIII_4960_FLUX
# 		  NA_OIII_4960_2_FLUX
# 		  NA_OIII_4960_3_FLUX
# 		  NA_OIII_5007_FLUX
# 		  NA_OIII_5007_2_FLUX
# 		  NA_OIII_5007_3_FLUX
# 		  BR_H_BETA_FLUX
# 		  NA_UNK_1_FLUX
# 		  NA_H_BETA_COMB_FLUX
# 		  NA_OIII_4960_COMB_FLUX
# 		  NA_OIII_5007_COMB_FLUX
# 		  H_BETA_COMP_FLUX
#
#  Generating model luminosity distributions...
#
# 		  NA_OPT_FEII_TEMPLATE_LUM
# 		  BR_OPT_FEII_TEMPLATE_LUM
# 		  NA_H_BETA_LUM
# 		  NA_H_BETA_2_LUM
# 		  NA_H_BETA_3_LUM
# 		  NA_OIII_4960_LUM
# 		  NA_OIII_4960_2_LUM
# 		  NA_OIII_4960_3_LUM
# 		  NA_OIII_5007_LUM
# 		  NA_OIII_5007_2_LUM
# 		  NA_OIII_5007_3_LUM
# 		  BR_H_BETA_LUM
# 		  NA_UNK_1_LUM
# 		  NA_H_BETA_COMB_LUM
# 		  NA_OIII_4960_COMB_LUM
# 		  NA_OIII_5007_COMB_LUM
# 		  H_BETA_COMP_LUM
# 		  L_CONT_TOT_5100
# 		  L_CONT_AGN_5100
# 		  L_CONT_HOST_5100
#
#  Generating model equivalent width distributions...
#
# 		  NA_OPT_FEII_TEMPLATE_EW
# 		  BR_OPT_FEII_TEMPLATE_EW
# 		  NA_H_BETA_EW
# 		  NA_H_BETA_2_EW
# 		  NA_H_BETA_3_EW
# 		  NA_OIII_4960_EW
# 		  NA_OIII_4960_2_EW
# 		  NA_OIII_4960_3_EW
# 		  NA_OIII_5007_EW
# 		  NA_OIII_5007_2_EW
# 		  NA_OIII_5007_3_EW
# 		  BR_H_BETA_EW
# 		  NA_UNK_1_EW
# 		  NA_H_BETA_COMB_EW
# 		  NA_OIII_4960_COMB_EW
# 		  NA_OIII_5007_COMB_EW
# 		  H_BETA_COMP_EW
#
#  Generating model integrated velocity moment distributions...
#
# 		  NA_H_BETA_FWHM
# 		  NA_H_BETA_W80
# 		  NA_H_BETA_2_FWHM
# 		  NA_H_BETA_2_W80
# 		  NA_H_BETA_3_FWHM
# 		  NA_H_BETA_3_W80
# 		  NA_OIII_4960_FWHM
# 		  NA_OIII_4960_W80
# 		  NA_OIII_4960_2_FWHM
# 		  NA_OIII_4960_2_W80
# 		  NA_OIII_4960_3_FWHM
# 		  NA_OIII_4960_3_W80
# 		  NA_OIII_5007_FWHM
# 		  NA_OIII_5007_W80
# 		  NA_OIII_5007_2_FWHM
# 		  NA_OIII_5007_2_W80
# 		  NA_OIII_5007_3_FWHM
# 		  NA_OIII_5007_3_W80
# 		  BR_H_BETA_FWHM
# 		  BR_H_BETA_W80
# 		  NA_UNK_1_FWHM
# 		  NA_UNK_1_W80
# 		  NA_H_BETA_COMB_FWHM
# 		  NA_H_BETA_COMB_W80
# 		  NA_H_BETA_COMB_DISP
# 		  NA_H_BETA_COMB_VOFF
# 		  NA_OIII_4960_COMB_FWHM
# 		  NA_OIII_4960_COMB_W80
# 		  NA_OIII_4960_COMB_DISP
# 		  NA_OIII_4960_COMB_VOFF
# 		  NA_OIII_5007_COMB_FWHM
# 		  NA_OIII_5007_COMB_W80
# 		  NA_OIII_5007_COMB_DISP
# 		  NA_OIII_5007_COMB_VOFF
# 		  H_BETA_COMP_FWHM
# 		  H_BETA_COMP_W80
# 		  H_BETA_COMP_DISP
# 		  H_BETA_COMP_VOFF
# 		  NA_H_BETA_NPIX
# 		  NA_H_BETA_2_NPIX
# 		  NA_H_BETA_3_NPIX
# 		  NA_OIII_4960_NPIX
# 		  NA_OIII_4960_2_NPIX
# 		  NA_OIII_4960_3_NPIX
# 		  NA_OIII_5007_NPIX
# 		  NA_OIII_5007_2_NPIX
# 		  NA_OIII_5007_3_NPIX
# 		  BR_H_BETA_NPIX
# 		  NA_UNK_1_NPIX
# 		  NA_H_BETA_COMB_NPIX
# 		  NA_OIII_4960_COMB_NPIX
# 		  NA_OIII_5007_COMB_NPIX
# 		  H_BETA_COMP_NPIX
# 		  NA_H_BETA_SNR
# 		  NA_H_BETA_2_SNR
# 		  NA_H_BETA_3_SNR
# 		  NA_OIII_4960_SNR
# 		  NA_OIII_4960_2_SNR
# 		  NA_OIII_4960_3_SNR
# 		  NA_OIII_5007_SNR
# 		  NA_OIII_5007_2_SNR
# 		  NA_OIII_5007_3_SNR
# 		  BR_H_BETA_SNR
# 		  NA_UNK_1_SNR
# 		  NA_H_BETA_COMB_SNR
# 		  NA_OIII_4960_COMB_SNR
# 		  NA_OIII_5007_COMB_SNR
# 		  H_BETA_COMP_SNR
# 		  R_SQUARED
# 		  RCHI_SQUARED
#
#  > Saving Data...
#
#  Cleaning up...
# ----------------------------------------------------------------------------------------------------
#
#  Total Runtime = 2:24:51
#  - Done fitting spec-2756-54508-0579!
#
# End process memory: 0.29659955
